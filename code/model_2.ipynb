# %%
import pandas as pd 
import numpy as np 
import os
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split

# %%
def tpr_weight_funtion(y_true,y_predict):
    d = pd.DataFrame()
    d['prob'] = list(y_predict)
    d['y'] = list(y_true)
    d = d.sort_values(['prob'], ascending=[0])
    y = d.y
    PosAll = pd.Series(y).value_counts()[1]
    NegAll = pd.Series(y).value_counts()[0]
    pCumsum = d['y'].cumsum()
    nCumsum = np.arange(len(y)) - pCumsum + 1
    pCumsumPer = pCumsum / PosAll
    nCumsumPer = nCumsum / NegAll
    TR1 = pCumsumPer[abs(nCumsumPer-0.001).idxmin()]
    TR2 = pCumsumPer[abs(nCumsumPer-0.005).idxmin()]
    TR3 = pCumsumPer[abs(nCumsumPer-0.01).idxmin()]
    return 0.4 * TR1 + 0.3 * TR2 + 0.3 * TR3

# %%
path = os.path.join(os.path.dirname('__file__'),'data')

def get_data(name):
	train_name = name+'_train_new.csv'
	test_name = 'test_'+name+'_round2.csv'
	train_data_path = os.path.join(path, train_name)
	test_data_path = os.path.join(path, test_name)
	train_data = pd.read_csv('../'+train_data_path)
	test_data = pd.read_csv('../'+test_data_path)
	train_data = pd.concat([train_data, test_data], axis=0, ignore_index=True, sort=False)
	if name=='tag':
		train_data.loc[train_data['Tag']==0.5, 'Tag']=-1
		train_data['Tag'] = train_data['Tag'].astype(int)			
	return train_data

# %%
def get_operation_features(tag_data, operation_data):
	columns = ['day', 'mode', 'success', 'time', 'os', 'version', 'device1',
		       'device2', 'device_code1', 'device_code2', 'device_code3', 'mac1',
		       'mac2', 'ip1', 'wifi', 'geo_code', 'ip1_sub']
	delete = ['mode', 'time', 'os', 'device1', 'success']
	
	operation_data['time'] = operation_data['time'].apply(lambda x: int(x.split(':')[0]))
	tmp_time = operation_data[operation_data['time']<6]
	tmp_time = tmp_time.groupby(['UID'])['time'].agg({'op_time_abnor_nunique':'nunique', 'op_time_abnor_count':'count'}).reset_index()
	tag_data = pd.merge(tag_data, tmp_time, on='UID', how='left')

	operation_data['isnull_num'] = operation_data.apply(lambda x: x.isnull().sum(),axis=1)
	agg_dict = {'isnull_num_max':'max', 'isnull_num_min':'min', 'isnull_num_mean':'mean', 'isnull_numt_std':'std', 'isnull_numt_sum':'sum'}
	tag_data = tag_data.merge(operation_data.groupby(['UID'])['isnull_num'].agg(agg_dict).reset_index(), on='UID', how='left')

	for col in columns:
		count_column = col+'_op_count'
		nunique_column = col+'_op_nunique'
		if col in delete:
			agg_dict = {nunique_column: 'nunique'}
		else:
			agg_dict = {count_column: "count", nunique_column: 'nunique'}
		
		tag_data = tag_data.merge(operation_data.groupby(['UID'])[col].agg(agg_dict).reset_index(), on='UID', how='left')

		count_column = col+'_UID_op_count'
		agg_dict = {count_column: "count"}
		tmp_cat =  operation_data.groupby(['UID', col])['Tag'].agg(agg_dict).reset_index()
		agg_dict = {col+'_op_count_mean':'mean', col+'_op_count_std':'std'}
		tag_data = tag_data.merge(tmp_cat.groupby(['UID'])[count_column].agg(agg_dict).reset_index(), on='UID', how='left')

	one_columns = []
	for col in columns:
		isnull_  = operation_data[col].isnull().sum()/len(operation_data)
		nunique_ = operation_data[col].nunique()
		if nunique_ > 200:
			one_columns.append(col)

	for col in one_columns:
		nunique_ = operation_data[col].nunique()
		if nunique_<5000:
			threshold = 10
		elif nunique_<10000 and nunique_>=5000:
			threshold = 8
		elif nunique_<16000 and nunique_>=10000:
			threshold = 5
		else:
			threshold = 3
		tmp_all = operation_data.groupby(['UID',col])['Tag'].agg({col+'_count':'count'}).reset_index()
		tmp = tmp_all.groupby([col])['UID'].agg({col+'_UID_count':'count'}).reset_index()
		
		#tmp_return = pd.merge(tmp_all, tmp, on=col, how=left)
		#agg_dict = {col+'_num_max':'max', col+'_num_min':'min', col+'_num_mean':'mean', col+'_numt_std':'std', col+'_numt_sum':'sum'}
		#tag_data = tag_data.merge(tmp_return.groupby(['UID'])[col+'_UID_count'].agg(agg_dict).reset_index(), on='UID', how='left')
		
		tmp = tmp[tmp[col+'_UID_count']>threshold+3]
		tmp[col+'_UID_count'] = 1
		tmp_all = pd.merge(tmp_all, tmp, on=col, how='left')
		tmp_all = tmp_all.fillna(0)
		tmp_all = tmp_all.groupby(['UID'])[col+'_UID_count'].agg({col+'_UID_sum':'sum'}).reset_index()
		tag_data = pd.merge(tag_data, tmp_all, on='UID', how='left')


	return tag_data

# %%
def get_transaction_features(tag_data, transaction_data):
	num_columns = ['trans_amt', 'bal']
	columns = ['channel', 'day', 'time', 'amt_src1', 'merchant',
	               'trans_type1', 'acc_id1', 'device_code1',
	               'device_code2', 'device_code3', 'device1', 'device2', 'mac1', 'ip1',
	               'amt_src2', 'acc_id2', 'acc_id3', 'geo_code', 'trans_type2',
	               'market_code', 'market_type', 'ip1_sub']
	delete = ['day', 'time', 'amt_src1', 'merchant','trans_type1', 'ip1', 'bal']

	transaction_data['time'] = transaction_data['time'].apply(lambda x: int(x.split(':')[0]))
	tmp_time = transaction_data[transaction_data['time']<6]
	tmp_time = tmp_time.groupby(['UID'])['time'].agg({'trans_time_abnor_nunique':'nunique', 'trans_time_abnor_count':'count'}).reset_index()
	tag_data = pd.merge(tag_data, tmp_time, on='UID', how='left')

	transaction_data['isnull_num'] = transaction_data.apply(lambda x: x.isnull().sum(),axis=1)
	agg_dict = {'isnull_num_max':'max', 'isnull_num_min':'min', 'isnull_num_mean':'mean', 'isnull_numt_std':'std', 'isnull_numt_sum':'sum'}
	tag_data = tag_data.merge(transaction_data.groupby(['UID'])['isnull_num'].agg(agg_dict).reset_index(), on='UID', how='left')

	for col in columns:
		count_column = col+'_trans_count'
		nunique_column = col+'_trans_nunique'
		if col in delete:
			agg_dict = {nunique_column: 'nunique'}
		else:
			agg_dict = {count_column: "count", nunique_column: 'nunique'}
		
		tag_data = tag_data.merge(transaction_data.groupby(['UID'])[col].agg(agg_dict).reset_index(), on='UID', how='left')

		count_column = col+'_UID_trans_count'
		agg_dict = {count_column: "count"}
		tmp_cat =  transaction_data.groupby(['UID', col])['Tag'].agg(agg_dict).reset_index()
		agg_dict = {col+'_trans_count_mean':'mean', col+'_trans_count_std':'std'}
		tag_data = tag_data.merge(tmp_cat.groupby(['UID'])[count_column].agg(agg_dict).reset_index(), on='UID', how='left')

	for col in num_columns:
		nunique_column = col+'_trans_nunique'
		max_column = col+'_trans_max'
		min_column = col+'_trans_min'
		sum_column = col+'_trans_sum'
		mean_column = col+'_trans_mean'
		std_column = col+'_trans_std'

		agg_dict = {nunique_column:'nunique', max_column:'max', min_column:'min', sum_column:'sum', mean_column:'mean', std_column:'std'}

		tag_data = tag_data.merge(transaction_data.groupby(['UID'])[col].agg(agg_dict).reset_index(), on='UID', how='left')

	one_columns = []
	for col in columns:
		isnull_  = transaction_data[col].isnull().sum()/len(transaction_data)
		nunique_ = transaction_data[col].nunique()
		if nunique_ > 200:
			one_columns.append(col)
	delete = delete+one_columns
	one_columns = columns
	columns = [i for i in columns if i not in delete]

	##10 8 5 3 0.653
	for col in one_columns:
		nunique_ = transaction_data[col].nunique()
		if nunique_<5000:
			threshold = 10
		elif nunique_<10000 and nunique_>=5000:
			threshold = 8
		elif nunique_<16000 and nunique_>=10000:
			threshold = 5
		else:
			threshold = 3
		tmp_all = transaction_data.groupby(['UID',col])['Tag'].agg({col+'_count':'count'}).reset_index()
		tmp = tmp_all.groupby([col])['UID'].agg({col+'_UID_count':'count'}).reset_index()
		tmp = tmp[tmp[col+'_UID_count']>threshold+3]
		tmp[col+'_UID_count'] = 1
		tmp_all = pd.merge(tmp_all, tmp, on=col, how='left')
		tmp_all = tmp_all.fillna(0)
		tmp_all = tmp_all.groupby(['UID'])[col+'_UID_count'].agg({col+'_UID_sum':'sum'}).reset_index()
		tag_data = pd.merge(tag_data, tmp_all, on='UID', how='left')

	return tag_data

# %%
def get_ctr_feature(tag_data):
	train_data = tag_data[tag_data['Tag']!=-1]
	columns = tag_data.columns
	items = []
	lack_features = ['device_code3','mac1','acc_id2','acc_id3','market_code','market_type']
	for col in columns:
		if tag_data[col].nunique()<30 and col != 'Tag':
			flag=0
			for lack_ in lack_features:
				if lack_ in col:
					flag=1
					break
			if flag==0:
				items.append(col)
	for item in items:
		temp = train_data.groupby(item, as_index = False)['Tag'].agg({item+'_click':'sum', item+'_count':'count'})
		temp[item+'_ctr'] = temp[item+'_click']/(temp[item+'_count'])
		tag_data = pd.merge(tag_data, temp, on=item, how='left')

	for i in range(len(items)):
		for j in range(i+1, len(items)):
			item_g = [items[i], items[j]]
			temp = train_data.groupby(item_g, as_index=False)['Tag'].agg({'_'.join(item_g)+'_click': 'sum','_'.join(item_g)+'count':'count'})
			temp['_'.join(item_g)+'_ctr'] = temp['_'.join(item_g)+'_click']/(temp['_'.join(item_g)+'count']+3)
			tag_data = pd.merge(tag_data, temp, on=item_g, how='left')

	return tag_data

# %%
def get_cat_used(tag_data, operation_data, transaction_data):
	
	def get_cat(x):
		res = []
		tmp = x.value_counts()
		tmp_value=list(tmp)
		if tmp.shape[0]>1 and tmp.index[0]==-1:
			res.append(tmp.index[1])
			res.append(tmp_value[1]/len(x))
			return res
		else:
			res.append(tmp.index[0])
			res.append(tmp_value[0]/len(x))
			return res


	cols = ['mode', 'os',  'device2',  'geo_code', 'ip1_sub','version',  'mac2','device1', 'device_code1', 'device_code2', 'device_code3','ip1', 'mac1','wifi']
	for col in cols:
		tmp=pd.DataFrame()
		operation_data[col] = pd.factorize(operation_data[col])[0]
		tmp = operation_data.groupby(['UID'])[col].apply(get_cat).reset_index()
		#tmp[col+'_op_clike'] = tmp[col].apply(lambda x: x[0])
		tmp[col+'_op_clike_ratio'] = tmp[col].apply(lambda x: x[1])
		tmp = tmp.drop(col, axis=1)
		tag_data = pd.merge(tag_data, tmp, on='UID',how='left')

	#for col in cols:
		#tag_data = tag_data.merge(operation_data.groupby(['UID'])[col].agg(lambda x: x.value_counts().index[0]).reset_index(),on='UID',how='left')

	#op_data['hour'] = op_data.time.str[0:2].astype(int)
	#op_data['time'] = pd.to_datetime(op_data['time'])
	#op_data['time'] = op_data['time'].apply(lambda x:(x-datetime.now()).seconds/3600)

	cols_f = ['amt_src1', 'trans_type1','amt_src2','geo_code','ip1_sub','mac1','acc_id2','merchant','acc_id3','channel','market_type',
			'trans_type2','market_code','ip1','device_code2','device_code3','device1','device_code1','acc_id1','device2']
	for col in cols_f:
		tmp=pd.DataFrame()
		transaction_data[col] = pd.factorize(transaction_data[col])[0]
		tmp = transaction_data.groupby(['UID'])[col].apply(get_cat).reset_index()
		#tmp[col+'_trans_clike'] = tmp[col].apply(lambda x: x[0])
		tmp[col+'_trans_clike_ratio'] = tmp[col].apply(lambda x: x[1])
		tmp = tmp.drop(col, axis=1)
		tag_data = pd.merge(tag_data, tmp, on='UID',how='left')

	#for col in cols_f:
		#tag_data = tag_data.merge(transaction_data.groupby(['UID'])[col].agg(lambda x: x.value_counts().index[0]).reset_index(),on='UID',how='left')
	
	#tr_data['hour'] = tr_data.time.str[0:2].astype(int)
	#tr_data['time'] = pd.to_datetime(tr_data['time'])
	#tr_data['time'] = tr_data['time'].apply(lambda x:(x-datetime.now()).seconds/3600)

	return tag_data

# %%
def bulid_cat_feature(uid_list,feature_list,featureName):
	#1.找到每个uid有哪些特征
	uid2featureList = {}  #key uid  feature 这个uid对应历史上出现过哪些list
	for i in range(len(uid_list)):
	    uid = uid_list[i]
	    feature = feature_list[i]
	    #不为空
	    #if feature:
	    if not pd.isnull(feature):
	        if uid not in uid2featureList:
	            uid2featureList[uid] = set()
	        uid2featureList[uid].add(str(feature))  #用str

	feasvalue2index = {}  #这个值对应的特征名         
	#2.将每一行转化为dict
	rows = []
	for uid,value in uid2featureList.items():
	    tmp_dict = {}
	    tmp_dict["UID"] = uid
	    value = "@".join(sorted(list(value)))
	    if value not in feasvalue2index:
	        feasvalue2index[value] = len(feasvalue2index)
	    tmp_dict[featureName+"_cat"] = feasvalue2index[value]
	    rows.append(tmp_dict)
	df = pd.DataFrame(rows)
	return df

# %%
def get_cat_feature(tag_data, operation_data, transaction_data):
	one_hot_t_feature = ["channel","amt_src1","trans_type1","amt_src2","trans_type2","market_type"]
	one_hot_op_feature = ["mode","success","os","version"]
	#4.构造分类特征 0.31 -> 0.48
	for feature in one_hot_t_feature:
		df_temp = bulid_cat_feature(list(transaction_data["UID"]),list(transaction_data[feature]),feature)
		tag_data = tag_data.merge(df_temp,on='UID',how='left')

	for feature in one_hot_op_feature:
		df_temp = bulid_cat_feature(list(operation_data["UID"]),list(operation_data[feature]),feature)
		tag_data = tag_data.merge(df_temp,on='UID',how='left')

	return tag_data

# %%
def get_cross_feature(tag_data, operation_data, transaction_data):
	cross_col = ['mode', 'os', 'version', 'device1',
				'device2', 'device_code1', 'device_code2', 'device_code3', 'mac1',
				'mac2', 'ip1',  'wifi', 'geo_code', 'ip1_sub']
	for col in cross_col: 
		tmp = operation_data.groupby(['UID', 'day'])[col].agg({col+'_op_day_nunique': 'nunique'})
		tmp = tmp.groupby(['UID'])[col+'_op_day_nunique'].agg({col+'_op_day_nunique_max':'max', col+'_op_day_nunique_mean':'mean'})
		tag_data = pd.merge(tag_data, tmp, on='UID', how='left')
	cross_col = ['channel', 'trans_amt', 'amt_src1', 'merchant',
				'trans_type1', 'acc_id1', 'device_code1',
				'device_code2', 'device_code3', 'device1', 'device2', 'mac1', 'ip1',
				'bal', 'amt_src2', 'acc_id2', 'acc_id3', 'geo_code', 'trans_type2',
				'market_code', 'market_type', 'ip1_sub']
	for col in cross_col: 
		tmp = transaction_data.groupby(['UID', 'day'])[col].agg({col+'_trans_day_nunique': 'nunique'})
		tmp = tmp.groupby(['UID'])[col+'_trans_day_nunique'].agg({col+'_trans_day_nunique_max':'max', col+'_trans_day_nunique_mean':'mean'})
		tag_data = pd.merge(tag_data, tmp, on='UID', how='left')
	return tag_data

# %%
def get_time_feature(tag_data, operation_data, transaction_data):
	"""
feature_prefix:特征前缀

对day特征进行构建
针对每个UID
(1)计算这个UID前后两次交易的平均时间   如  1,6,10  那么平均时间为  （5 + 4） / 2  = 4.5 (多少天会交易1次)
(2)计算这个UID第1次交易和最后一次交易的时间差   如1,6,10  那么前后两次交易的时间差为 10 - 1 = 9

后续可以开发的 max_gap  min_gap 

"""
	def bulid_day_avg_gap(uid_list,feature_list,feature_prefix):
		uid2daylist = {}
		#1.先计算每个uid有哪些day
		for i in range(len(uid_list)):
			uid = uid_list[i]
			day = feature_list[i]
			if uid not in uid2daylist:
				uid2daylist[uid] = []
			uid2daylist[uid].append(day)

		rows = []
		#2.对每个uid进行处理
		for uid,value in uid2daylist.items():
			value = sorted(value)
			if len(value) == 1:
				avg = 0
				gap = 0
			else:
				tmp_sum = 0
				for i in range(1,len(value)):
				    tmp_sum += (value[i] - value[i - 1])
				avg = tmp_sum * 1.0 / (len(value))
				gap = value[-1] - value[0]

			tmp_dict = {}
			tmp_dict["UID"] = uid
			tmp_dict[feature_prefix + "_avg"] = avg
			tmp_dict[feature_prefix + "_gap"] = gap
			rows.append(tmp_dict)

		df = pd.DataFrame(rows)
		#if norm_flag:
		#归一化
		#df[feature_prefix + "_avg"] = norm_list(list(df[feature_prefix + "_avg"]))
		#df[feature_prefix + "_gap"] = norm_list(list(df[feature_prefix + "_gap"]))
		#print df
		return df

	"""
	对time进行处理
	(1)计算这个UID前后两次交易的平均时间   
	(2)计算这个UID第1次交易和最后一次交易的时间差
	_day_hour 精确到小时
	_day_hour_min 精确到分钟
	"""
	def bulid_time_avg_gap(uid_list,day_list,time_list,feature_prefix):
		day_hour_list = []
		day_hour_min_list = []
		for i in range(len(day_list)):
			day = int(day_list[i])
			time_array_2 = time_list[i].split(':') #时分秒
			hour = int(time_array_2[0])
			minute = int(time_array_2[1])
			day_hour_list.append(day * 24 + hour )
			day_hour_min_list.append(day * 3600 + hour * 60 + minute)

		df1 = bulid_day_avg_gap(uid_list,day_hour_list,feature_prefix+"_day_hour")
		df2 = bulid_day_avg_gap(uid_list,day_hour_min_list,feature_prefix+"_day_hour_min")
		df1 = df1.merge(df2,on='UID',how='left')
		#print df1
		return df1
	#2.时间day的统计 (这部分如果不需要基础统计，就不放在get_feature之前)
	#统计每个UID 每次交易的平均时间间隔 最大时间间隔，最小时间间隔 (Day为单位)
	#(1)trans - day
	df_temp = bulid_day_avg_gap(list(transaction_data["UID"]),list(transaction_data["day"]),"trans_day_between")
	tag_data = tag_data.merge(df_temp,on='UID',how='left')

	#(2)op - day
	df_temp = bulid_day_avg_gap(list(operation_data["UID"]),list(operation_data["day"]),"op_day_between")
	tag_data = tag_data.merge(df_temp,on='UID',how='left')

	#(3)trans - time
	#df_temp = bulid_time_avg_gap(list(transaction_data["UID"]),list(transaction_data["day"]),list(transaction_data["time"]),"trans_time_between")
	#tag_data = tag_data.merge(df_temp,on='UID',how='left')

	#(4)op - time
	#df_temp = bulid_time_avg_gap(list(operation_data["UID"]),list(operation_data["day"]),list(operation_data["time"]),"op_time_between")
	#tag_data = tag_data.merge(df_temp,on='UID',how='left')

	return tag_data

# %%
def deal_tag_features(tag_data):
	features = tag_data.columns
	flag = '_Tag_count_max'
	Tag_features = [col for col in features if flag in col]
	tag_data = tag_data.drop(Tag_features, axis=1)
	flag = 'ctr'
	Tag_features = [col for col in features if flag in col]
	tag_data = tag_data.drop(Tag_features, axis=1)
	#tag_data.loc[tag_data['Tag_count_max_sum']>3, 'Tag_count_max_sum']=4
	return tag_data

# %%
def get_day_feature(data_set, tag_data):
	tmp = data_set.groupby(['UID', 'merchant'])['day'].agg({'day':'mean'}).reset_index()
	tmp_merchant_day = tmp.groupby(['merchant', 'day'])['UID'].agg({'count':'count'}).reset_index()
	tmp_merchant = tmp.groupby(['merchant'])['UID'].agg({'all_count':'count'}).reset_index()
	tmp_merchant_day = tmp_merchant_day.merge(tmp_merchant, on='merchant', how='left')
	tmp_merchant_day['day_ratio'] = tmp_merchant_day['count']/tmp_merchant_day['all_count']
	tmp = tmp.merge(tmp_merchant_day, on=['merchant', 'day'], how='left')
	tmp = tmp.groupby(['UID'])['day_ratio'].agg({'ratio_mean':'mean', 'ratio_max':'max', 'ratio_min':'min', 'ratio_std':'std'}).reset_index()
	tag_data = tag_data.merge(tmp, on='UID', how='left')
	return tag_data

def get_mercant_feature(data_set, tag_data):
	tmp = data_set.groupby(['merchant'])['UID'].agg({'merchant_UID_nunique':'nunique'})
	tmp = data_set.merge(tmp, on='merchant', how='left')
	tmp = tmp.groupby(['UID'])['merchant_UID_nunique'].agg({'merchant_UID_nunique_max':'max', 'merchant_UID_nunique_mim':'min','merchant_UID_nunique_mean':'mean', 'merchant_UID_nunique_std':'std'}).reset_index()
	tag_data = tag_data.merge(tmp, on='UID', how='left')
	return tag_data

# %%
def get_features(tag_data, operation_data, transaction_data):
	print('==============================')
	print('start getting operation features....')
#
	tag_data = get_operation_features(tag_data, operation_data)
#
	print('finish getting operation features....')
#
	print('==============================')
	print('start getting transaction features....')
#
	tag_data = get_transaction_features(tag_data, transaction_data)
	
#
	print('finish getting transaction features....')
#
	print('==============================')
	print('start getting ctr features....')
#
	#tag_data = get_ctr_feature(tag_data)
#	
	#tag_data = get_checkBlack_count(tag_data, operation_data, transaction_data)

	print('finish getting ctr features....')

	print('==============================')
	print('start getting cat features....')

	#tag_data = get_cat_feature(tag_data, operation_data, transaction_data)

	tag_data = get_time_feature(tag_data, operation_data, transaction_data)

	tag_data = get_cross_feature(tag_data, operation_data, transaction_data)

	tag_data = get_cat_used(tag_data, operation_data, transaction_data)

	tag_data = get_day_feature(transaction_data, tag_data)

	#tag_data = get_mercant_feature(transaction_data, tag_data)
	print('start getting cat features....')
	#tag_data = pd.read_csv('../data/tag_data.csv')

	tag_data = deal_tag_features(tag_data)

	return tag_data

# %%
def lgb_model(tag_data, operation_data, transaction_data):


    #train_features = train_data[features_columns]
    #train_labels = train_data["tag"]

	lgb_parms = {
				"boosting_type": "gbdt",
				"num_leaves": 35,
				"max_depth": -1,
				"learning_rate": 0.1,
				"n_estimators": 500,
				"max_bin": 425,
				"subsample_for_bin": 20000,
				"objective": 'binary',
				"metric": 'auc',
				"min_split_gain": 0,
				"min_child_weight": 0.001,
				"min_child_samples": 20,
				"subsample": 0.9,
				"subsample_freq": 1,
				"colsample_bytree": 0.7,
				"reg_alpha": 3,
				"reg_lambda": 5,
				"seed": 2018,
				"n_jobs": 25,
				"verbose": 1,
				"silent": False,
				}

	#test_data = test_data.drop(['Tag'], axis = 1)

	trian_tag = tag_data[tag_data['Tag']!=-1]
	test_tag = tag_data[tag_data['Tag']==-1]

	n_folds = 2

	preds_list = list()
	vali_score = list()
	features_importance=pd.DataFrame()
	for times in range(n_folds):
		train_tag, val_tag, train_tag_, val_tag_ = train_test_split(trian_tag,trian_tag['Tag'],test_size=0.5,random_state=times)
		test_tag_1, test_tag_2, test_1, test_tag2 = train_test_split(test_tag,test_tag['Tag'],test_size=0.5,random_state=times)
		#train_data
		train_op_data = operation_data[operation_data['UID'].isin(train_tag['UID'])]
		train_trans_data = transaction_data[transaction_data['UID'].isin(train_tag['UID'])]
		#val_data
		val_op_data = operation_data[operation_data['UID'].isin(val_tag['UID'])]
		val_trans_data = transaction_data[transaction_data['UID'].isin(val_tag['UID'])]
		#test_data1
		test_op_data_1 = operation_data[operation_data['UID'].isin(test_tag_1['UID'])]
		test_trans_data_1 = transaction_data[transaction_data['UID'].isin(test_tag_1['UID'])]
		#test_data2
		test_op_data_2 = operation_data[operation_data['UID'].isin(test_tag_2['UID'])]
		test_trans_data_2 = transaction_data[transaction_data['UID'].isin(test_tag_2['UID'])]

		train_tag = get_features(train_tag, train_op_data, train_trans_data)
		val_tag = get_features(val_tag, val_op_data, val_trans_data)
		test_tag_1 = get_features(test_tag_1, test_op_data_1, test_trans_data_1)
		test_tag_2 = get_features(test_tag_2, test_op_data_2, test_trans_data_2)

		test_data = pd.concat([test_tag_1, test_tag_2], axis=0, ignore_index=True, sort=False)
		test_data = test_data.sort_values(['UID'])

		print(test_data['UID'])
		print(train_tag.shape)
		print(val_tag.shape)
		print(test_data.shape)

		print('==============================')
		print('start training....')

		columns = train_tag.columns
		remove_columns = ['Tag']
		features_columns = [column for column in columns if column not in remove_columns]
		
		test_data = test_data.drop(['Tag'], axis = 1)
		features_importance['feature_name'] = features_columns
		for i in range(2):
			if i==0:
				k_train = train_tag
				k_test = val_tag
			else:
				k_train = val_tag
				k_test = train_tag


			X_train = k_train.drop(['Tag'], axis = 1)
			y_train = k_train['Tag']
			X_test = k_test.drop(['Tag'], axis = 1)
			y_test = k_test['Tag']

			gbm = lgb.LGBMClassifier(**lgb_parms)
			gbm = gbm.fit(X_train, y_train,
		                  eval_metric="auc",
		                  eval_set=[(X_train, y_train),
		                            (X_test, y_test)],
		                  eval_names=["train", "valid"],
		                  early_stopping_rounds=100,
		                  verbose=True)

			vali_pred = gbm.predict_proba(X_test, num_iteration=gbm.best_iteration_)[:, 1]
			vali_k_score = tpr_weight_funtion(y_test, vali_pred)

			print('The {} {} kfold score : {}'.format(times, i, vali_k_score))

			vali_score.append(vali_k_score)
			preds = gbm.predict_proba(test_data, num_iteration=gbm.best_iteration_)[:, 1]

			preds_list.append(preds)

			booster = gbm.booster_
			importance = booster.feature_importance(importance_type='split')
			feature_name = booster.feature_name()
			feature_importance = pd.DataFrame({'feature_name':feature_name,'importance_'+str(times)+str(i):importance} )
			features_importance = pd.merge(features_importance, feature_importance, how='left', on='feature_name')

	features_importance.to_csv('../data/features_importance_devide.csv', index=False)

	for n, (i) in enumerate(vali_score):
		print('score_{}: {}'.format(n, i))    
	print('score_mean: ', np.mean(vali_score))

	s = 0
	for i in preds_list:
		s = s + i

	test_tag = test_tag.drop(['Tag'], axis = 1)
	print(s)
# 	save = pd.DataFrame(list(s))
# 	save.to_csv('../submit/save.csv',index = False)
	test_tag['Tag'] = list(s / (n_folds*2))
	test_tag[['UID', 'Tag']].to_csv('../result/model_2.csv',index = False)

# %%
def Processing():

	operation_data = get_data(name='operation')
	transaction_data = get_data(name='transaction')
	tag_data = get_data(name='tag')
	operation_data = pd.merge(operation_data, tag_data, on='UID', how='left')
	transaction_data = pd.merge(transaction_data, tag_data, on='UID', how='left')
	op_delete=['ip2', 'ip2_sub' ]
	trans_delete = ['code1', 'code2']
	operation_data = operation_data.drop(op_delete, axis=1)
	transaction_data = transaction_data.drop(trans_delete, axis=1)
	print('finish get data...')

	lgb_model(tag_data, operation_data, transaction_data)

# %%
if __name__ == "__main__":
    Processing()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2881: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# finish get data...
# ==============================
# start getting operation features....
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:9: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:14: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:24: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:28: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:30: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:49: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:50: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:60: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# finish getting operation features....
# ==============================
# start getting transaction features....
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:12: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:17: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:27: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:31: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:33: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:45: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:68: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:69: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:74: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# finish getting transaction features....
# ==============================
# start getting ctr features....
# finish getting ctr features....
# ==============================
# start getting cat features....
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:7: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:15: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:16: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   from ipykernel import kernelapp as app
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   app.launch_new_instance()
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:8: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# start getting cat features....
# ==============================
# start getting operation features....
# finish getting operation features....
# ==============================
# start getting transaction features....
# finish getting transaction features....
# ==============================
# start getting ctr features....
# finish getting ctr features....
# ==============================
# start getting cat features....
# start getting cat features....
# ==============================
# start getting operation features....
# finish getting operation features....
# ==============================
# start getting transaction features....
# finish getting transaction features....
# ==============================
# start getting ctr features....
# finish getting ctr features....
# ==============================
# start getting cat features....
# start getting cat features....
# ==============================
# start getting operation features....
# finish getting operation features....
# ==============================
# start getting transaction features....
# finish getting transaction features....
# ==============================
# start getting ctr features....
# finish getting ctr features....
# ==============================
# start getting cat features....
# start getting cat features....
# 24867    100000
# 29735    100001
# 30636    100002
# 29678    100003
# 20127    100004
# 2310     100005
# 16169    100006
# 19342    100007
# 24821    100008
# 28253    100009
# 11573    100010
# 8916     100011
# 25204    100012
# 9637     100013
# 2771     100014
# 29585    100015
# 26558    100016
# 27685    100017
# 15795    100018
# 11356    100019
# 1755     100020
# 6275     100021
# 15824    100022
# 4832     100023
# 8528     100024
# 30946    100025
# 9216     100026
# 27618    100027
# 9736     100028
# 23033    100029
#           ...
# 22768    131558
# 7901     131559
# 13571    131560
# 23485    131561
# 27387    131562
# 9667     131563
# 10306    131564
# 31204    131565
# 24856    131566
# 19390    131567
# 20347    131568
# 17662    131569
# 18600    131570
# 9538     131571
# 18218    131572
# 24477    131573
# 29740    131574
# 2638     131575
# 30634    131576
# 1577     131577
# 12075    131578
# 10187    131579
# 10554    131580
# 31523    131581
# 30340    131582
# 20193    131583
# 25425    131584
# 22969    131585
# 20315    131586
# 17607    131587
# Name: UID, Length: 31588, dtype: int64
# (15589, 320)
# (15590, 320)
# (31588, 320)
# ==============================
# start training....
# [1]	train's auc: 0.921349	valid's auc: 0.904057
# Training until validation scores don't improve for 100 rounds.
# [2]	train's auc: 0.937735	valid's auc: 0.920758
# [3]	train's auc: 0.940703	valid's auc: 0.925316
# [4]	train's auc: 0.948557	valid's auc: 0.930928
# [5]	train's auc: 0.952913	valid's auc: 0.932738
# [6]	train's auc: 0.954632	valid's auc: 0.933545
# [7]	train's auc: 0.955975	valid's auc: 0.933515
# [8]	train's auc: 0.958774	valid's auc: 0.936
# [9]	train's auc: 0.961247	valid's auc: 0.938023
# [10]	train's auc: 0.963189	valid's auc: 0.940065
# [11]	train's auc: 0.964608	valid's auc: 0.940901
# [12]	train's auc: 0.96616	valid's auc: 0.942067
# [13]	train's auc: 0.967165	valid's auc: 0.943038
# [14]	train's auc: 0.968038	valid's auc: 0.944443
# [15]	train's auc: 0.968855	valid's auc: 0.945268
# [16]	train's auc: 0.970284	valid's auc: 0.946664
# [17]	train's auc: 0.97129	valid's auc: 0.947308
# [18]	train's auc: 0.97201	valid's auc: 0.947736
# [19]	train's auc: 0.972337	valid's auc: 0.948235
# [20]	train's auc: 0.972963	valid's auc: 0.948699
# [21]	train's auc: 0.973866	valid's auc: 0.949112
# [22]	train's auc: 0.974562	valid's auc: 0.94956
# [23]	train's auc: 0.975491	valid's auc: 0.950529
# [24]	train's auc: 0.976094	valid's auc: 0.950962
# [25]	train's auc: 0.976597	valid's auc: 0.95125
# [26]	train's auc: 0.977378	valid's auc: 0.951444
# [27]	train's auc: 0.977954	valid's auc: 0.95174
# [28]	train's auc: 0.978447	valid's auc: 0.951891
# [29]	train's auc: 0.9789	valid's auc: 0.952023
# [30]	train's auc: 0.979459	valid's auc: 0.952066
# [31]	train's auc: 0.980074	valid's auc: 0.952389
# [32]	train's auc: 0.980536	valid's auc: 0.952787
# [33]	train's auc: 0.981233	valid's auc: 0.95318
# [34]	train's auc: 0.981637	valid's auc: 0.953572
# [35]	train's auc: 0.981968	valid's auc: 0.953758
# [36]	train's auc: 0.982313	valid's auc: 0.953914
# [37]	train's auc: 0.982704	valid's auc: 0.954034
# [38]	train's auc: 0.983203	valid's auc: 0.954079
# [39]	train's auc: 0.983603	valid's auc: 0.95426
# [40]	train's auc: 0.984047	valid's auc: 0.954407
# [41]	train's auc: 0.984434	valid's auc: 0.954476
# [42]	train's auc: 0.984738	valid's auc: 0.95476
# [43]	train's auc: 0.985019	valid's auc: 0.954785
# [44]	train's auc: 0.985531	valid's auc: 0.955025
# [45]	train's auc: 0.985903	valid's auc: 0.955204
# [46]	train's auc: 0.986457	valid's auc: 0.955412
# [47]	train's auc: 0.986844	valid's auc: 0.955458
# [48]	train's auc: 0.987191	valid's auc: 0.955626
# [49]	train's auc: 0.987605	valid's auc: 0.95591
# [50]	train's auc: 0.987966	valid's auc: 0.956122
# [51]	train's auc: 0.988256	valid's auc: 0.956336
# [52]	train's auc: 0.988543	valid's auc: 0.956499
# [53]	train's auc: 0.988844	valid's auc: 0.956716
# [54]	train's auc: 0.989113	valid's auc: 0.957036
# [55]	train's auc: 0.989408	valid's auc: 0.95732
# [56]	train's auc: 0.989644	valid's auc: 0.957558
# [57]	train's auc: 0.989895	valid's auc: 0.957674
# [58]	train's auc: 0.990125	valid's auc: 0.9577
# [59]	train's auc: 0.990406	valid's auc: 0.957798
# [60]	train's auc: 0.990583	valid's auc: 0.957818
# [61]	train's auc: 0.990831	valid's auc: 0.957868
# [62]	train's auc: 0.991106	valid's auc: 0.957989
# [63]	train's auc: 0.99137	valid's auc: 0.958072
# [64]	train's auc: 0.9917	valid's auc: 0.958145
# [65]	train's auc: 0.991936	valid's auc: 0.958241
# [66]	train's auc: 0.992158	valid's auc: 0.958327
# [67]	train's auc: 0.992339	valid's auc: 0.958531
# [68]	train's auc: 0.992551	valid's auc: 0.958593
# [69]	train's auc: 0.992743	valid's auc: 0.958771
# [70]	train's auc: 0.992936	valid's auc: 0.958919
# [71]	train's auc: 0.993178	valid's auc: 0.959113
# [72]	train's auc: 0.993335	valid's auc: 0.959061
# [73]	train's auc: 0.99359	valid's auc: 0.959139
# [74]	train's auc: 0.993735	valid's auc: 0.959204
# [75]	train's auc: 0.99389	valid's auc: 0.959341
# [76]	train's auc: 0.994051	valid's auc: 0.959343
# [77]	train's auc: 0.994187	valid's auc: 0.959405
# [78]	train's auc: 0.994371	valid's auc: 0.959544
# [79]	train's auc: 0.994472	valid's auc: 0.959574
# [80]	train's auc: 0.994679	valid's auc: 0.959588
# [81]	train's auc: 0.994831	valid's auc: 0.959619
# [82]	train's auc: 0.994941	valid's auc: 0.95969
# [83]	train's auc: 0.995092	valid's auc: 0.959797
# [84]	train's auc: 0.995199	valid's auc: 0.95991
# [85]	train's auc: 0.99531	valid's auc: 0.960078
# [86]	train's auc: 0.995409	valid's auc: 0.96019
# [87]	train's auc: 0.995536	valid's auc: 0.960307
# [88]	train's auc: 0.995653	valid's auc: 0.960403
# [89]	train's auc: 0.995747	valid's auc: 0.960497
# [90]	train's auc: 0.995824	valid's auc: 0.960503
# [91]	train's auc: 0.995974	valid's auc: 0.960712
# [92]	train's auc: 0.996097	valid's auc: 0.960714
# [93]	train's auc: 0.996193	valid's auc: 0.960719
# [94]	train's auc: 0.99627	valid's auc: 0.960802
# [95]	train's auc: 0.996364	valid's auc: 0.960878
# [96]	train's auc: 0.996458	valid's auc: 0.960909
# [97]	train's auc: 0.996566	valid's auc: 0.961026
# [98]	train's auc: 0.996624	valid's auc: 0.961025
# [99]	train's auc: 0.996702	valid's auc: 0.961044
# [100]	train's auc: 0.996787	valid's auc: 0.961006
# [101]	train's auc: 0.996871	valid's auc: 0.961007
# [102]	train's auc: 0.996949	valid's auc: 0.960926
# [103]	train's auc: 0.997016	valid's auc: 0.960951
# [104]	train's auc: 0.997112	valid's auc: 0.961102
# [105]	train's auc: 0.997185	valid's auc: 0.961213
# [106]	train's auc: 0.997251	valid's auc: 0.9612
# [107]	train's auc: 0.997339	valid's auc: 0.961138
# [108]	train's auc: 0.997429	valid's auc: 0.961194
# [109]	train's auc: 0.997498	valid's auc: 0.961303
# [110]	train's auc: 0.997561	valid's auc: 0.961317
# [111]	train's auc: 0.997612	valid's auc: 0.961368
# [112]	train's auc: 0.99764	valid's auc: 0.961345
# [113]	train's auc: 0.997675	valid's auc: 0.961236
# [114]	train's auc: 0.99774	valid's auc: 0.961368
# [115]	train's auc: 0.997819	valid's auc: 0.96138
# [116]	train's auc: 0.99788	valid's auc: 0.961383
# [117]	train's auc: 0.997953	valid's auc: 0.961478
# [118]	train's auc: 0.998016	valid's auc: 0.961568
# [119]	train's auc: 0.998052	valid's auc: 0.961534
# [120]	train's auc: 0.998116	valid's auc: 0.961618
# [121]	train's auc: 0.998154	valid's auc: 0.961725
# [122]	train's auc: 0.998195	valid's auc: 0.96167
# [123]	train's auc: 0.998246	valid's auc: 0.961717
# [124]	train's auc: 0.998299	valid's auc: 0.961628
# [125]	train's auc: 0.998339	valid's auc: 0.961648
# [126]	train's auc: 0.998388	valid's auc: 0.961675
# [127]	train's auc: 0.998436	valid's auc: 0.961654
# [128]	train's auc: 0.998474	valid's auc: 0.961685
# [129]	train's auc: 0.998532	valid's auc: 0.961618
# [130]	train's auc: 0.998586	valid's auc: 0.961629
# [131]	train's auc: 0.998635	valid's auc: 0.961614
# [132]	train's auc: 0.998695	valid's auc: 0.961588
# [133]	train's auc: 0.998739	valid's auc: 0.961649
# [134]	train's auc: 0.998775	valid's auc: 0.961656
# [135]	train's auc: 0.998818	valid's auc: 0.961665
# [136]	train's auc: 0.998839	valid's auc: 0.961687
# [137]	train's auc: 0.99888	valid's auc: 0.961694
# [138]	train's auc: 0.998912	valid's auc: 0.96183
# [139]	train's auc: 0.998935	valid's auc: 0.961886
# [140]	train's auc: 0.998956	valid's auc: 0.961971
# [141]	train's auc: 0.998972	valid's auc: 0.961936
# [142]	train's auc: 0.999004	valid's auc: 0.961941
# [143]	train's auc: 0.999032	valid's auc: 0.96203
# [144]	train's auc: 0.999059	valid's auc: 0.962092
# [145]	train's auc: 0.999084	valid's auc: 0.96206
# [146]	train's auc: 0.999105	valid's auc: 0.962025
# [147]	train's auc: 0.999118	valid's auc: 0.962009
# [148]	train's auc: 0.999148	valid's auc: 0.961998
# [149]	train's auc: 0.999174	valid's auc: 0.96201
# [150]	train's auc: 0.9992	valid's auc: 0.961989
# [151]	train's auc: 0.999223	valid's auc: 0.961969
# [152]	train's auc: 0.999249	valid's auc: 0.961907
# [153]	train's auc: 0.999262	valid's auc: 0.961942
# [154]	train's auc: 0.99929	valid's auc: 0.962003
# [155]	train's auc: 0.99932	valid's auc: 0.961976
# [156]	train's auc: 0.99934	valid's auc: 0.962038
# [157]	train's auc: 0.99936	valid's auc: 0.962069
# [158]	train's auc: 0.999375	valid's auc: 0.962018
# [159]	train's auc: 0.99939	valid's auc: 0.962068
# [160]	train's auc: 0.999404	valid's auc: 0.962047
# [161]	train's auc: 0.999428	valid's auc: 0.961988
# [162]	train's auc: 0.999447	valid's auc: 0.962059
# [163]	train's auc: 0.999464	valid's auc: 0.961934
# [164]	train's auc: 0.999473	valid's auc: 0.961923
# [165]	train's auc: 0.999485	valid's auc: 0.961991
# [166]	train's auc: 0.999505	valid's auc: 0.96199
# [167]	train's auc: 0.999523	valid's auc: 0.961963
# [168]	train's auc: 0.99953	valid's auc: 0.961905
# [169]	train's auc: 0.999541	valid's auc: 0.961943
# [170]	train's auc: 0.999561	valid's auc: 0.961957
# [171]	train's auc: 0.999575	valid's auc: 0.961965
# [172]	train's auc: 0.999581	valid's auc: 0.962005
# [173]	train's auc: 0.999595	valid's auc: 0.962002
# [174]	train's auc: 0.999612	valid's auc: 0.961895
# [175]	train's auc: 0.99962	valid's auc: 0.96182
# [176]	train's auc: 0.99963	valid's auc: 0.961796
# [177]	train's auc: 0.999644	valid's auc: 0.961822
# [178]	train's auc: 0.999654	valid's auc: 0.961834
# [179]	train's auc: 0.99966	valid's auc: 0.961832
# [180]	train's auc: 0.99967	valid's auc: 0.961794
# [181]	train's auc: 0.999681	valid's auc: 0.96179
# [182]	train's auc: 0.999691	valid's auc: 0.961776
# [183]	train's auc: 0.999704	valid's auc: 0.961885
# [184]	train's auc: 0.999708	valid's auc: 0.961828
# [185]	train's auc: 0.99972	valid's auc: 0.961808
# [186]	train's auc: 0.999728	valid's auc: 0.961828
# [187]	train's auc: 0.999737	valid's auc: 0.961765
# [188]	train's auc: 0.999745	valid's auc: 0.961762
# [189]	train's auc: 0.999749	valid's auc: 0.961793
# [190]	train's auc: 0.99976	valid's auc: 0.961758
# [191]	train's auc: 0.999765	valid's auc: 0.961756
# [192]	train's auc: 0.999774	valid's auc: 0.96174
# [193]	train's auc: 0.999783	valid's auc: 0.961747
# [194]	train's auc: 0.999789	valid's auc: 0.961763
# [195]	train's auc: 0.999795	valid's auc: 0.961686
# [196]	train's auc: 0.999798	valid's auc: 0.961736
# [197]	train's auc: 0.9998	valid's auc: 0.961742
# [198]	train's auc: 0.999805	valid's auc: 0.96173
# [199]	train's auc: 0.999815	valid's auc: 0.961775
# [200]	train's auc: 0.99982	valid's auc: 0.961777
# [201]	train's auc: 0.999822	valid's auc: 0.96173
# [202]	train's auc: 0.999823	valid's auc: 0.96172
# [203]	train's auc: 0.999828	valid's auc: 0.961721
# [204]	train's auc: 0.999829	valid's auc: 0.961695
# [205]	train's auc: 0.999833	valid's auc: 0.961752
# [206]	train's auc: 0.999839	valid's auc: 0.96179
# [207]	train's auc: 0.999843	valid's auc: 0.961764
# [208]	train's auc: 0.999846	valid's auc: 0.961785
# [209]	train's auc: 0.999853	valid's auc: 0.961786
# [210]	train's auc: 0.999859	valid's auc: 0.96177
# [211]	train's auc: 0.999861	valid's auc: 0.961757
# [212]	train's auc: 0.999863	valid's auc: 0.96177
# [213]	train's auc: 0.99987	valid's auc: 0.961749
# [214]	train's auc: 0.999873	valid's auc: 0.961739
# [215]	train's auc: 0.99988	valid's auc: 0.96175
# [216]	train's auc: 0.99988	valid's auc: 0.9617
# [217]	train's auc: 0.999885	valid's auc: 0.961668
# [218]	train's auc: 0.999886	valid's auc: 0.961706
# [219]	train's auc: 0.999891	valid's auc: 0.961711
# [220]	train's auc: 0.999892	valid's auc: 0.961687
# [221]	train's auc: 0.999897	valid's auc: 0.961741
# [222]	train's auc: 0.999901	valid's auc: 0.961777
# [223]	train's auc: 0.999904	valid's auc: 0.961778
# [224]	train's auc: 0.999906	valid's auc: 0.961772
# [225]	train's auc: 0.999908	valid's auc: 0.961758
# [226]	train's auc: 0.999912	valid's auc: 0.961764
# [227]	train's auc: 0.999915	valid's auc: 0.961741
# [228]	train's auc: 0.999918	valid's auc: 0.961712
# [229]	train's auc: 0.999919	valid's auc: 0.96166
# [230]	train's auc: 0.999922	valid's auc: 0.961666
# [231]	train's auc: 0.999923	valid's auc: 0.961675
# [232]	train's auc: 0.999927	valid's auc: 0.961721
# [233]	train's auc: 0.999929	valid's auc: 0.961689
# [234]	train's auc: 0.999931	valid's auc: 0.961712
# [235]	train's auc: 0.999934	valid's auc: 0.961759
# [236]	train's auc: 0.999934	valid's auc: 0.961766
# [237]	train's auc: 0.999935	valid's auc: 0.961787
# [238]	train's auc: 0.999936	valid's auc: 0.961772
# [239]	train's auc: 0.999939	valid's auc: 0.961755
# [240]	train's auc: 0.999942	valid's auc: 0.961778
# [241]	train's auc: 0.999943	valid's auc: 0.961789
# [242]	train's auc: 0.999944	valid's auc: 0.961814
# [243]	train's auc: 0.999946	valid's auc: 0.961816
# [244]	train's auc: 0.999947	valid's auc: 0.961785
# Early stopping, best iteration is:
# [144]	train's auc: 0.999059	valid's auc: 0.962092
# The 0 0 kfold score : 0.7177695511337344
# [1]	train's auc: 0.928979	valid's auc: 0.912809
# Training until validation scores don't improve for 100 rounds.
# [2]	train's auc: 0.939463	valid's auc: 0.926899
# [3]	train's auc: 0.943319	valid's auc: 0.932115
# [4]	train's auc: 0.951965	valid's auc: 0.9391
# [5]	train's auc: 0.955704	valid's auc: 0.942343
# [6]	train's auc: 0.957154	valid's auc: 0.943371
# [7]	train's auc: 0.958741	valid's auc: 0.944471
# [8]	train's auc: 0.959287	valid's auc: 0.945048
# [9]	train's auc: 0.961111	valid's auc: 0.946128
# [10]	train's auc: 0.962815	valid's auc: 0.947885
# [11]	train's auc: 0.963463	valid's auc: 0.948453
# [12]	train's auc: 0.964459	valid's auc: 0.949361
# [13]	train's auc: 0.965138	valid's auc: 0.949497
# [14]	train's auc: 0.966379	valid's auc: 0.950893
# [15]	train's auc: 0.966537	valid's auc: 0.950781
# [16]	train's auc: 0.967354	valid's auc: 0.951723
# [17]	train's auc: 0.968713	valid's auc: 0.953024
# [18]	train's auc: 0.969115	valid's auc: 0.953194
# [19]	train's auc: 0.969933	valid's auc: 0.953664
# [20]	train's auc: 0.970639	valid's auc: 0.953697
# [21]	train's auc: 0.971225	valid's auc: 0.953824
# [22]	train's auc: 0.972236	valid's auc: 0.954647
# [23]	train's auc: 0.973195	valid's auc: 0.955587
# [24]	train's auc: 0.973679	valid's auc: 0.955848
# [25]	train's auc: 0.974431	valid's auc: 0.956205
# [26]	train's auc: 0.975077	valid's auc: 0.956274
# [27]	train's auc: 0.975714	valid's auc: 0.956785
# [28]	train's auc: 0.976203	valid's auc: 0.957077
# [29]	train's auc: 0.976965	valid's auc: 0.957583
# [30]	train's auc: 0.977604	valid's auc: 0.958084
# [31]	train's auc: 0.977975	valid's auc: 0.958215
# [32]	train's auc: 0.97892	valid's auc: 0.958557
# [33]	train's auc: 0.979521	valid's auc: 0.958571
# [34]	train's auc: 0.979886	valid's auc: 0.958873
# [35]	train's auc: 0.980303	valid's auc: 0.958961
# [36]	train's auc: 0.980841	valid's auc: 0.959344
# [37]	train's auc: 0.98134	valid's auc: 0.959642
# [38]	train's auc: 0.981676	valid's auc: 0.95975
# [39]	train's auc: 0.982231	valid's auc: 0.96013
# [40]	train's auc: 0.982837	valid's auc: 0.960358
# [41]	train's auc: 0.983323	valid's auc: 0.960627
# [42]	train's auc: 0.98369	valid's auc: 0.960744
# [43]	train's auc: 0.984269	valid's auc: 0.961153
# [44]	train's auc: 0.984608	valid's auc: 0.961516
# [45]	train's auc: 0.985107	valid's auc: 0.961664
# [46]	train's auc: 0.985512	valid's auc: 0.961984
# [47]	train's auc: 0.98583	valid's auc: 0.962051
# [48]	train's auc: 0.986283	valid's auc: 0.962155
# [49]	train's auc: 0.986814	valid's auc: 0.962475
# [50]	train's auc: 0.987232	valid's auc: 0.962636
# [51]	train's auc: 0.987771	valid's auc: 0.962639
# [52]	train's auc: 0.98809	valid's auc: 0.96276
# [53]	train's auc: 0.988358	valid's auc: 0.962804
# [54]	train's auc: 0.98868	valid's auc: 0.962975
# [55]	train's auc: 0.988906	valid's auc: 0.963164
# [56]	train's auc: 0.989169	valid's auc: 0.963356
# [57]	train's auc: 0.989504	valid's auc: 0.96344
# [58]	train's auc: 0.989854	valid's auc: 0.963493
# [59]	train's auc: 0.990167	valid's auc: 0.963471
# [60]	train's auc: 0.990464	valid's auc: 0.963572
# [61]	train's auc: 0.990784	valid's auc: 0.96378
# [62]	train's auc: 0.991025	valid's auc: 0.963928
# [63]	train's auc: 0.991308	valid's auc: 0.96401
# [64]	train's auc: 0.991516	valid's auc: 0.964004
# [65]	train's auc: 0.991828	valid's auc: 0.964064
# [66]	train's auc: 0.992047	valid's auc: 0.964136
# [67]	train's auc: 0.992199	valid's auc: 0.964341
# [68]	train's auc: 0.992395	valid's auc: 0.964399
# [69]	train's auc: 0.99258	valid's auc: 0.964441
# [70]	train's auc: 0.992821	valid's auc: 0.964429
# [71]	train's auc: 0.993107	valid's auc: 0.964433
# [72]	train's auc: 0.993279	valid's auc: 0.964488
# [73]	train's auc: 0.993462	valid's auc: 0.964523
# [74]	train's auc: 0.993723	valid's auc: 0.96466
# [75]	train's auc: 0.993921	valid's auc: 0.964761
# [76]	train's auc: 0.994086	valid's auc: 0.964883
# [77]	train's auc: 0.99424	valid's auc: 0.964969
# [78]	train's auc: 0.99438	valid's auc: 0.965085
# [79]	train's auc: 0.994525	valid's auc: 0.965202
# [80]	train's auc: 0.994716	valid's auc: 0.965198
# [81]	train's auc: 0.99485	valid's auc: 0.965271
# [82]	train's auc: 0.994973	valid's auc: 0.965284
# [83]	train's auc: 0.995173	valid's auc: 0.965289
# [84]	train's auc: 0.995296	valid's auc: 0.965242
# [85]	train's auc: 0.995462	valid's auc: 0.965288
# [86]	train's auc: 0.995638	valid's auc: 0.965313
# [87]	train's auc: 0.995762	valid's auc: 0.965291
# [88]	train's auc: 0.995887	valid's auc: 0.965292
# [89]	train's auc: 0.996013	valid's auc: 0.965284
# [90]	train's auc: 0.996121	valid's auc: 0.965307
# [91]	train's auc: 0.996251	valid's auc: 0.96525
# [92]	train's auc: 0.996351	valid's auc: 0.965279
# [93]	train's auc: 0.996415	valid's auc: 0.965315
# [94]	train's auc: 0.996521	valid's auc: 0.965398
# [95]	train's auc: 0.996626	valid's auc: 0.965473
# [96]	train's auc: 0.996724	valid's auc: 0.965413
# [97]	train's auc: 0.996878	valid's auc: 0.965375
# [98]	train's auc: 0.996965	valid's auc: 0.965337
# [99]	train's auc: 0.997038	valid's auc: 0.965405
# [100]	train's auc: 0.997141	valid's auc: 0.965352
# [101]	train's auc: 0.997251	valid's auc: 0.965353
# [102]	train's auc: 0.997349	valid's auc: 0.965331
# [103]	train's auc: 0.997426	valid's auc: 0.965397
# [104]	train's auc: 0.997515	valid's auc: 0.965402
# [105]	train's auc: 0.997608	valid's auc: 0.965527
# [106]	train's auc: 0.997694	valid's auc: 0.965509
# [107]	train's auc: 0.997789	valid's auc: 0.965471
# [108]	train's auc: 0.997882	valid's auc: 0.965593
# [109]	train's auc: 0.997927	valid's auc: 0.965498
# [110]	train's auc: 0.998003	valid's auc: 0.965649
# [111]	train's auc: 0.99807	valid's auc: 0.965728
# [112]	train's auc: 0.998124	valid's auc: 0.96574
# [113]	train's auc: 0.998176	valid's auc: 0.965738
# [114]	train's auc: 0.998218	valid's auc: 0.965782
# [115]	train's auc: 0.998284	valid's auc: 0.965772
# [116]	train's auc: 0.998344	valid's auc: 0.96578
# [117]	train's auc: 0.998399	valid's auc: 0.965788
# [118]	train's auc: 0.998453	valid's auc: 0.965861
# [119]	train's auc: 0.998489	valid's auc: 0.965882
# [120]	train's auc: 0.998529	valid's auc: 0.965913
# [121]	train's auc: 0.998573	valid's auc: 0.965928
# [122]	train's auc: 0.998613	valid's auc: 0.965912
# [123]	train's auc: 0.998656	valid's auc: 0.965904
# [124]	train's auc: 0.998709	valid's auc: 0.96593
# [125]	train's auc: 0.998735	valid's auc: 0.965967
# [126]	train's auc: 0.998762	valid's auc: 0.96605
# [127]	train's auc: 0.998802	valid's auc: 0.966089
# [128]	train's auc: 0.998843	valid's auc: 0.966088
# [129]	train's auc: 0.998878	valid's auc: 0.966187
# [130]	train's auc: 0.998916	valid's auc: 0.966138
# [131]	train's auc: 0.998954	valid's auc: 0.966113
# [132]	train's auc: 0.998992	valid's auc: 0.966188
# [133]	train's auc: 0.999036	valid's auc: 0.966186
# [134]	train's auc: 0.999077	valid's auc: 0.966203
# [135]	train's auc: 0.999115	valid's auc: 0.96621
# [136]	train's auc: 0.999135	valid's auc: 0.966217
# [137]	train's auc: 0.999156	valid's auc: 0.96606
# [138]	train's auc: 0.99919	valid's auc: 0.966064
# [139]	train's auc: 0.999213	valid's auc: 0.966158
# [140]	train's auc: 0.999237	valid's auc: 0.966126
# [141]	train's auc: 0.999254	valid's auc: 0.966074
# [142]	train's auc: 0.999271	valid's auc: 0.966129
# [143]	train's auc: 0.999288	valid's auc: 0.96611
# [144]	train's auc: 0.999304	valid's auc: 0.966114
# [145]	train's auc: 0.999334	valid's auc: 0.966023
# [146]	train's auc: 0.999351	valid's auc: 0.966124
# [147]	train's auc: 0.999365	valid's auc: 0.966159
# [148]	train's auc: 0.999386	valid's auc: 0.966114
# [149]	train's auc: 0.999411	valid's auc: 0.966151
# [150]	train's auc: 0.999434	valid's auc: 0.966072
# [151]	train's auc: 0.99945	valid's auc: 0.966083
# [152]	train's auc: 0.999461	valid's auc: 0.9661
# [153]	train's auc: 0.999479	valid's auc: 0.96611
# [154]	train's auc: 0.999491	valid's auc: 0.966118
# [155]	train's auc: 0.999498	valid's auc: 0.966156
# [156]	train's auc: 0.999509	valid's auc: 0.966217
# [157]	train's auc: 0.999522	valid's auc: 0.966257
# [158]	train's auc: 0.999535	valid's auc: 0.966239
# [159]	train's auc: 0.999559	valid's auc: 0.966221
# [160]	train's auc: 0.999575	valid's auc: 0.96623
# [161]	train's auc: 0.999591	valid's auc: 0.966165
# [162]	train's auc: 0.999609	valid's auc: 0.96618
# [163]	train's auc: 0.999619	valid's auc: 0.966169
# [164]	train's auc: 0.99963	valid's auc: 0.966194
# [165]	train's auc: 0.99964	valid's auc: 0.966173
# [166]	train's auc: 0.999647	valid's auc: 0.966178
# [167]	train's auc: 0.999657	valid's auc: 0.966216
# [168]	train's auc: 0.999671	valid's auc: 0.966197
# [169]	train's auc: 0.999683	valid's auc: 0.966202
# [170]	train's auc: 0.99969	valid's auc: 0.966224
# [171]	train's auc: 0.999702	valid's auc: 0.966203
# [172]	train's auc: 0.999711	valid's auc: 0.966232
# [173]	train's auc: 0.99972	valid's auc: 0.966244
# [174]	train's auc: 0.999729	valid's auc: 0.966201
# [175]	train's auc: 0.999736	valid's auc: 0.966183
# [176]	train's auc: 0.999743	valid's auc: 0.966203
# [177]	train's auc: 0.999751	valid's auc: 0.966193
# [178]	train's auc: 0.99976	valid's auc: 0.966113
# [179]	train's auc: 0.999765	valid's auc: 0.96616
# [180]	train's auc: 0.999771	valid's auc: 0.966128
# [181]	train's auc: 0.999776	valid's auc: 0.966114
# [182]	train's auc: 0.999782	valid's auc: 0.966193
# [183]	train's auc: 0.999789	valid's auc: 0.966243
# [184]	train's auc: 0.999797	valid's auc: 0.966224
# [185]	train's auc: 0.999801	valid's auc: 0.966155
# [186]	train's auc: 0.999806	valid's auc: 0.966202
# [187]	train's auc: 0.999814	valid's auc: 0.966195
# [188]	train's auc: 0.999817	valid's auc: 0.966209
# [189]	train's auc: 0.999823	valid's auc: 0.966199
# [190]	train's auc: 0.99983	valid's auc: 0.966205
# [191]	train's auc: 0.999834	valid's auc: 0.96622
# [192]	train's auc: 0.999836	valid's auc: 0.966247
# [193]	train's auc: 0.999843	valid's auc: 0.966174
# [194]	train's auc: 0.999845	valid's auc: 0.96619
# [195]	train's auc: 0.999849	valid's auc: 0.966152
# [196]	train's auc: 0.999854	valid's auc: 0.966201
# [197]	train's auc: 0.99986	valid's auc: 0.966271
# [198]	train's auc: 0.999863	valid's auc: 0.966284
# [199]	train's auc: 0.999866	valid's auc: 0.96626
# [200]	train's auc: 0.999871	valid's auc: 0.96628
# [201]	train's auc: 0.999874	valid's auc: 0.966237
# [202]	train's auc: 0.999877	valid's auc: 0.966167
# [203]	train's auc: 0.999881	valid's auc: 0.966162
# [204]	train's auc: 0.999882	valid's auc: 0.966141
# [205]	train's auc: 0.999887	valid's auc: 0.966177
# [206]	train's auc: 0.999888	valid's auc: 0.966164
# [207]	train's auc: 0.999891	valid's auc: 0.966214
# [208]	train's auc: 0.999892	valid's auc: 0.966211
# [209]	train's auc: 0.999895	valid's auc: 0.966177
# [210]	train's auc: 0.999897	valid's auc: 0.966154
# [211]	train's auc: 0.9999	valid's auc: 0.966159
# [212]	train's auc: 0.999902	valid's auc: 0.966176
# [213]	train's auc: 0.999903	valid's auc: 0.966177
# [214]	train's auc: 0.999904	valid's auc: 0.966183
# [215]	train's auc: 0.999906	valid's auc: 0.966185
# [216]	train's auc: 0.999909	valid's auc: 0.966166
# [217]	train's auc: 0.999911	valid's auc: 0.966144
# [218]	train's auc: 0.999915	valid's auc: 0.966132
# [219]	train's auc: 0.999916	valid's auc: 0.966153
# [220]	train's auc: 0.999918	valid's auc: 0.966154
# [221]	train's auc: 0.999919	valid's auc: 0.966161
# [222]	train's auc: 0.999921	valid's auc: 0.966159
# [223]	train's auc: 0.999922	valid's auc: 0.966156
# [224]	train's auc: 0.999924	valid's auc: 0.966245
# [225]	train's auc: 0.999926	valid's auc: 0.966199
# [226]	train's auc: 0.999929	valid's auc: 0.966205
# [227]	train's auc: 0.999932	valid's auc: 0.966166
# [228]	train's auc: 0.999933	valid's auc: 0.966194
# [229]	train's auc: 0.999934	valid's auc: 0.966208
# [230]	train's auc: 0.999936	valid's auc: 0.966173
# [231]	train's auc: 0.999937	valid's auc: 0.966186
# [232]	train's auc: 0.999937	valid's auc: 0.966165
# [233]	train's auc: 0.999937	valid's auc: 0.96615
# [234]	train's auc: 0.99994	valid's auc: 0.966116
# [235]	train's auc: 0.999943	valid's auc: 0.966142
# [236]	train's auc: 0.999945	valid's auc: 0.966135
# [237]	train's auc: 0.999945	valid's auc: 0.966163
# [238]	train's auc: 0.999946	valid's auc: 0.966149
# [239]	train's auc: 0.999948	valid's auc: 0.966168
# [240]	train's auc: 0.999949	valid's auc: 0.966161
# [241]	train's auc: 0.99995	valid's auc: 0.966197
# [242]	train's auc: 0.999951	valid's auc: 0.966161
# [243]	train's auc: 0.999952	valid's auc: 0.966123
# [244]	train's auc: 0.999952	valid's auc: 0.966108
# [245]	train's auc: 0.999953	valid's auc: 0.966166
# [246]	train's auc: 0.999954	valid's auc: 0.96619
# [247]	train's auc: 0.999955	valid's auc: 0.966179
# [248]	train's auc: 0.999956	valid's auc: 0.966185
# [249]	train's auc: 0.999957	valid's auc: 0.966203
# [250]	train's auc: 0.999957	valid's auc: 0.96619
# [251]	train's auc: 0.999959	valid's auc: 0.966147
# [252]	train's auc: 0.99996	valid's auc: 0.966212
# [253]	train's auc: 0.999961	valid's auc: 0.966169
# [254]	train's auc: 0.999962	valid's auc: 0.96615
# [255]	train's auc: 0.999962	valid's auc: 0.96616
# [256]	train's auc: 0.999962	valid's auc: 0.966153
# [257]	train's auc: 0.999963	valid's auc: 0.96617
# [258]	train's auc: 0.999964	valid's auc: 0.96615
# [259]	train's auc: 0.999965	valid's auc: 0.966187
# [260]	train's auc: 0.999965	valid's auc: 0.966195
# [261]	train's auc: 0.999965	valid's auc: 0.966196
# [262]	train's auc: 0.999966	valid's auc: 0.96619
# [263]	train's auc: 0.999967	valid's auc: 0.966205
# [264]	train's auc: 0.999967	valid's auc: 0.966176
# [265]	train's auc: 0.999968	valid's auc: 0.966233
# [266]	train's auc: 0.999969	valid's auc: 0.966196
# [267]	train's auc: 0.999969	valid's auc: 0.9662
# [268]	train's auc: 0.999969	valid's auc: 0.966159
# [269]	train's auc: 0.999969	valid's auc: 0.966217
# [270]	train's auc: 0.999971	valid's auc: 0.966234
# [271]	train's auc: 0.999971	valid's auc: 0.966222
# [272]	train's auc: 0.999972	valid's auc: 0.966199
# [273]	train's auc: 0.999973	valid's auc: 0.966247
# [274]	train's auc: 0.999975	valid's auc: 0.966288
# [275]	train's auc: 0.999977	valid's auc: 0.966313
# [276]	train's auc: 0.999977	valid's auc: 0.96633
# [277]	train's auc: 0.999977	valid's auc: 0.966368
# [278]	train's auc: 0.999978	valid's auc: 0.966331
# [279]	train's auc: 0.999978	valid's auc: 0.966357
# [280]	train's auc: 0.999979	valid's auc: 0.966295
# [281]	train's auc: 0.999979	valid's auc: 0.96634
# [282]	train's auc: 0.999979	valid's auc: 0.96632
# [283]	train's auc: 0.99998	valid's auc: 0.966304
# [284]	train's auc: 0.99998	valid's auc: 0.966252
# [285]	train's auc: 0.999981	valid's auc: 0.966247
# [286]	train's auc: 0.999981	valid's auc: 0.966241
# [287]	train's auc: 0.999983	valid's auc: 0.966293
# [288]	train's auc: 0.999984	valid's auc: 0.9663
# [289]	train's auc: 0.999984	valid's auc: 0.966326
# [290]	train's auc: 0.999984	valid's auc: 0.966321
# [291]	train's auc: 0.999985	valid's auc: 0.966342
# [292]	train's auc: 0.999985	valid's auc: 0.966386
# [293]	train's auc: 0.999985	valid's auc: 0.966343
# [294]	train's auc: 0.999985	valid's auc: 0.966341
# [295]	train's auc: 0.999986	valid's auc: 0.966336
# [296]	train's auc: 0.999986	valid's auc: 0.966338
# [297]	train's auc: 0.999986	valid's auc: 0.966352
# [298]	train's auc: 0.999986	valid's auc: 0.966361
# [299]	train's auc: 0.999987	valid's auc: 0.966353
# [300]	train's auc: 0.999987	valid's auc: 0.96636
# [301]	train's auc: 0.999988	valid's auc: 0.966348
# [302]	train's auc: 0.999988	valid's auc: 0.966338
# [303]	train's auc: 0.999988	valid's auc: 0.966312
# [304]	train's auc: 0.999989	valid's auc: 0.966297
# [305]	train's auc: 0.999989	valid's auc: 0.966339
# [306]	train's auc: 0.999989	valid's auc: 0.966363
# [307]	train's auc: 0.99999	valid's auc: 0.96635
# [308]	train's auc: 0.99999	valid's auc: 0.966374
# [309]	train's auc: 0.99999	valid's auc: 0.966339
# [310]	train's auc: 0.99999	valid's auc: 0.9663
# [311]	train's auc: 0.999991	valid's auc: 0.966253
# [312]	train's auc: 0.999991	valid's auc: 0.96624
# [313]	train's auc: 0.999992	valid's auc: 0.966258
# [314]	train's auc: 0.999991	valid's auc: 0.966258
# [315]	train's auc: 0.999991	valid's auc: 0.966289
# [316]	train's auc: 0.999992	valid's auc: 0.966272
# [317]	train's auc: 0.999992	valid's auc: 0.966289
# [318]	train's auc: 0.999992	valid's auc: 0.966278
# [319]	train's auc: 0.999992	valid's auc: 0.966279
# [320]	train's auc: 0.999992	valid's auc: 0.966262
# [321]	train's auc: 0.999992	valid's auc: 0.966269
# [322]	train's auc: 0.999992	valid's auc: 0.966256
# [323]	train's auc: 0.999992	valid's auc: 0.966284
# [324]	train's auc: 0.999992	valid's auc: 0.96632
# [325]	train's auc: 0.999992	valid's auc: 0.966336
# [326]	train's auc: 0.999992	valid's auc: 0.96634
# [327]	train's auc: 0.999992	valid's auc: 0.966388
# [328]	train's auc: 0.999992	valid's auc: 0.966374
# [329]	train's auc: 0.999993	valid's auc: 0.966434
# [330]	train's auc: 0.999993	valid's auc: 0.966433
# [331]	train's auc: 0.999993	valid's auc: 0.9664
# [332]	train's auc: 0.999993	valid's auc: 0.966412
# [333]	train's auc: 0.999993	valid's auc: 0.966371
# [334]	train's auc: 0.999993	valid's auc: 0.966323
# [335]	train's auc: 0.999993	valid's auc: 0.966332
# [336]	train's auc: 0.999993	valid's auc: 0.966307
# [337]	train's auc: 0.999993	valid's auc: 0.966304
# [338]	train's auc: 0.999993	valid's auc: 0.966294
# [339]	train's auc: 0.999993	valid's auc: 0.966315
# [340]	train's auc: 0.999993	valid's auc: 0.96632
# [341]	train's auc: 0.999994	valid's auc: 0.966287
# [342]	train's auc: 0.999994	valid's auc: 0.966304
# [343]	train's auc: 0.999994	valid's auc: 0.966334
# [344]	train's auc: 0.999994	valid's auc: 0.966334
# [345]	train's auc: 0.999994	valid's auc: 0.966349
# [346]	train's auc: 0.999994	valid's auc: 0.966371
# [347]	train's auc: 0.999994	valid's auc: 0.966369
# [348]	train's auc: 0.999994	valid's auc: 0.966388
# [349]	train's auc: 0.999995	valid's auc: 0.966359
# [350]	train's auc: 0.999995	valid's auc: 0.966358
# [351]	train's auc: 0.999995	valid's auc: 0.966321
# [352]	train's auc: 0.999995	valid's auc: 0.966328
# [353]	train's auc: 0.999995	valid's auc: 0.966343
# [354]	train's auc: 0.999995	valid's auc: 0.966369
# [355]	train's auc: 0.999995	valid's auc: 0.966352
# [356]	train's auc: 0.999995	valid's auc: 0.966325
# [357]	train's auc: 0.999995	valid's auc: 0.966328
# [358]	train's auc: 0.999996	valid's auc: 0.966301
# [359]	train's auc: 0.999996	valid's auc: 0.966288
# [360]	train's auc: 0.999996	valid's auc: 0.966288
# [361]	train's auc: 0.999996	valid's auc: 0.966301
# [362]	train's auc: 0.999996	valid's auc: 0.966281
# [363]	train's auc: 0.999996	valid's auc: 0.9663
# [364]	train's auc: 0.999996	valid's auc: 0.966336
# [365]	train's auc: 0.999996	valid's auc: 0.966368
# [366]	train's auc: 0.999996	valid's auc: 0.966349
# [367]	train's auc: 0.999996	valid's auc: 0.966334
# [368]	train's auc: 0.999996	valid's auc: 0.966337
# [369]	train's auc: 0.999996	valid's auc: 0.966334
# [370]	train's auc: 0.999996	valid's auc: 0.966356
# [371]	train's auc: 0.999997	valid's auc: 0.96632
# [372]	train's auc: 0.999997	valid's auc: 0.966304
# [373]	train's auc: 0.999997	valid's auc: 0.966322
# [374]	train's auc: 0.999997	valid's auc: 0.966336
# [375]	train's auc: 0.999997	valid's auc: 0.966333
# [376]	train's auc: 0.999997	valid's auc: 0.966341
# [377]	train's auc: 0.999997	valid's auc: 0.966315
# [378]	train's auc: 0.999998	valid's auc: 0.966329
# [379]	train's auc: 0.999998	valid's auc: 0.96632
# [380]	train's auc: 0.999998	valid's auc: 0.966325
# [381]	train's auc: 0.999998	valid's auc: 0.966339
# [382]	train's auc: 0.999998	valid's auc: 0.966334
# [383]	train's auc: 0.999998	valid's auc: 0.966355
# [384]	train's auc: 0.999998	valid's auc: 0.966345
# [385]	train's auc: 0.999998	valid's auc: 0.966408
# [386]	train's auc: 0.999998	valid's auc: 0.966391
# [387]	train's auc: 0.999998	valid's auc: 0.966377
# [388]	train's auc: 0.999998	valid's auc: 0.966351
# [389]	train's auc: 0.999998	valid's auc: 0.966371
# [390]	train's auc: 0.999998	valid's auc: 0.966341
# [391]	train's auc: 0.999998	valid's auc: 0.966353
# [392]	train's auc: 0.999998	valid's auc: 0.966316
# [393]	train's auc: 0.999998	valid's auc: 0.966314
# [394]	train's auc: 0.999998	valid's auc: 0.966297
# [395]	train's auc: 0.999998	valid's auc: 0.966315
# [396]	train's auc: 0.999998	valid's auc: 0.966302
# [397]	train's auc: 0.999998	valid's auc: 0.966258
# [398]	train's auc: 0.999999	valid's auc: 0.966253
# [399]	train's auc: 0.999999	valid's auc: 0.966279
# [400]	train's auc: 0.999999	valid's auc: 0.966278
# [401]	train's auc: 0.999999	valid's auc: 0.966276
# [402]	train's auc: 0.999999	valid's auc: 0.966275
# [403]	train's auc: 0.999999	valid's auc: 0.966296
# [404]	train's auc: 0.999999	valid's auc: 0.96628
# [405]	train's auc: 0.999999	valid's auc: 0.966276
# [406]	train's auc: 0.999999	valid's auc: 0.966273
# [407]	train's auc: 0.999999	valid's auc: 0.9663
# [408]	train's auc: 0.999999	valid's auc: 0.966285
# [409]	train's auc: 0.999999	valid's auc: 0.966295
# [410]	train's auc: 0.999999	valid's auc: 0.966306
# [411]	train's auc: 0.999999	valid's auc: 0.966282
# [412]	train's auc: 0.999999	valid's auc: 0.966301
# [413]	train's auc: 0.999999	valid's auc: 0.966281
# [414]	train's auc: 0.999999	valid's auc: 0.96628
# [415]	train's auc: 0.999999	valid's auc: 0.966306
# [416]	train's auc: 0.999999	valid's auc: 0.966306
# [417]	train's auc: 0.999999	valid's auc: 0.966295
# [418]	train's auc: 0.999999	valid's auc: 0.966272
# [419]	train's auc: 0.999999	valid's auc: 0.966276
# [420]	train's auc: 0.999999	valid's auc: 0.966269
# [421]	train's auc: 0.999999	valid's auc: 0.966223
# [422]	train's auc: 0.999999	valid's auc: 0.966241
# [423]	train's auc: 0.999999	valid's auc: 0.966235
# [424]	train's auc: 0.999999	valid's auc: 0.966221
# [425]	train's auc: 0.999999	valid's auc: 0.966211
# [426]	train's auc: 0.999999	valid's auc: 0.966215
# [427]	train's auc: 0.999999	valid's auc: 0.966217
# [428]	train's auc: 0.999999	valid's auc: 0.966251
# [429]	train's auc: 0.999999	valid's auc: 0.966236
# Early stopping, best iteration is:
# [329]	train's auc: 0.999993	valid's auc: 0.966434
# The 0 1 kfold score : 0.7284839924670433
# ==============================
# start getting operation features....
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:9: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:14: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:24: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:28: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:30: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:49: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:50: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:60: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# finish getting operation features....
# ==============================
# start getting transaction features....
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:12: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:17: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:27: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:31: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:33: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:45: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:68: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:69: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:74: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# finish getting transaction features....
# ==============================
# start getting ctr features....
# ...
# [196]	train's auc: 0.999874	valid's auc: 0.963011
# [197]	train's auc: 0.999876	valid's auc: 0.962996
# [198]	train's auc: 0.999878	valid's auc: 0.962964
# [199]	train's auc: 0.999884	valid's auc: 0.962962
# [200]	train's auc: 0.999888	valid's auc: 0.962936
# [201]	train's auc: 0.999893	valid's auc: 0.96295
# [202]	train's auc: 0.999895	valid's auc: 0.962889
# [203]	train's auc: 0.999898	valid's auc: 0.96286
# [204]	train's auc: 0.999901	valid's auc: 0.962782
# [205]	train's auc: 0.999904	valid's auc: 0.962745
# [206]	train's auc: 0.999907	valid's auc: 0.962777
# [207]	train's auc: 0.999911	valid's auc: 0.962782
# [208]	train's auc: 0.999917	valid's auc: 0.962761
# [209]	train's auc: 0.999919	valid's auc: 0.962725
# [210]	train's auc: 0.999921	valid's auc: 0.962703
# [211]	train's auc: 0.999923	valid's auc: 0.962665
# [212]	train's auc: 0.999926	valid's auc: 0.962671
# [213]	train's auc: 0.999928	valid's auc: 0.962672
# [214]	train's auc: 0.999932	valid's auc: 0.962676
# [215]	train's auc: 0.999933	valid's auc: 0.962649
# [216]	train's auc: 0.999936	valid's auc: 0.962649
# [217]	train's auc: 0.99994	valid's auc: 0.962612
# [218]	train's auc: 0.999942	valid's auc: 0.962604
# [219]	train's auc: 0.999944	valid's auc: 0.962633
# [220]	train's auc: 0.999946	valid's auc: 0.962654
# [221]	train's auc: 0.999947	valid's auc: 0.962623
# [222]	train's auc: 0.999948	valid's auc: 0.962592
# [223]	train's auc: 0.999949	valid's auc: 0.962572
# [224]	train's auc: 0.999951	valid's auc: 0.962531
# [225]	train's auc: 0.999951	valid's auc: 0.96258
# [226]	train's auc: 0.999954	valid's auc: 0.962566
# [227]	train's auc: 0.999955	valid's auc: 0.962599
# [228]	train's auc: 0.999956	valid's auc: 0.962639
# Early stopping, best iteration is:
# [128]	train's auc: 0.998821	valid's auc: 0.963571
# The 1 0 kfold score : 0.7156807511737089
# [1]	train's auc: 0.928172	valid's auc: 0.916353
# Training until validation scores don't improve for 100 rounds.
# [2]	train's auc: 0.945991	valid's auc: 0.931777
# [3]	train's auc: 0.948447	valid's auc: 0.933656
# [4]	train's auc: 0.953023	valid's auc: 0.940655
# [5]	train's auc: 0.95448	valid's auc: 0.941327
# [6]	train's auc: 0.956338	valid's auc: 0.942978
# [7]	train's auc: 0.956621	valid's auc: 0.943471
# [8]	train's auc: 0.95871	valid's auc: 0.944122
# [9]	train's auc: 0.960924	valid's auc: 0.945538
# [10]	train's auc: 0.961388	valid's auc: 0.946109
# [11]	train's auc: 0.962073	valid's auc: 0.946407
# [12]	train's auc: 0.963245	valid's auc: 0.947006
# [13]	train's auc: 0.964962	valid's auc: 0.94861
# [14]	train's auc: 0.966411	valid's auc: 0.949171
# [15]	train's auc: 0.967554	valid's auc: 0.949902
# [16]	train's auc: 0.968673	valid's auc: 0.950847
# [17]	train's auc: 0.969556	valid's auc: 0.951474
# [18]	train's auc: 0.970449	valid's auc: 0.951888
# [19]	train's auc: 0.97145	valid's auc: 0.952295
# [20]	train's auc: 0.972127	valid's auc: 0.952732
# [21]	train's auc: 0.972799	valid's auc: 0.953039
# [22]	train's auc: 0.973558	valid's auc: 0.953939
# [23]	train's auc: 0.974811	valid's auc: 0.954506
# [24]	train's auc: 0.975573	valid's auc: 0.955058
# [25]	train's auc: 0.97644	valid's auc: 0.955052
# [26]	train's auc: 0.977266	valid's auc: 0.955072
# [27]	train's auc: 0.977956	valid's auc: 0.955604
# [28]	train's auc: 0.978848	valid's auc: 0.956051
# [29]	train's auc: 0.979526	valid's auc: 0.956485
# [30]	train's auc: 0.980173	valid's auc: 0.956685
# [31]	train's auc: 0.98086	valid's auc: 0.956844
# [32]	train's auc: 0.981429	valid's auc: 0.957006
# [33]	train's auc: 0.981813	valid's auc: 0.957304
# [34]	train's auc: 0.982427	valid's auc: 0.957678
# [35]	train's auc: 0.982877	valid's auc: 0.95787
# [36]	train's auc: 0.98339	valid's auc: 0.958142
# [37]	train's auc: 0.98382	valid's auc: 0.958145
# [38]	train's auc: 0.984317	valid's auc: 0.958441
# [39]	train's auc: 0.984735	valid's auc: 0.958644
# [40]	train's auc: 0.985144	valid's auc: 0.958821
# [41]	train's auc: 0.985468	valid's auc: 0.958903
# [42]	train's auc: 0.985983	valid's auc: 0.958929
# [43]	train's auc: 0.986431	valid's auc: 0.959047
# [44]	train's auc: 0.986754	valid's auc: 0.959191
# [45]	train's auc: 0.987169	valid's auc: 0.959326
# [46]	train's auc: 0.987502	valid's auc: 0.959388
# [47]	train's auc: 0.987873	valid's auc: 0.959479
# [48]	train's auc: 0.988221	valid's auc: 0.959624
# [49]	train's auc: 0.988494	valid's auc: 0.959731
# [50]	train's auc: 0.988754	valid's auc: 0.959907
# [51]	train's auc: 0.989063	valid's auc: 0.960153
# [52]	train's auc: 0.989321	valid's auc: 0.960118
# [53]	train's auc: 0.989621	valid's auc: 0.960058
# [54]	train's auc: 0.98999	valid's auc: 0.960162
# [55]	train's auc: 0.990279	valid's auc: 0.960335
# [56]	train's auc: 0.990569	valid's auc: 0.960564
# [57]	train's auc: 0.990835	valid's auc: 0.960725
# [58]	train's auc: 0.991125	valid's auc: 0.960938
# [59]	train's auc: 0.991377	valid's auc: 0.960927
# [60]	train's auc: 0.991682	valid's auc: 0.961063
# [61]	train's auc: 0.991913	valid's auc: 0.961021
# [62]	train's auc: 0.992159	valid's auc: 0.961098
# [63]	train's auc: 0.992412	valid's auc: 0.961141
# [64]	train's auc: 0.992643	valid's auc: 0.961065
# [65]	train's auc: 0.992886	valid's auc: 0.961149
# [66]	train's auc: 0.993016	valid's auc: 0.961093
# [67]	train's auc: 0.993237	valid's auc: 0.961263
# [68]	train's auc: 0.993384	valid's auc: 0.961291
# [69]	train's auc: 0.993539	valid's auc: 0.961401
# [70]	train's auc: 0.993704	valid's auc: 0.961588
# [71]	train's auc: 0.993868	valid's auc: 0.961697
# [72]	train's auc: 0.99402	valid's auc: 0.961717
# [73]	train's auc: 0.994241	valid's auc: 0.961639
# [74]	train's auc: 0.994546	valid's auc: 0.96174
# [75]	train's auc: 0.994675	valid's auc: 0.961825
# [76]	train's auc: 0.994831	valid's auc: 0.961834
# [77]	train's auc: 0.994929	valid's auc: 0.961955
# [78]	train's auc: 0.995084	valid's auc: 0.962016
# [79]	train's auc: 0.99526	valid's auc: 0.962029
# [80]	train's auc: 0.995392	valid's auc: 0.962061
# [81]	train's auc: 0.995517	valid's auc: 0.962188
# [82]	train's auc: 0.995642	valid's auc: 0.962274
# [83]	train's auc: 0.995798	valid's auc: 0.962312
# [84]	train's auc: 0.995921	valid's auc: 0.962435
# [85]	train's auc: 0.996009	valid's auc: 0.962467
# [86]	train's auc: 0.99612	valid's auc: 0.962451
# [87]	train's auc: 0.996228	valid's auc: 0.962583
# [88]	train's auc: 0.996324	valid's auc: 0.962634
# [89]	train's auc: 0.996417	valid's auc: 0.962698
# [90]	train's auc: 0.996587	valid's auc: 0.96278
# [91]	train's auc: 0.996659	valid's auc: 0.962728
# [92]	train's auc: 0.996786	valid's auc: 0.962746
# [93]	train's auc: 0.996884	valid's auc: 0.962712
# [94]	train's auc: 0.996968	valid's auc: 0.962769
# [95]	train's auc: 0.997065	valid's auc: 0.962782
# [96]	train's auc: 0.997138	valid's auc: 0.962728
# [97]	train's auc: 0.997246	valid's auc: 0.962748
# [98]	train's auc: 0.997318	valid's auc: 0.962777
# [99]	train's auc: 0.997391	valid's auc: 0.962761
# [100]	train's auc: 0.99745	valid's auc: 0.962826
# [101]	train's auc: 0.997531	valid's auc: 0.962845
# [102]	train's auc: 0.997608	valid's auc: 0.962873
# [103]	train's auc: 0.997691	valid's auc: 0.962831
# [104]	train's auc: 0.997764	valid's auc: 0.962839
# [105]	train's auc: 0.997845	valid's auc: 0.962828
# [106]	train's auc: 0.997918	valid's auc: 0.962806
# [107]	train's auc: 0.997976	valid's auc: 0.962761
# [108]	train's auc: 0.998025	valid's auc: 0.962744
# [109]	train's auc: 0.998106	valid's auc: 0.962782
# [110]	train's auc: 0.998155	valid's auc: 0.962793
# [111]	train's auc: 0.998206	valid's auc: 0.962818
# [112]	train's auc: 0.998259	valid's auc: 0.962888
# [113]	train's auc: 0.998326	valid's auc: 0.962851
# [114]	train's auc: 0.998371	valid's auc: 0.962897
# [115]	train's auc: 0.998428	valid's auc: 0.962931
# [116]	train's auc: 0.998489	valid's auc: 0.962902
# [117]	train's auc: 0.998532	valid's auc: 0.962869
# [118]	train's auc: 0.99857	valid's auc: 0.962786
# [119]	train's auc: 0.998617	valid's auc: 0.962792
# [120]	train's auc: 0.998653	valid's auc: 0.962821
# [121]	train's auc: 0.998684	valid's auc: 0.962854
# [122]	train's auc: 0.998717	valid's auc: 0.962909
# [123]	train's auc: 0.99875	valid's auc: 0.962917
# [124]	train's auc: 0.998785	valid's auc: 0.96288
# [125]	train's auc: 0.998822	valid's auc: 0.962801
# [126]	train's auc: 0.998856	valid's auc: 0.962882
# [127]	train's auc: 0.998893	valid's auc: 0.963004
# [128]	train's auc: 0.998926	valid's auc: 0.963149
# [129]	train's auc: 0.99895	valid's auc: 0.963101
# [130]	train's auc: 0.998988	valid's auc: 0.963152
# [131]	train's auc: 0.999015	valid's auc: 0.963081
# [132]	train's auc: 0.999052	valid's auc: 0.963086
# [133]	train's auc: 0.999066	valid's auc: 0.963134
# [134]	train's auc: 0.999093	valid's auc: 0.963188
# [135]	train's auc: 0.999129	valid's auc: 0.963211
# [136]	train's auc: 0.999169	valid's auc: 0.963284
# [137]	train's auc: 0.999194	valid's auc: 0.963243
# [138]	train's auc: 0.999209	valid's auc: 0.963275
# [139]	train's auc: 0.999239	valid's auc: 0.963282
# [140]	train's auc: 0.99928	valid's auc: 0.963302
# [141]	train's auc: 0.999303	valid's auc: 0.963283
# [142]	train's auc: 0.999338	valid's auc: 0.963274
# [143]	train's auc: 0.999355	valid's auc: 0.963345
# [144]	train's auc: 0.999371	valid's auc: 0.963323
# [145]	train's auc: 0.99939	valid's auc: 0.963323
# [146]	train's auc: 0.999401	valid's auc: 0.963319
# [147]	train's auc: 0.999411	valid's auc: 0.96329
# [148]	train's auc: 0.99943	valid's auc: 0.963265
# [149]	train's auc: 0.999448	valid's auc: 0.963328
# [150]	train's auc: 0.99947	valid's auc: 0.963383
# [151]	train's auc: 0.999484	valid's auc: 0.963401
# [152]	train's auc: 0.999497	valid's auc: 0.96335
# [153]	train's auc: 0.999516	valid's auc: 0.963295
# [154]	train's auc: 0.999532	valid's auc: 0.963309
# [155]	train's auc: 0.999546	valid's auc: 0.963316
# [156]	train's auc: 0.999555	valid's auc: 0.963346
# [157]	train's auc: 0.999565	valid's auc: 0.963393
# [158]	train's auc: 0.999576	valid's auc: 0.963411
# [159]	train's auc: 0.999583	valid's auc: 0.963419
# [160]	train's auc: 0.999595	valid's auc: 0.963497
# [161]	train's auc: 0.999609	valid's auc: 0.963471
# [162]	train's auc: 0.999616	valid's auc: 0.963486
# [163]	train's auc: 0.999635	valid's auc: 0.963552
# [164]	train's auc: 0.999643	valid's auc: 0.963566
# [165]	train's auc: 0.999657	valid's auc: 0.963528
# [166]	train's auc: 0.999671	valid's auc: 0.963464
# [167]	train's auc: 0.999678	valid's auc: 0.963498
# [168]	train's auc: 0.999688	valid's auc: 0.963445
# [169]	train's auc: 0.999697	valid's auc: 0.963436
# [170]	train's auc: 0.999703	valid's auc: 0.963469
# [171]	train's auc: 0.999717	valid's auc: 0.963498
# [172]	train's auc: 0.999725	valid's auc: 0.963483
# [173]	train's auc: 0.999731	valid's auc: 0.963468
# [174]	train's auc: 0.99974	valid's auc: 0.963541
# [175]	train's auc: 0.999747	valid's auc: 0.963581
# [176]	train's auc: 0.999757	valid's auc: 0.963595
# [177]	train's auc: 0.999763	valid's auc: 0.963708
# [178]	train's auc: 0.999772	valid's auc: 0.963731
# [179]	train's auc: 0.999781	valid's auc: 0.963752
# [180]	train's auc: 0.999783	valid's auc: 0.963745
# [181]	train's auc: 0.99979	valid's auc: 0.963737
# [182]	train's auc: 0.999795	valid's auc: 0.963691
# [183]	train's auc: 0.999801	valid's auc: 0.963651
# [184]	train's auc: 0.999808	valid's auc: 0.963683
# [185]	train's auc: 0.999812	valid's auc: 0.963678
# [186]	train's auc: 0.99982	valid's auc: 0.963711
# [187]	train's auc: 0.999824	valid's auc: 0.963694
# [188]	train's auc: 0.999828	valid's auc: 0.963688
# [189]	train's auc: 0.999831	valid's auc: 0.963678
# [190]	train's auc: 0.999837	valid's auc: 0.963603
# [191]	train's auc: 0.999838	valid's auc: 0.963681
# [192]	train's auc: 0.999842	valid's auc: 0.963679
# [193]	train's auc: 0.999844	valid's auc: 0.963656
# [194]	train's auc: 0.999855	valid's auc: 0.963602
# [195]	train's auc: 0.999857	valid's auc: 0.963642
# [196]	train's auc: 0.999864	valid's auc: 0.963611
# [197]	train's auc: 0.999866	valid's auc: 0.963617
# [198]	train's auc: 0.999865	valid's auc: 0.963553
# [199]	train's auc: 0.99987	valid's auc: 0.963528
# [200]	train's auc: 0.999875	valid's auc: 0.963483
# [201]	train's auc: 0.999878	valid's auc: 0.963511
# [202]	train's auc: 0.999883	valid's auc: 0.963549
# [203]	train's auc: 0.999887	valid's auc: 0.963564
# [204]	train's auc: 0.999891	valid's auc: 0.963563
# [205]	train's auc: 0.999893	valid's auc: 0.963501
# [206]	train's auc: 0.999896	valid's auc: 0.96353
# [207]	train's auc: 0.999899	valid's auc: 0.963527
# [208]	train's auc: 0.999902	valid's auc: 0.96349
# [209]	train's auc: 0.999903	valid's auc: 0.963457
# [210]	train's auc: 0.999906	valid's auc: 0.963408
# [211]	train's auc: 0.999907	valid's auc: 0.963412
# [212]	train's auc: 0.999909	valid's auc: 0.963374
# [213]	train's auc: 0.999913	valid's auc: 0.963315
# [214]	train's auc: 0.999916	valid's auc: 0.963306
# [215]	train's auc: 0.999919	valid's auc: 0.963313
# [216]	train's auc: 0.99992	valid's auc: 0.963262
# [217]	train's auc: 0.999921	valid's auc: 0.963262
# [218]	train's auc: 0.999923	valid's auc: 0.963258
# [219]	train's auc: 0.999926	valid's auc: 0.963244
# [220]	train's auc: 0.999928	valid's auc: 0.963276
# [221]	train's auc: 0.999928	valid's auc: 0.963301
# [222]	train's auc: 0.999931	valid's auc: 0.963311
# [223]	train's auc: 0.999933	valid's auc: 0.963368
# [224]	train's auc: 0.999935	valid's auc: 0.963317
# [225]	train's auc: 0.999937	valid's auc: 0.963302
# [226]	train's auc: 0.999938	valid's auc: 0.963279
# [227]	train's auc: 0.99994	valid's auc: 0.963257
# [228]	train's auc: 0.999941	valid's auc: 0.963323
# [229]	train's auc: 0.999943	valid's auc: 0.963304
# [230]	train's auc: 0.999943	valid's auc: 0.963275
# [231]	train's auc: 0.999946	valid's auc: 0.963278
# [232]	train's auc: 0.999946	valid's auc: 0.963292
# [233]	train's auc: 0.999947	valid's auc: 0.963263
# [234]	train's auc: 0.999948	valid's auc: 0.963295
# [235]	train's auc: 0.999951	valid's auc: 0.963257
# [236]	train's auc: 0.999953	valid's auc: 0.963249
# [237]	train's auc: 0.999955	valid's auc: 0.963249
# [238]	train's auc: 0.999955	valid's auc: 0.963252
# [239]	train's auc: 0.999956	valid's auc: 0.963222
# [240]	train's auc: 0.999957	valid's auc: 0.963177
# [241]	train's auc: 0.999958	valid's auc: 0.963136
# [242]	train's auc: 0.99996	valid's auc: 0.963171
# [243]	train's auc: 0.999961	valid's auc: 0.963143
# [244]	train's auc: 0.999964	valid's auc: 0.96317
# [245]	train's auc: 0.999963	valid's auc: 0.963213
# [246]	train's auc: 0.999965	valid's auc: 0.963223
# [247]	train's auc: 0.999966	valid's auc: 0.963235
# [248]	train's auc: 0.999967	valid's auc: 0.963196
# [249]	train's auc: 0.999967	valid's auc: 0.963205
# [250]	train's auc: 0.999968	valid's auc: 0.963185
# [251]	train's auc: 0.999969	valid's auc: 0.963132
# [252]	train's auc: 0.99997	valid's auc: 0.963067
# [253]	train's auc: 0.999971	valid's auc: 0.963119
# [254]	train's auc: 0.999971	valid's auc: 0.963091
# [255]	train's auc: 0.999971	valid's auc: 0.963037
# [256]	train's auc: 0.999972	valid's auc: 0.963054
# [257]	train's auc: 0.999972	valid's auc: 0.963075
# [258]	train's auc: 0.999973	valid's auc: 0.963049
# [259]	train's auc: 0.999974	valid's auc: 0.963035
# [260]	train's auc: 0.999975	valid's auc: 0.962971
# [261]	train's auc: 0.999976	valid's auc: 0.963023
# [262]	train's auc: 0.999977	valid's auc: 0.96298
# [263]	train's auc: 0.999978	valid's auc: 0.962971
# [264]	train's auc: 0.999978	valid's auc: 0.96296
# [265]	train's auc: 0.999979	valid's auc: 0.962931
# [266]	train's auc: 0.99998	valid's auc: 0.962924
# [267]	train's auc: 0.999981	valid's auc: 0.962886
# [268]	train's auc: 0.999981	valid's auc: 0.962923
# [269]	train's auc: 0.999982	valid's auc: 0.962907
# [270]	train's auc: 0.999982	valid's auc: 0.962893
# [271]	train's auc: 0.999983	valid's auc: 0.962865
# [272]	train's auc: 0.999984	valid's auc: 0.962886
# [273]	train's auc: 0.999984	valid's auc: 0.962889
# [274]	train's auc: 0.999985	valid's auc: 0.962932
# [275]	train's auc: 0.999985	valid's auc: 0.962994
# [276]	train's auc: 0.999985	valid's auc: 0.962966
# [277]	train's auc: 0.999985	valid's auc: 0.962986
# [278]	train's auc: 0.999986	valid's auc: 0.962987
# [279]	train's auc: 0.999986	valid's auc: 0.962972
# Early stopping, best iteration is:
# [179]	train's auc: 0.999781	valid's auc: 0.963752
# The 1 1 kfold score : 0.7180046403712297
# score_0: 0.7177695511337344
# score_1: 0.7284839924670433
# score_2: 0.7156807511737089
# score_3: 0.7180046403712297
# score_mean:  0.7199847337864291
# [0.38191896 0.03347794 0.1197111  ... 3.8976244  0.06735348 0.00616443]
