# %%
import pandas as pd 
import numpy as np 
import os
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split

# %%
def tpr_weight_funtion(y_true,y_predict):
    d = pd.DataFrame()
    d['prob'] = list(y_predict)
    d['y'] = list(y_true)
    d = d.sort_values(['prob'], ascending=[0])
    y = d.y
    PosAll = pd.Series(y).value_counts()[1]
    NegAll = pd.Series(y).value_counts()[0]
    pCumsum = d['y'].cumsum()
    nCumsum = np.arange(len(y)) - pCumsum + 1
    pCumsumPer = pCumsum / PosAll
    nCumsumPer = nCumsum / NegAll
    TR1 = pCumsumPer[abs(nCumsumPer-0.001).idxmin()]
    TR2 = pCumsumPer[abs(nCumsumPer-0.005).idxmin()]
    TR3 = pCumsumPer[abs(nCumsumPer-0.01).idxmin()]
    return 0.4 * TR1 + 0.3 * TR2 + 0.3 * TR3

# %%
path = os.path.join(os.path.dirname('__file__'),'data')

def get_data(name):
	train_name = name+'_train_new.csv'
	test_name = 'test_'+name+'_round2.csv'
	train_data_path = os.path.join(path, train_name)
	test_data_path = os.path.join(path, test_name)
	train_data = pd.read_csv('../'+train_data_path)
	test_data = pd.read_csv('../'+test_data_path)
	train_data = pd.concat([train_data, test_data], axis=0, ignore_index=True, sort=False)
	if name=='tag':
		train_data.loc[train_data['Tag']==0.5, 'Tag']=-1
		train_data['Tag'] = train_data['Tag'].astype(int)			
	return train_data

# %%
def get_operation_features(tag_data, operation_data):
	columns = ['day', 'mode', 'success', 'time', 'os', 'version', 'device1',
		       'device2', 'device_code1', 'device_code2', 'device_code3', 'mac1',
		       'mac2', 'ip1', 'wifi', 'geo_code', 'ip1_sub']
	delete = ['mode', 'time', 'os', 'device1']
	
	operation_data['time'] = operation_data['time'].apply(lambda x: int(x.split(':')[0]))
	tmp_time = operation_data[operation_data['time']<6]
	tmp_time = tmp_time.groupby(['UID'])['time'].agg({'op_time_abnor_nunique':'nunique', 'op_time_abnor_count':'count'}).reset_index()
	tag_data = pd.merge(tag_data, tmp_time, on='UID', how='left')

	operation_data['isnull_num'] = operation_data.apply(lambda x: x.isnull().sum(),axis=1)
	agg_dict = {'isnull_num_max':'max', 'isnull_num_min':'min', 'isnull_num_mean':'mean', 'isnull_numt_std':'std', 'isnull_numt_sum':'sum'}
	tag_data = tag_data.merge(operation_data.groupby(['UID'])['isnull_num'].agg(agg_dict).reset_index(), on='UID', how='left')

	for col in columns:
		count_column = col+'_op_count'
		nunique_column = col+'_op_nunique'
		if col in delete:
			agg_dict = {nunique_column: 'nunique'}
		else:
			agg_dict = {count_column: "count", nunique_column: 'nunique'}
		
		tag_data = tag_data.merge(operation_data.groupby(['UID'])[col].agg(agg_dict).reset_index(), on='UID', how='left')

		count_column = col+'_UID_op_count'
		agg_dict = {count_column: "count"}
		tmp_cat =  operation_data.groupby(['UID', col])['Tag'].agg(agg_dict).reset_index()
		agg_dict = {col+'_op_count_mean':'mean', col+'_op_count_std':'std'}
		tag_data = tag_data.merge(tmp_cat.groupby(['UID'])[count_column].agg(agg_dict).reset_index(), on='UID', how='left')

	one_columns = []
	for col in columns:
		isnull_  = operation_data[col].isnull().sum()/len(operation_data)
		nunique_ = operation_data[col].nunique()
		if nunique_ > 200:
			one_columns.append(col)

	train_opertion_data = operation_data[operation_data['Tag']!=-1]
	for col in one_columns:
		nunique_ = train_opertion_data[col].nunique()
		if nunique_<5000:
			threshold = 10
		elif nunique_<10000 and nunique_>=5000:
			threshold = 8
		elif nunique_<16000 and nunique_>=10000:
			threshold = 5
		else:
			threshold = 3
		tmp_all = operation_data.groupby(['UID',col])['Tag'].agg({col+'_count':'count'}).reset_index()
		tmp = tmp_all.groupby([col])['UID'].agg({col+'_UID_count':'count'}).reset_index()
		
		#tmp_return = pd.merge(tmp_all, tmp, on=col, how=left)
		#agg_dict = {col+'_num_max':'max', col+'_num_min':'min', col+'_num_mean':'mean', col+'_numt_std':'std', col+'_numt_sum':'sum'}
		#tag_data = tag_data.merge(tmp_return.groupby(['UID'])[col+'_UID_count'].agg(agg_dict).reset_index(), on='UID', how='left')
		
		tmp = tmp[tmp[col+'_UID_count']>threshold+10]
		tmp[col+'_UID_count'] = 1
		tmp_all = pd.merge(tmp_all, tmp, on=col, how='left')
		tmp_all = tmp_all.fillna(0)
		tmp_all = tmp_all.groupby(['UID'])[col+'_UID_count'].agg({col+'_UID_sum':'sum'}).reset_index()
		tag_data = pd.merge(tag_data, tmp_all, on='UID', how='left')


	return tag_data

# %%
def get_transaction_features(tag_data, transaction_data):
	num_columns = ['trans_amt', 'bal']
	columns = ['channel', 'day', 'time', 'amt_src1', 'merchant',
	               'trans_type1', 'acc_id1', 'device_code1',
	               'device_code2', 'device_code3', 'device1', 'device2', 'mac1', 'ip1',
	               'amt_src2', 'acc_id2', 'acc_id3', 'geo_code', 'trans_type2',
	               'market_code', 'market_type', 'ip1_sub']
	delete = ['day', 'time', 'amt_src1', 'merchant','trans_type1']

	transaction_data['time'] = transaction_data['time'].apply(lambda x: int(x.split(':')[0]))
	tmp_time = transaction_data[transaction_data['time']<6]
	tmp_time = tmp_time.groupby(['UID'])['time'].agg({'trans_time_abnor_nunique':'nunique', 'trans_time_abnor_count':'count'}).reset_index()
	tag_data = pd.merge(tag_data, tmp_time, on='UID', how='left')

	transaction_data['isnull_num'] = transaction_data.apply(lambda x: x.isnull().sum(),axis=1)
	agg_dict = {'isnull_num_max':'max', 'isnull_num_min':'min', 'isnull_num_mean':'mean', 'isnull_numt_std':'std', 'isnull_numt_sum':'sum'}
	tag_data = tag_data.merge(transaction_data.groupby(['UID'])['isnull_num'].agg(agg_dict).reset_index(), on='UID', how='left')

	for col in columns:
		count_column = col+'_trans_count'
		nunique_column = col+'_trans_nunique'
		if col in delete:
			agg_dict = {nunique_column: 'nunique'}
		else:
			agg_dict = {count_column: "count", nunique_column: 'nunique'}
		
		tag_data = tag_data.merge(transaction_data.groupby(['UID'])[col].agg(agg_dict).reset_index(), on='UID', how='left')

		count_column = col+'_UID_trans_count'
		agg_dict = {count_column: "count"}
		tmp_cat =  transaction_data.groupby(['UID', col])['Tag'].agg(agg_dict).reset_index()
		agg_dict = {col+'_trans_count_mean':'mean', col+'_trans_count_std':'std'}
		tag_data = tag_data.merge(tmp_cat.groupby(['UID'])[count_column].agg(agg_dict).reset_index(), on='UID', how='left')

	for col in num_columns:
		nunique_column = col+'_trans_nunique'
		max_column = col+'_trans_max'
		min_column = col+'_trans_min'
		sum_column = col+'_trans_sum'
		mean_column = col+'_trans_mean'
		std_column = col+'_trans_std'

		agg_dict = {nunique_column:'nunique', max_column:'max', min_column:'min', sum_column:'sum', mean_column:'mean', std_column:'std'}

		tag_data = tag_data.merge(transaction_data.groupby(['UID'])[col].agg(agg_dict).reset_index(), on='UID', how='left')

	one_columns = []
	for col in columns:
		isnull_  = transaction_data[col].isnull().sum()/len(transaction_data)
		nunique_ = transaction_data[col].nunique()
		if nunique_ > 200:
			one_columns.append(col)
	delete = delete+one_columns
	one_columns = columns
	columns = [i for i in columns if i not in delete]
	train_trans_data = transaction_data[transaction_data['Tag']!=-1]

	##10 8 5 3 0.653
	for col in one_columns:
		nunique_ = train_trans_data[col].nunique()
		if nunique_<5000:
			threshold = 10
		elif nunique_<10000 and nunique_>=5000:
			threshold = 8
		elif nunique_<16000 and nunique_>=10000:
			threshold = 5
		else:
			threshold = 3
		tmp_all = transaction_data.groupby(['UID',col])['Tag'].agg({col+'_count':'count'}).reset_index()
		tmp = tmp_all.groupby([col])['UID'].agg({col+'_UID_count':'count'}).reset_index()
		tmp = tmp[tmp[col+'_UID_count']>threshold+10]
		tmp[col+'_UID_count'] = 1
		tmp_all = pd.merge(tmp_all, tmp, on=col, how='left')
		tmp_all = tmp_all.fillna(0)
		tmp_all = tmp_all.groupby(['UID'])[col+'_UID_count'].agg({col+'_UID_sum':'sum'}).reset_index()
		tag_data = pd.merge(tag_data, tmp_all, on='UID', how='left')

	return tag_data

# %%
def get_trans_devide_feature(tag_data, transaction_data):
	devide_col=[]
	for col in transaction_data.columns:
		nunique_ = transaction_data[col].nunique()
		if nunique_ <= 30 and col!='Tag':
			devide_col.append(col)

	for col in devide_col:
		unique = transaction_data[col].unique()
		for i, name in enumerate(unique):
			tmp = transaction_data[transaction_data[col]==name]
			#tmp = tmp.groupby('UID')[col].agg({col+'_count_'+str(i):'count'}).reset_index()
			tag_data = tag_data.merge(tmp.groupby('UID')[col].agg({col+'_count_'+str(i):'count'}).reset_index(), on='UID', how='left')
	return tag_data


def get_ctr_feature(tag_data):
	train_data = tag_data[tag_data['Tag']!=-1]
	columns = tag_data.columns
	items = []
	lack_features = ['device_code3','mac1','acc_id2','acc_id3','market_code','market_type']
	for col in columns:
		if tag_data[col].nunique()<30 and col != 'Tag':
			flag=0
			for lack_ in lack_features:
				if lack_ in col:
					flag=1
					break
			if flag==0:
				items.append(col)
	for item in items:
		temp = train_data.groupby(item, as_index = False)['Tag'].agg({item+'_click':'sum', item+'_count':'count'})
		temp[item+'_ctr'] = temp[item+'_click']/(temp[item+'_count'])
		tag_data = pd.merge(tag_data, temp, on=item, how='left')

	for i in range(len(items)):
		for j in range(i+1, len(items)):
			item_g = [items[i], items[j]]
			temp = train_data.groupby(item_g, as_index=False)['Tag'].agg({'_'.join(item_g)+'_click': 'sum','_'.join(item_g)+'count':'count'})
			temp['_'.join(item_g)+'_ctr'] = temp['_'.join(item_g)+'_click']/(temp['_'.join(item_g)+'count']+3)
			tag_data = pd.merge(tag_data, temp, on=item_g, how='left')

	return tag_data

# %%
def get_cat_used(tag_data, operation_data, transaction_data):
	
	def get_cat(x):
		res = []
		tmp = x.value_counts()
		tmp_value=list(tmp)
		if tmp.shape[0]>1 and tmp.index[0]==-1:
			res.append(tmp.index[1])
			res.append(tmp_value[1]/len(x))
			return res
		else:
			res.append(tmp.index[0])
			res.append(tmp_value[0]/len(x))
			return res


	cols = ['mode', 'os',  'device2',  'geo_code', 'ip1_sub','version',  'mac2','device1', 'device_code1', 'device_code2', 'device_code3','ip1', 'mac1','wifi']
	for col in cols:
		tmp=pd.DataFrame()
		operation_data[col] = pd.factorize(operation_data[col])[0]
		tmp = operation_data.groupby(['UID'])[col].apply(get_cat).reset_index()
		#tmp[col+'_op_clike'] = tmp[col].apply(lambda x: x[0])
		tmp[col+'_op_clike_ratio'] = tmp[col].apply(lambda x: x[1])
		tmp = tmp.drop(col, axis=1)
		tag_data = pd.merge(tag_data, tmp, on='UID',how='left')

	#for col in cols:
		#tag_data = tag_data.merge(operation_data.groupby(['UID'])[col].agg(lambda x: x.value_counts().index[0]).reset_index(),on='UID',how='left')

	#op_data['hour'] = op_data.time.str[0:2].astype(int)
	#op_data['time'] = pd.to_datetime(op_data['time'])
	#op_data['time'] = op_data['time'].apply(lambda x:(x-datetime.now()).seconds/3600)

	cols_f = ['amt_src1', 'trans_type1','amt_src2','geo_code','ip1_sub','mac1','acc_id2','merchant','acc_id3','channel','market_type',
			'trans_type2','market_code','ip1','device_code2','device_code3','device1','device_code1','acc_id1','device2']
	for col in cols_f:
		tmp=pd.DataFrame()
		transaction_data[col] = pd.factorize(transaction_data[col])[0]
		tmp = transaction_data.groupby(['UID'])[col].apply(get_cat).reset_index()
		#tmp[col+'_trans_clike'] = tmp[col].apply(lambda x: x[0])
		tmp[col+'_trans_clike_ratio'] = tmp[col].apply(lambda x: x[1])
		tmp = tmp.drop(col, axis=1)
		tag_data = pd.merge(tag_data, tmp, on='UID',how='left')

	#for col in cols_f:
		#tag_data = tag_data.merge(transaction_data.groupby(['UID'])[col].agg(lambda x: x.value_counts().index[0]).reset_index(),on='UID',how='left')
	
	#tr_data['hour'] = tr_data.time.str[0:2].astype(int)
	#tr_data['time'] = pd.to_datetime(tr_data['time'])
	#tr_data['time'] = tr_data['time'].apply(lambda x:(x-datetime.now()).seconds/3600)

	return tag_data

# %%
def bulid_cat_feature(uid_list,feature_list,featureName):
	#1.找到每个uid有哪些特征
	uid2featureList = {}  #key uid  feature 这个uid对应历史上出现过哪些list
	for i in range(len(uid_list)):
	    uid = uid_list[i]
	    feature = feature_list[i]
	    #不为空
	    #if feature:
	    if not pd.isnull(feature):
	        if uid not in uid2featureList:
	            uid2featureList[uid] = set()
	        uid2featureList[uid].add(str(feature))  #用str

	feasvalue2index = {}  #这个值对应的特征名         
	#2.将每一行转化为dict
	rows = []
	for uid,value in uid2featureList.items():
	    tmp_dict = {}
	    tmp_dict["UID"] = uid
	    value = "@".join(sorted(list(value)))
	    if value not in feasvalue2index:
	        feasvalue2index[value] = len(feasvalue2index)
	    tmp_dict[featureName+"_cat"] = feasvalue2index[value]
	    rows.append(tmp_dict)
	df = pd.DataFrame(rows)
	return df

def get_cat_feature(tag_data, operation_data, transaction_data):
	one_hot_t_feature = ["channel","amt_src1","trans_type1","amt_src2","trans_type2","market_type"]
	one_hot_op_feature = ["mode","success","os","version"]
	#4.构造分类特征 0.31 -> 0.48
	for feature in one_hot_t_feature:
		df_temp = bulid_cat_feature(list(transaction_data["UID"]),list(transaction_data[feature]),feature)
		tag_data = tag_data.merge(df_temp,on='UID',how='left')

	for feature in one_hot_op_feature:
		df_temp = bulid_cat_feature(list(operation_data["UID"]),list(operation_data[feature]),feature)
		tag_data = tag_data.merge(df_temp,on='UID',how='left')

	return tag_data

def get_cross_feature(tag_data, operation_data, transaction_data):
	cross_col = ['mode', 'os', 'version', 'device1',
				'device2', 'device_code1', 'device_code2', 'device_code3', 'mac1',
				'mac2', 'ip1',  'wifi', 'geo_code', 'ip1_sub']
	for col in cross_col: 
		tmp = operation_data.groupby(['UID', 'day'])[col].agg({col+'_op_day_nunique': 'nunique'})
		tmp = tmp.groupby(['UID'])[col+'_op_day_nunique'].agg({col+'_op_day_nunique_max':'max', col+'_op_day_nunique_mean':'mean'})
		tag_data = pd.merge(tag_data, tmp, on='UID', how='left')
	cross_col = ['channel', 'trans_amt', 'amt_src1', 'merchant',
				'trans_type1', 'acc_id1', 'device_code1',
				'device_code2', 'device_code3', 'device1', 'device2', 'mac1', 'ip1',
				'bal', 'amt_src2', 'acc_id2', 'acc_id3', 'geo_code', 'trans_type2',
				'market_code', 'market_type', 'ip1_sub']
	for col in cross_col: 
		tmp = transaction_data.groupby(['UID', 'day'])[col].agg({col+'_trans_day_nunique': 'nunique'})
		tmp = tmp.groupby(['UID'])[col+'_trans_day_nunique'].agg({col+'_trans_day_nunique_max':'max', col+'_trans_day_nunique_mean':'mean'})
		tag_data = pd.merge(tag_data, tmp, on='UID', how='left')
	return tag_data

# %%
def get_time_feature(tag_data, operation_data, transaction_data):
	"""
feature_prefix:特征前缀

对day特征进行构建
针对每个UID
(1)计算这个UID前后两次交易的平均时间   如  1,6,10  那么平均时间为  （5 + 4） / 2  = 4.5 (多少天会交易1次)
(2)计算这个UID第1次交易和最后一次交易的时间差   如1,6,10  那么前后两次交易的时间差为 10 - 1 = 9

后续可以开发的 max_gap  min_gap 

"""
	def bulid_day_avg_gap(uid_list,feature_list,feature_prefix):
		uid2daylist = {}
		#1.先计算每个uid有哪些day
		for i in range(len(uid_list)):
			uid = uid_list[i]
			day = feature_list[i]
			if uid not in uid2daylist:
				uid2daylist[uid] = []
			uid2daylist[uid].append(day)

		rows = []
		#2.对每个uid进行处理
		for uid,value in uid2daylist.items():
			value = sorted(value)
			if len(value) == 1:
				avg = 0
				gap = 0
			else:
				tmp_sum = 0
				for i in range(1,len(value)):
				    tmp_sum += (value[i] - value[i - 1])
				avg = tmp_sum * 1.0 / (len(value))
				gap = value[-1] - value[0]

			tmp_dict = {}
			tmp_dict["UID"] = uid
			tmp_dict[feature_prefix + "_avg"] = avg
			tmp_dict[feature_prefix + "_gap"] = gap
			rows.append(tmp_dict)

		df = pd.DataFrame(rows)
		#if norm_flag:
		#归一化
		#df[feature_prefix + "_avg"] = norm_list(list(df[feature_prefix + "_avg"]))
		#df[feature_prefix + "_gap"] = norm_list(list(df[feature_prefix + "_gap"]))
		#print df
		return df

	"""
	对time进行处理
	(1)计算这个UID前后两次交易的平均时间   
	(2)计算这个UID第1次交易和最后一次交易的时间差
	_day_hour 精确到小时
	_day_hour_min 精确到分钟
	"""
	def bulid_time_avg_gap(uid_list,day_list,time_list,feature_prefix):
		day_hour_list = []
		day_hour_min_list = []
		for i in range(len(day_list)):
			day = int(day_list[i])
			time_array_2 = time_list[i].split(':') #时分秒
			hour = int(time_array_2[0])
			minute = int(time_array_2[1])
			day_hour_list.append(day * 24 + hour )
			day_hour_min_list.append(day * 3600 + hour * 60 + minute)

		df1 = bulid_day_avg_gap(uid_list,day_hour_list,feature_prefix+"_day_hour")
		df2 = bulid_day_avg_gap(uid_list,day_hour_min_list,feature_prefix+"_day_hour_min")
		df1 = df1.merge(df2,on='UID',how='left')
		#print df1
		return df1
	#2.时间day的统计 (这部分如果不需要基础统计，就不放在get_feature之前)
	#统计每个UID 每次交易的平均时间间隔 最大时间间隔，最小时间间隔 (Day为单位)
	#(1)trans - day
	df_temp = bulid_day_avg_gap(list(transaction_data["UID"]),list(transaction_data["day"]),"trans_day_between")
	tag_data = tag_data.merge(df_temp,on='UID',how='left')

	#(2)op - day
	df_temp = bulid_day_avg_gap(list(operation_data["UID"]),list(operation_data["day"]),"op_day_between")
	tag_data = tag_data.merge(df_temp,on='UID',how='left')

	#(3)trans - time
	#df_temp = bulid_time_avg_gap(list(transaction_data["UID"]),list(transaction_data["day"]),list(transaction_data["time"]),"trans_time_between")
	#tag_data = tag_data.merge(df_temp,on='UID',how='left')

	#(4)op - time
	#df_temp = bulid_time_avg_gap(list(operation_data["UID"]),list(operation_data["day"]),list(operation_data["time"]),"op_time_between")
	#tag_data = tag_data.merge(df_temp,on='UID',how='left')

	return tag_data

def deal_tag_features(tag_data):
	features = tag_data.columns
	flag = '_Tag_count_max'
	Tag_features = [col for col in features if flag in col]
	tag_data = tag_data.drop(Tag_features, axis=1)
	flag = 'ctr'
	Tag_features = [col for col in features if flag in col]
	tag_data = tag_data.drop(Tag_features, axis=1)
	#tag_data.loc[tag_data['Tag_count_max_sum']>3, 'Tag_count_max_sum']=4
	return tag_data

# %%
def lgb_model(train_data, test_data, n_folds=5):
	columns = train_data.columns
	remove_columns = ['Tag','UID']
	features_columns = [column for column in columns if column not in remove_columns]

    #train_features = train_data[features_columns]
    #train_labels = train_data["tag"]

	lgb_parms = {
				"boosting_type": "gbdt",
				"num_leaves": 15,
				"max_depth": -1,
				"learning_rate": 0.1,
				"n_estimators": 500,
				"max_bin": 425,
				"subsample_for_bin": 20000,
				"objective": 'binary',
				"metric": 'auc',
				"min_split_gain": 0,
				"min_child_weight": 0.001,
				"min_child_samples": 20,
				"subsample": 0.8,
				"subsample_freq": 1,
				"colsample_bytree": 0.7,
				"reg_alpha": 3,
				"reg_lambda": 5,
				"seed": 2018,
				"n_jobs": 25,
				"verbose": 1,
				"silent": False,
				}

	test_data = test_data.drop(['Tag'], axis = 1)

	skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=2018)

	preds_list = list()
	vali_score = list()
	features_importance=pd.DataFrame()
	features_importance['feature_name'] = features_columns
	for n, (train_index, test_index) in enumerate(skf.split(train_data, train_data["Tag"])):
		k_train = train_data.loc[train_index, :]
		k_test = train_data.loc[test_index, :]

		#X_train = np.array(k_train.drop(['Tag'], axis = 1))
		#y_train = np.array(k_train['Tag'])
		#X_test = np.array(k_test.drop(['Tag'], axis = 1))
		#y_test = np.array(k_test['Tag'])

		X_train = k_train.drop(['Tag'], axis = 1)
		y_train = k_train['Tag']
		X_test = k_test.drop(['Tag'], axis = 1)
		y_test = k_test['Tag']

		gbm = lgb.LGBMClassifier(**lgb_parms)
		gbm = gbm.fit(X_train, y_train,
                      eval_metric="auc",
                      eval_set=[(X_train, y_train),
                                (X_test, y_test)],
                      eval_names=["train", "valid"],
                      early_stopping_rounds=100,
                      verbose=True)

		vali_pred = gbm.predict_proba(X_test, num_iteration=gbm.best_iteration_)[:, 1]
		vali_k_score = tpr_weight_funtion(y_test, vali_pred)

		print('The {} kfold score : {}'.format(n, vali_k_score))

		vali_score.append(vali_k_score)
		preds = gbm.predict_proba(test_data, num_iteration=gbm.best_iteration_)[:, 1]

		preds_list.append(preds)

		booster = gbm.booster_
		importance = booster.feature_importance(importance_type='split')
		feature_name = booster.feature_name()
		feature_importance = pd.DataFrame({'feature_name':feature_name,'importance_'+str(n):importance} )
		features_importance = pd.merge(features_importance, feature_importance, how='left', on='feature_name')

	features_importance.to_csv('../data/features_importance.csv', index=False)

	for n, (i) in enumerate(vali_score):
		print('score_{}: {}'.format(n, i))    
	print('score_mean: ', np.mean(vali_score))

	s = 0
	for i in preds_list:
		s = s + i

	test_data['Tag'] = list(s / n_folds)
	test_data[['UID', 'Tag']].to_csv('../data/submit_delete.csv',index = False)

# %%
def get_day_feature(data_set, tag_data):
	tmp = data_set.groupby(['UID', 'merchant'])['day'].agg({'day':'mean'}).reset_index()
	tmp_merchant_day = tmp.groupby(['merchant', 'day'])['UID'].agg({'count':'count'}).reset_index()
	tmp_merchant = tmp.groupby(['merchant'])['UID'].agg({'all_count':'count'}).reset_index()
	tmp_merchant_day = tmp_merchant_day.merge(tmp_merchant, on='merchant', how='left')
	tmp_merchant_day['day_ratio'] = tmp_merchant_day['count']/tmp_merchant_day['all_count']
	tmp = tmp.merge(tmp_merchant_day, on=['merchant', 'day'], how='left')
	tmp = tmp.groupby(['UID'])['day_ratio'].agg({'ratio_mean':'mean', 'ratio_max':'max', 'ratio_min':'min', 'ratio_std':'std'}).reset_index()
	tag_data = tag_data.merge(tmp, on='UID', how='left')
	return tag_data

def get_mercant_feature(data_set, tag_data):
	tmp = data_set.groupby(['merchant'])['UID'].agg({'merchant_UID_nunique':'nunique'})
	tmp = data_set.merge(tmp, on='merchant', how='left')
	tmp = tmp.groupby(['UID'])['merchant_UID_nunique'].agg({'merchant_UID_nunique_max':'max', 'merchant_UID_nunique_mim':'min','merchant_UID_nunique_mean':'mean', 'merchant_UID_nunique_std':'std'}).reset_index()
	tag_data = tag_data.merge(tmp, on='UID', how='left')
	return tag_data

def Processing():

	operation_data = get_data(name='operation')
	transaction_data = get_data(name='transaction')
	tag_data = get_data(name='tag')
	operation_data = pd.merge(operation_data, tag_data, on='UID', how='left')
	transaction_data = pd.merge(transaction_data, tag_data, on='UID', how='left')
	op_delete=['ip2', 'ip2_sub' ]
	trans_delete = ['code1', 'code2']
	operation_data = operation_data.drop(op_delete, axis=1)
	transaction_data = transaction_data.drop(trans_delete, axis=1)
	print('finish get data...')


	create = True
	if create:
			#
		print('==============================')
		print('start getting operation features....')
	#
		tag_data = get_operation_features(tag_data, operation_data)
	#
		print('finish getting operation features....')
	#
		print('==============================')
		print('start getting transaction features....')
	#
		tag_data = get_transaction_features(tag_data, transaction_data)
		
	#
		print('finish getting transaction features....')
	#
		print('==============================')
		print('start getting ctr features....')
	#
		#tag_data = get_ctr_feature(tag_data)
	#	
		#tag_data = get_checkBlack_count(tag_data, operation_data, transaction_data)

		print('finish getting ctr features....')

		print('==============================')
		print('start getting cat features....')

		#tag_data = get_cat_feature(tag_data, operation_data, transaction_data)

		tag_data = get_time_feature(tag_data, operation_data, transaction_data)

		tag_data = get_cross_feature(tag_data, operation_data, transaction_data)

		#tag_data = get_cat_used(tag_data, operation_data, transaction_data)

		tag_data = get_day_feature(transaction_data, tag_data)

		#tag_data = get_mercant_feature(transaction_data, tag_data)
		print('start getting cat features....')
		#tag_data = pd.read_csv('../data/tag_data.csv')

		tag_data = deal_tag_features(tag_data)


		tag_data.to_csv('../data/tag_data_baseline.csv', index = False)

	else:
		print('create new features')
		tag_data = pd.read_csv('../data/tag_data_baseline.csv')
		#tag_data = get_ctr_feature(tag_data)
		#tag_data = get_trans_devide_feature(tag_data, transaction_data)		## be of no effect +0.002
		#tag_data = get_cat_used(tag_data, operation_data, transaction_data)  ##+0.007
		#tag_data = get_day_feature(transaction_data, tag_data)
		#tag_data = get_mercant_feature(transaction_data, tag_data)
		#tag_data = get_checkBlack_count(tag_data, operation_data, transaction_data) ##+0.004
		#tag_data = get_cat_feature(tag_data, operation_data, transaction_data)
		#tag_data = deal_tag_features(tag_data)
		#tag_data = get_cross_feature(tag_data, operation_data, transaction_data)  ##+0.004
		#tag_data = get_time_feature(tag_data, operation_data, transaction_data)
		#tag_data.to_csv('../features_data/tag_data_1.csv', index = False)
		delete = [i for i in tag_data.columns if 'trans_amt' in i]
		print(delete)
		tag_data = tag_data.drop(delete, axis=1)
		delete = [i for i in tag_data.columns if 'bal' in i]
		print(delete)
		tag_data = tag_data.drop(delete, axis=1)
		#print(train_data.shape)
		#print(test_data.shape)

	train_data = tag_data[tag_data['Tag']!=-1]
	test_data = tag_data[tag_data['Tag']==-1]

	print(train_data.shape)
	print(test_data.shape)

	print('==============================')
	print('start training....')

	lgb_model(train_data, test_data)

# %%
if __name__ == "__main__":
    Processing()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2881: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# finish get data...
# ==============================
# start getting operation features....
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:9: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:14: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:24: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:28: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:30: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:50: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:51: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:61: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# finish getting operation features....
# ==============================
# start getting transaction features....
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:12: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:17: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:27: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:31: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:33: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:45: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:69: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:70: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:75: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# finish getting transaction features....
# ==============================
# start getting ctr features....
# finish getting ctr features....
# ==============================
# start getting cat features....
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:47: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:48: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:56: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:57: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   from ipykernel import kernelapp as app
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   app.launch_new_instance()
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:8: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
# start getting cat features....
# (31179, 288)
# (31588, 288)
# ==============================
# start training....
# [1]	train's auc: 0.866429	valid's auc: 0.874759
# Training until validation scores don't improve for 100 rounds.
# [2]	train's auc: 0.891039	valid's auc: 0.895261
# [3]	train's auc: 0.898493	valid's auc: 0.903437
# [4]	train's auc: 0.904689	valid's auc: 0.903763
# [5]	train's auc: 0.918163	valid's auc: 0.92098
# [6]	train's auc: 0.923044	valid's auc: 0.924891
# [7]	train's auc: 0.9255	valid's auc: 0.92517
# [8]	train's auc: 0.929344	valid's auc: 0.928624
# [9]	train's auc: 0.933668	valid's auc: 0.929825
# [10]	train's auc: 0.937391	valid's auc: 0.933632
# [11]	train's auc: 0.938984	valid's auc: 0.937023
# [12]	train's auc: 0.939435	valid's auc: 0.938598
# [13]	train's auc: 0.941132	valid's auc: 0.939564
# [14]	train's auc: 0.943464	valid's auc: 0.941754
# [15]	train's auc: 0.945797	valid's auc: 0.943588
# [16]	train's auc: 0.94757	valid's auc: 0.944197
# [17]	train's auc: 0.948541	valid's auc: 0.944754
# [18]	train's auc: 0.949683	valid's auc: 0.946284
# [19]	train's auc: 0.950907	valid's auc: 0.946989
# [20]	train's auc: 0.951282	valid's auc: 0.947471
# [21]	train's auc: 0.953044	valid's auc: 0.949612
# [22]	train's auc: 0.954259	valid's auc: 0.950442
# [23]	train's auc: 0.955074	valid's auc: 0.950513
# [24]	train's auc: 0.955738	valid's auc: 0.951292
# [25]	train's auc: 0.95644	valid's auc: 0.951467
# [26]	train's auc: 0.957085	valid's auc: 0.952297
# [27]	train's auc: 0.957811	valid's auc: 0.952825
# [28]	train's auc: 0.958388	valid's auc: 0.953043
# [29]	train's auc: 0.958866	valid's auc: 0.953446
# [30]	train's auc: 0.959383	valid's auc: 0.95372
# [31]	train's auc: 0.960021	valid's auc: 0.953994
# [32]	train's auc: 0.960288	valid's auc: 0.954357
# [33]	train's auc: 0.96095	valid's auc: 0.954961
# [34]	train's auc: 0.961414	valid's auc: 0.954794
# [35]	train's auc: 0.962131	valid's auc: 0.955131
# [36]	train's auc: 0.962656	valid's auc: 0.955471
# [37]	train's auc: 0.963239	valid's auc: 0.955502
# [38]	train's auc: 0.963721	valid's auc: 0.956157
# [39]	train's auc: 0.964214	valid's auc: 0.956115
# [40]	train's auc: 0.964809	valid's auc: 0.956714
# [41]	train's auc: 0.965106	valid's auc: 0.95711
# [42]	train's auc: 0.965292	valid's auc: 0.957407
# [43]	train's auc: 0.965747	valid's auc: 0.957564
# [44]	train's auc: 0.965961	valid's auc: 0.957882
# [45]	train's auc: 0.966354	valid's auc: 0.957971
# [46]	train's auc: 0.966581	valid's auc: 0.957911
# [47]	train's auc: 0.966988	valid's auc: 0.958117
# [48]	train's auc: 0.967408	valid's auc: 0.958586
# [49]	train's auc: 0.967853	valid's auc: 0.958911
# [50]	train's auc: 0.968146	valid's auc: 0.958817
# [51]	train's auc: 0.96844	valid's auc: 0.959014
# [52]	train's auc: 0.968882	valid's auc: 0.95901
# [53]	train's auc: 0.96919	valid's auc: 0.95915
# [54]	train's auc: 0.969596	valid's auc: 0.959184
# [55]	train's auc: 0.969852	valid's auc: 0.959253
# [56]	train's auc: 0.970224	valid's auc: 0.95954
# [57]	train's auc: 0.970608	valid's auc: 0.959721
# [58]	train's auc: 0.970907	valid's auc: 0.959769
# [59]	train's auc: 0.971159	valid's auc: 0.959992
# [60]	train's auc: 0.971506	valid's auc: 0.960063
# [61]	train's auc: 0.971712	valid's auc: 0.96024
# [62]	train's auc: 0.97198	valid's auc: 0.960499
# [63]	train's auc: 0.972257	valid's auc: 0.960718
# [64]	train's auc: 0.972605	valid's auc: 0.960941
# [65]	train's auc: 0.972877	valid's auc: 0.961115
# [66]	train's auc: 0.973194	valid's auc: 0.961392
# [67]	train's auc: 0.973488	valid's auc: 0.961466
# [68]	train's auc: 0.973713	valid's auc: 0.961574
# [69]	train's auc: 0.973917	valid's auc: 0.961682
# [70]	train's auc: 0.974137	valid's auc: 0.961757
# [71]	train's auc: 0.9744	valid's auc: 0.961979
# [72]	train's auc: 0.974717	valid's auc: 0.962298
# [73]	train's auc: 0.974896	valid's auc: 0.962435
# [74]	train's auc: 0.975186	valid's auc: 0.96263
# [75]	train's auc: 0.975335	valid's auc: 0.962691
# [76]	train's auc: 0.975571	valid's auc: 0.962657
# [77]	train's auc: 0.975755	valid's auc: 0.962731
# [78]	train's auc: 0.976033	valid's auc: 0.962654
# [79]	train's auc: 0.976269	valid's auc: 0.962732
# [80]	train's auc: 0.976456	valid's auc: 0.962675
# [81]	train's auc: 0.976682	valid's auc: 0.962677
# [82]	train's auc: 0.97685	valid's auc: 0.96259
# [83]	train's auc: 0.977037	valid's auc: 0.962729
# [84]	train's auc: 0.977253	valid's auc: 0.962822
# [85]	train's auc: 0.977505	valid's auc: 0.962808
# [86]	train's auc: 0.977667	valid's auc: 0.962892
# [87]	train's auc: 0.977796	valid's auc: 0.962967
# [88]	train's auc: 0.977969	valid's auc: 0.963063
# [89]	train's auc: 0.978174	valid's auc: 0.963105
# [90]	train's auc: 0.978395	valid's auc: 0.963225
# [91]	train's auc: 0.97861	valid's auc: 0.963214
# [92]	train's auc: 0.978786	valid's auc: 0.963277
# [93]	train's auc: 0.97896	valid's auc: 0.963359
# [94]	train's auc: 0.979157	valid's auc: 0.963576
# [95]	train's auc: 0.979305	valid's auc: 0.963672
# [96]	train's auc: 0.97956	valid's auc: 0.963879
# [97]	train's auc: 0.979697	valid's auc: 0.963901
# [98]	train's auc: 0.979864	valid's auc: 0.963891
# [99]	train's auc: 0.980032	valid's auc: 0.963931
# [100]	train's auc: 0.980181	valid's auc: 0.964059
# [101]	train's auc: 0.980341	valid's auc: 0.964062
# [102]	train's auc: 0.980506	valid's auc: 0.964108
# [103]	train's auc: 0.980712	valid's auc: 0.964087
# [104]	train's auc: 0.980859	valid's auc: 0.964187
# [105]	train's auc: 0.980943	valid's auc: 0.96415
# [106]	train's auc: 0.981084	valid's auc: 0.964173
# [107]	train's auc: 0.981226	valid's auc: 0.964173
# [108]	train's auc: 0.981339	valid's auc: 0.964251
# [109]	train's auc: 0.981451	valid's auc: 0.964262
# [110]	train's auc: 0.981626	valid's auc: 0.964404
# [111]	train's auc: 0.981789	valid's auc: 0.964478
# [112]	train's auc: 0.981918	valid's auc: 0.964451
# [113]	train's auc: 0.982022	valid's auc: 0.964534
# [114]	train's auc: 0.98214	valid's auc: 0.964608
# [115]	train's auc: 0.982269	valid's auc: 0.964439
# [116]	train's auc: 0.982368	valid's auc: 0.96457
# [117]	train's auc: 0.982507	valid's auc: 0.964567
# [118]	train's auc: 0.982601	valid's auc: 0.964559
# [119]	train's auc: 0.982735	valid's auc: 0.964668
# [120]	train's auc: 0.982809	valid's auc: 0.964716
# [121]	train's auc: 0.982946	valid's auc: 0.964749
# [122]	train's auc: 0.983054	valid's auc: 0.964816
# [123]	train's auc: 0.98325	valid's auc: 0.964998
# [124]	train's auc: 0.983382	valid's auc: 0.965023
# [125]	train's auc: 0.983508	valid's auc: 0.964974
# [126]	train's auc: 0.9836	valid's auc: 0.965065
# [127]	train's auc: 0.9838	valid's auc: 0.965135
# [128]	train's auc: 0.983865	valid's auc: 0.965206
# [129]	train's auc: 0.983955	valid's auc: 0.965126
# [130]	train's auc: 0.984064	valid's auc: 0.96505
# [131]	train's auc: 0.984214	valid's auc: 0.965033
# [132]	train's auc: 0.98434	valid's auc: 0.965138
# [133]	train's auc: 0.984498	valid's auc: 0.965206
# [134]	train's auc: 0.984606	valid's auc: 0.965273
# [135]	train's auc: 0.984704	valid's auc: 0.965307
# [136]	train's auc: 0.984857	valid's auc: 0.965278
# [137]	train's auc: 0.984935	valid's auc: 0.965282
# [138]	train's auc: 0.985121	valid's auc: 0.965309
# [139]	train's auc: 0.985195	valid's auc: 0.965307
# [140]	train's auc: 0.985352	valid's auc: 0.965261
# [141]	train's auc: 0.985476	valid's auc: 0.965332
# [142]	train's auc: 0.985542	valid's auc: 0.965339
# [143]	train's auc: 0.9857	valid's auc: 0.965404
# [144]	train's auc: 0.985784	valid's auc: 0.965435
# [145]	train's auc: 0.985871	valid's auc: 0.965456
# [146]	train's auc: 0.985961	valid's auc: 0.965343
# [147]	train's auc: 0.986104	valid's auc: 0.965425
# [148]	train's auc: 0.986194	valid's auc: 0.965538
# [149]	train's auc: 0.9863	valid's auc: 0.96562
# [150]	train's auc: 0.986441	valid's auc: 0.96573
# [151]	train's auc: 0.986546	valid's auc: 0.96576
# [152]	train's auc: 0.986642	valid's auc: 0.965813
# [153]	train's auc: 0.98674	valid's auc: 0.965831
# [154]	train's auc: 0.986846	valid's auc: 0.965842
# [155]	train's auc: 0.986894	valid's auc: 0.965867
# [156]	train's auc: 0.986962	valid's auc: 0.965955
# [157]	train's auc: 0.987066	valid's auc: 0.966048
# [158]	train's auc: 0.987128	valid's auc: 0.966132
# [159]	train's auc: 0.987224	valid's auc: 0.966026
# [160]	train's auc: 0.987339	valid's auc: 0.966068
# [161]	train's auc: 0.987399	valid's auc: 0.966076
# [162]	train's auc: 0.987619	valid's auc: 0.966132
# [163]	train's auc: 0.987731	valid's auc: 0.966074
# [164]	train's auc: 0.987801	valid's auc: 0.966036
# [165]	train's auc: 0.987894	valid's auc: 0.966061
# [166]	train's auc: 0.987959	valid's auc: 0.966117
# [167]	train's auc: 0.988023	valid's auc: 0.966034
# [168]	train's auc: 0.988126	valid's auc: 0.966022
# [169]	train's auc: 0.988211	valid's auc: 0.966108
# [170]	train's auc: 0.988279	valid's auc: 0.966012
# [171]	train's auc: 0.988339	valid's auc: 0.966077
# [172]	train's auc: 0.988442	valid's auc: 0.966013
# [173]	train's auc: 0.988539	valid's auc: 0.966037
# [174]	train's auc: 0.988628	valid's auc: 0.966017
# [175]	train's auc: 0.988698	valid's auc: 0.966025
# [176]	train's auc: 0.988805	valid's auc: 0.965994
# [177]	train's auc: 0.988857	valid's auc: 0.966012
# [178]	train's auc: 0.988979	valid's auc: 0.965923
# [179]	train's auc: 0.989051	valid's auc: 0.965914
# [180]	train's auc: 0.989143	valid's auc: 0.965928
# [181]	train's auc: 0.989217	valid's auc: 0.965882
# [182]	train's auc: 0.989245	valid's auc: 0.965846
# [183]	train's auc: 0.989304	valid's auc: 0.965946
# [184]	train's auc: 0.98937	valid's auc: 0.96594
# [185]	train's auc: 0.98943	valid's auc: 0.965975
# [186]	train's auc: 0.989523	valid's auc: 0.965993
# [187]	train's auc: 0.989597	valid's auc: 0.966045
# [188]	train's auc: 0.989734	valid's auc: 0.966196
# [189]	train's auc: 0.989768	valid's auc: 0.966198
# [190]	train's auc: 0.989852	valid's auc: 0.966178
# [191]	train's auc: 0.989956	valid's auc: 0.966179
# [192]	train's auc: 0.990025	valid's auc: 0.966302
# [193]	train's auc: 0.990109	valid's auc: 0.966356
# [194]	train's auc: 0.99018	valid's auc: 0.96631
# [195]	train's auc: 0.990255	valid's auc: 0.966306
# [196]	train's auc: 0.99036	valid's auc: 0.966307
# [197]	train's auc: 0.990406	valid's auc: 0.966345
# [198]	train's auc: 0.99048	valid's auc: 0.966366
# [199]	train's auc: 0.990536	valid's auc: 0.966407
# [200]	train's auc: 0.990573	valid's auc: 0.966407
# [201]	train's auc: 0.990684	valid's auc: 0.966522
# [202]	train's auc: 0.990735	valid's auc: 0.966464
# [203]	train's auc: 0.990816	valid's auc: 0.966437
# [204]	train's auc: 0.990839	valid's auc: 0.966447
# [205]	train's auc: 0.990931	valid's auc: 0.966522
# [206]	train's auc: 0.990992	valid's auc: 0.966555
# [207]	train's auc: 0.99104	valid's auc: 0.966572
# [208]	train's auc: 0.991094	valid's auc: 0.96657
# [209]	train's auc: 0.991134	valid's auc: 0.966573
# [210]	train's auc: 0.991221	valid's auc: 0.966558
# [211]	train's auc: 0.991283	valid's auc: 0.966507
# [212]	train's auc: 0.991305	valid's auc: 0.966475
# [213]	train's auc: 0.991342	valid's auc: 0.966495
# [214]	train's auc: 0.991411	valid's auc: 0.966528
# [215]	train's auc: 0.991479	valid's auc: 0.966602
# [216]	train's auc: 0.991528	valid's auc: 0.966587
# [217]	train's auc: 0.991582	valid's auc: 0.966528
# [218]	train's auc: 0.991684	valid's auc: 0.966514
# [219]	train's auc: 0.991718	valid's auc: 0.966547
# [220]	train's auc: 0.991785	valid's auc: 0.966649
# [221]	train's auc: 0.991883	valid's auc: 0.966613
# [222]	train's auc: 0.991973	valid's auc: 0.96666
# [223]	train's auc: 0.992055	valid's auc: 0.966621
# [224]	train's auc: 0.992122	valid's auc: 0.966634
# [225]	train's auc: 0.992152	valid's auc: 0.966572
# [226]	train's auc: 0.99218	valid's auc: 0.966538
# [227]	train's auc: 0.99223	valid's auc: 0.966604
# [228]	train's auc: 0.992305	valid's auc: 0.966611
# [229]	train's auc: 0.992363	valid's auc: 0.966595
# [230]	train's auc: 0.992418	valid's auc: 0.966598
# [231]	train's auc: 0.992457	valid's auc: 0.966599
# [232]	train's auc: 0.992481	valid's auc: 0.966623
# [233]	train's auc: 0.99251	valid's auc: 0.966711
# [234]	train's auc: 0.992589	valid's auc: 0.966701
# [235]	train's auc: 0.992665	valid's auc: 0.966767
# [236]	train's auc: 0.99274	valid's auc: 0.966822
# [237]	train's auc: 0.9928	valid's auc: 0.966871
# [238]	train's auc: 0.992825	valid's auc: 0.966837
# [239]	train's auc: 0.992867	valid's auc: 0.966761
# [240]	train's auc: 0.992947	valid's auc: 0.966717
# [241]	train's auc: 0.99302	valid's auc: 0.966693
# [242]	train's auc: 0.99311	valid's auc: 0.966721
# [243]	train's auc: 0.993167	valid's auc: 0.966755
# [244]	train's auc: 0.993228	valid's auc: 0.966744
# [245]	train's auc: 0.993308	valid's auc: 0.96677
# [246]	train's auc: 0.993351	valid's auc: 0.966764
# [247]	train's auc: 0.993378	valid's auc: 0.966809
# [248]	train's auc: 0.993436	valid's auc: 0.966768
# [249]	train's auc: 0.9935	valid's auc: 0.966759
# [250]	train's auc: 0.993521	valid's auc: 0.966884
# [251]	train's auc: 0.993598	valid's auc: 0.966911
# [252]	train's auc: 0.993647	valid's auc: 0.966943
# [253]	train's auc: 0.993671	valid's auc: 0.966984
# [254]	train's auc: 0.993731	valid's auc: 0.967014
# [255]	train's auc: 0.993779	valid's auc: 0.967047
# [256]	train's auc: 0.993837	valid's auc: 0.967082
# [257]	train's auc: 0.993892	valid's auc: 0.967114
# [258]	train's auc: 0.993933	valid's auc: 0.967175
# [259]	train's auc: 0.993997	valid's auc: 0.967093
# [260]	train's auc: 0.994092	valid's auc: 0.967082
# [261]	train's auc: 0.994125	valid's auc: 0.967121
# [262]	train's auc: 0.994188	valid's auc: 0.967211
# [263]	train's auc: 0.994237	valid's auc: 0.967206
# [264]	train's auc: 0.994288	valid's auc: 0.967173
# [265]	train's auc: 0.994329	valid's auc: 0.967148
# [266]	train's auc: 0.994375	valid's auc: 0.967136
# [267]	train's auc: 0.994424	valid's auc: 0.967182
# [268]	train's auc: 0.994486	valid's auc: 0.967187
# [269]	train's auc: 0.994521	valid's auc: 0.967158
# [270]	train's auc: 0.994541	valid's auc: 0.967113
# [271]	train's auc: 0.994556	valid's auc: 0.967155
# [272]	train's auc: 0.994592	valid's auc: 0.967056
# [273]	train's auc: 0.994618	valid's auc: 0.967032
# [274]	train's auc: 0.994673	valid's auc: 0.967062
# [275]	train's auc: 0.994723	valid's auc: 0.966996
# [276]	train's auc: 0.994783	valid's auc: 0.966952
# [277]	train's auc: 0.994817	valid's auc: 0.966861
# [278]	train's auc: 0.994862	valid's auc: 0.96685
# [279]	train's auc: 0.994913	valid's auc: 0.966782
# [280]	train's auc: 0.994952	valid's auc: 0.966806
# [281]	train's auc: 0.995003	valid's auc: 0.966743
# [282]	train's auc: 0.995035	valid's auc: 0.966705
# [283]	train's auc: 0.995076	valid's auc: 0.966727
# [284]	train's auc: 0.995109	valid's auc: 0.966744
# [285]	train's auc: 0.995143	valid's auc: 0.966798
# [286]	train's auc: 0.995159	valid's auc: 0.966796
# [287]	train's auc: 0.995204	valid's auc: 0.966771
# [288]	train's auc: 0.995253	valid's auc: 0.966817
# [289]	train's auc: 0.99527	valid's auc: 0.966769
# [290]	train's auc: 0.99531	valid's auc: 0.966794
# [291]	train's auc: 0.995327	valid's auc: 0.966745
# [292]	train's auc: 0.995363	valid's auc: 0.966703
# [293]	train's auc: 0.99543	valid's auc: 0.96675
# [294]	train's auc: 0.995461	valid's auc: 0.966752
# [295]	train's auc: 0.99552	valid's auc: 0.966735
# [296]	train's auc: 0.995574	valid's auc: 0.966748
# [297]	train's auc: 0.995621	valid's auc: 0.966733
# [298]	train's auc: 0.995657	valid's auc: 0.966674
# [299]	train's auc: 0.995679	valid's auc: 0.966663
# [300]	train's auc: 0.995711	valid's auc: 0.966636
# [301]	train's auc: 0.995717	valid's auc: 0.96664
# [302]	train's auc: 0.995746	valid's auc: 0.966643
# [303]	train's auc: 0.995768	valid's auc: 0.966662
# [304]	train's auc: 0.995781	valid's auc: 0.966626
# [305]	train's auc: 0.995803	valid's auc: 0.966551
# [306]	train's auc: 0.995852	valid's auc: 0.966608
# [307]	train's auc: 0.995879	valid's auc: 0.966665
# [308]	train's auc: 0.995905	valid's auc: 0.966715
# [309]	train's auc: 0.995938	valid's auc: 0.966723
# [310]	train's auc: 0.995987	valid's auc: 0.966697
# [311]	train's auc: 0.996016	valid's auc: 0.966733
# [312]	train's auc: 0.996069	valid's auc: 0.966813
# [313]	train's auc: 0.996108	valid's auc: 0.966937
# [314]	train's auc: 0.996142	valid's auc: 0.966886
# [315]	train's auc: 0.996151	valid's auc: 0.966913
# [316]	train's auc: 0.996143	valid's auc: 0.966868
# [317]	train's auc: 0.996164	valid's auc: 0.966915
# [318]	train's auc: 0.996191	valid's auc: 0.966943
# [319]	train's auc: 0.996224	valid's auc: 0.966938
# [320]	train's auc: 0.996261	valid's auc: 0.9669
# [321]	train's auc: 0.996292	valid's auc: 0.966941
# [322]	train's auc: 0.996327	valid's auc: 0.966933
# [323]	train's auc: 0.996345	valid's auc: 0.966918
# [324]	train's auc: 0.996372	valid's auc: 0.966956
# [325]	train's auc: 0.996391	valid's auc: 0.966952
# [326]	train's auc: 0.996402	valid's auc: 0.966958
# [327]	train's auc: 0.996441	valid's auc: 0.966935
# [328]	train's auc: 0.996473	valid's auc: 0.966974
# [329]	train's auc: 0.996501	valid's auc: 0.966961
# [330]	train's auc: 0.996525	valid's auc: 0.967051
# [331]	train's auc: 0.996545	valid's auc: 0.967047
# [332]	train's auc: 0.99657	valid's auc: 0.967102
# [333]	train's auc: 0.996599	valid's auc: 0.967127
# [334]	train's auc: 0.996616	valid's auc: 0.967219
# [335]	train's auc: 0.996626	valid's auc: 0.967196
# [336]	train's auc: 0.99667	valid's auc: 0.967213
# [337]	train's auc: 0.996682	valid's auc: 0.967207
# [338]	train's auc: 0.9967	valid's auc: 0.967251
# [339]	train's auc: 0.996735	valid's auc: 0.967227
# [340]	train's auc: 0.996778	valid's auc: 0.967201
# [341]	train's auc: 0.996791	valid's auc: 0.967219
# [342]	train's auc: 0.996808	valid's auc: 0.967267
# [343]	train's auc: 0.996834	valid's auc: 0.967309
# [344]	train's auc: 0.996865	valid's auc: 0.96738
# [345]	train's auc: 0.996889	valid's auc: 0.967448
# [346]	train's auc: 0.996894	valid's auc: 0.967399
# [347]	train's auc: 0.996897	valid's auc: 0.967373
# [348]	train's auc: 0.996928	valid's auc: 0.967305
# [349]	train's auc: 0.996949	valid's auc: 0.967322
# [350]	train's auc: 0.996948	valid's auc: 0.967337
# [351]	train's auc: 0.996962	valid's auc: 0.967365
# [352]	train's auc: 0.996982	valid's auc: 0.967373
# [353]	train's auc: 0.997013	valid's auc: 0.967379
# [354]	train's auc: 0.997051	valid's auc: 0.967331
# [355]	train's auc: 0.997079	valid's auc: 0.967367
# [356]	train's auc: 0.997101	valid's auc: 0.967339
# [357]	train's auc: 0.997108	valid's auc: 0.967425
# [358]	train's auc: 0.997113	valid's auc: 0.967438
# [359]	train's auc: 0.997146	valid's auc: 0.967461
# [360]	train's auc: 0.997164	valid's auc: 0.967474
# [361]	train's auc: 0.997193	valid's auc: 0.967444
# [362]	train's auc: 0.997213	valid's auc: 0.967513
# [363]	train's auc: 0.997219	valid's auc: 0.967493
# [364]	train's auc: 0.997228	valid's auc: 0.967439
# [365]	train's auc: 0.99725	valid's auc: 0.967468
# [366]	train's auc: 0.997266	valid's auc: 0.967461
# [367]	train's auc: 0.997291	valid's auc: 0.967442
# [368]	train's auc: 0.997329	valid's auc: 0.96745
# [369]	train's auc: 0.997334	valid's auc: 0.967434
# [370]	train's auc: 0.997367	valid's auc: 0.967505
# [371]	train's auc: 0.99737	valid's auc: 0.967438
# [372]	train's auc: 0.997387	valid's auc: 0.967487
# [373]	train's auc: 0.997414	valid's auc: 0.967489
# [374]	train's auc: 0.997434	valid's auc: 0.967537
# [375]	train's auc: 0.997456	valid's auc: 0.967583
# [376]	train's auc: 0.997475	valid's auc: 0.967697
# [377]	train's auc: 0.997499	valid's auc: 0.967677
# [378]	train's auc: 0.997533	valid's auc: 0.967716
# [379]	train's auc: 0.997546	valid's auc: 0.967674
# [380]	train's auc: 0.997561	valid's auc: 0.967667
# [381]	train's auc: 0.997576	valid's auc: 0.967723
# [382]	train's auc: 0.997594	valid's auc: 0.967704
# [383]	train's auc: 0.997616	valid's auc: 0.967742
# [384]	train's auc: 0.997639	valid's auc: 0.967737
# [385]	train's auc: 0.997656	valid's auc: 0.967717
# [386]	train's auc: 0.997676	valid's auc: 0.96768
# [387]	train's auc: 0.997696	valid's auc: 0.967711
# [388]	train's auc: 0.997708	valid's auc: 0.967705
# [389]	train's auc: 0.997718	valid's auc: 0.967717
# [390]	train's auc: 0.997737	valid's auc: 0.967682
# [391]	train's auc: 0.997751	valid's auc: 0.967714
# [392]	train's auc: 0.997774	valid's auc: 0.967759
# [393]	train's auc: 0.997786	valid's auc: 0.9677
# [394]	train's auc: 0.997793	valid's auc: 0.967696
# [395]	train's auc: 0.997792	valid's auc: 0.967693
# [396]	train's auc: 0.997808	valid's auc: 0.967666
# [397]	train's auc: 0.997834	valid's auc: 0.967641
# [398]	train's auc: 0.997855	valid's auc: 0.967612
# [399]	train's auc: 0.997869	valid's auc: 0.967571
# [400]	train's auc: 0.997872	valid's auc: 0.967595
# [401]	train's auc: 0.997886	valid's auc: 0.967594
# [402]	train's auc: 0.997909	valid's auc: 0.967567
# [403]	train's auc: 0.997912	valid's auc: 0.967558
# [404]	train's auc: 0.997925	valid's auc: 0.967613
# [405]	train's auc: 0.997941	valid's auc: 0.967625
# [406]	train's auc: 0.997956	valid's auc: 0.967646
# [407]	train's auc: 0.997968	valid's auc: 0.967646
# [408]	train's auc: 0.997979	valid's auc: 0.967663
# [409]	train's auc: 0.997994	valid's auc: 0.967713
# [410]	train's auc: 0.997999	valid's auc: 0.967713
# [411]	train's auc: 0.998007	valid's auc: 0.967746
# [412]	train's auc: 0.99802	valid's auc: 0.967752
# [413]	train's auc: 0.998032	valid's auc: 0.967737
# [414]	train's auc: 0.998044	valid's auc: 0.967765
# [415]	train's auc: 0.998065	valid's auc: 0.967785
# [416]	train's auc: 0.99809	valid's auc: 0.967761
# [417]	train's auc: 0.998098	valid's auc: 0.967773
# [418]	train's auc: 0.998107	valid's auc: 0.967748
# [419]	train's auc: 0.998124	valid's auc: 0.967757
# [420]	train's auc: 0.998146	valid's auc: 0.967791
# [421]	train's auc: 0.998159	valid's auc: 0.967777
# [422]	train's auc: 0.99818	valid's auc: 0.967824
# [423]	train's auc: 0.998201	valid's auc: 0.967844
# [424]	train's auc: 0.998215	valid's auc: 0.967797
# [425]	train's auc: 0.998226	valid's auc: 0.967762
# [426]	train's auc: 0.998242	valid's auc: 0.967769
# [427]	train's auc: 0.998257	valid's auc: 0.967707
# [428]	train's auc: 0.998264	valid's auc: 0.967751
# [429]	train's auc: 0.998281	valid's auc: 0.967684
# [430]	train's auc: 0.998293	valid's auc: 0.967701
# [431]	train's auc: 0.998305	valid's auc: 0.967712
# [432]	train's auc: 0.998318	valid's auc: 0.967766
# [433]	train's auc: 0.998335	valid's auc: 0.967806
# [434]	train's auc: 0.998364	valid's auc: 0.96775
# [435]	train's auc: 0.998363	valid's auc: 0.967762
# [436]	train's auc: 0.99837	valid's auc: 0.967787
# [437]	train's auc: 0.998383	valid's auc: 0.967798
# [438]	train's auc: 0.998397	valid's auc: 0.967743
# [439]	train's auc: 0.998407	valid's auc: 0.967713
# [440]	train's auc: 0.998431	valid's auc: 0.967653
# [441]	train's auc: 0.998438	valid's auc: 0.967632
# [442]	train's auc: 0.998442	valid's auc: 0.967611
# [443]	train's auc: 0.998453	valid's auc: 0.967618
# [444]	train's auc: 0.998469	valid's auc: 0.967587
# [445]	train's auc: 0.998486	valid's auc: 0.967692
# [446]	train's auc: 0.998499	valid's auc: 0.967674
# [447]	train's auc: 0.998507	valid's auc: 0.967625
# [448]	train's auc: 0.998518	valid's auc: 0.967638
# [449]	train's auc: 0.99853	valid's auc: 0.967591
# [450]	train's auc: 0.998537	valid's auc: 0.967613
# [451]	train's auc: 0.998544	valid's auc: 0.967649
# [452]	train's auc: 0.998559	valid's auc: 0.967655
# [453]	train's auc: 0.998564	valid's auc: 0.967683
# [454]	train's auc: 0.998581	valid's auc: 0.967708
# [455]	train's auc: 0.998596	valid's auc: 0.96771
# [456]	train's auc: 0.9986	valid's auc: 0.96768
# [457]	train's auc: 0.9986	valid's auc: 0.967672
# [458]	train's auc: 0.998611	valid's auc: 0.967701
# [459]	train's auc: 0.998617	valid's auc: 0.967685
# [460]	train's auc: 0.998619	valid's auc: 0.967782
# [461]	train's auc: 0.998642	valid's auc: 0.967764
# [462]	train's auc: 0.998643	valid's auc: 0.967717
# [463]	train's auc: 0.998652	valid's auc: 0.967724
# [464]	train's auc: 0.998663	valid's auc: 0.967733
# [465]	train's auc: 0.99867	valid's auc: 0.967725
# [466]	train's auc: 0.998681	valid's auc: 0.967782
# [467]	train's auc: 0.998699	valid's auc: 0.967766
# [468]	train's auc: 0.998705	valid's auc: 0.967739
# [469]	train's auc: 0.998711	valid's auc: 0.967728
# [470]	train's auc: 0.998716	valid's auc: 0.967717
# [471]	train's auc: 0.998727	valid's auc: 0.967721
# [472]	train's auc: 0.998733	valid's auc: 0.967701
# [473]	train's auc: 0.998744	valid's auc: 0.967692
# [474]	train's auc: 0.998751	valid's auc: 0.967688
# [475]	train's auc: 0.99876	valid's auc: 0.967694
# [476]	train's auc: 0.998771	valid's auc: 0.967643
# [477]	train's auc: 0.998781	valid's auc: 0.967666
# [478]	train's auc: 0.998795	valid's auc: 0.967683
# [479]	train's auc: 0.998808	valid's auc: 0.967656
# [480]	train's auc: 0.998811	valid's auc: 0.96771
# [481]	train's auc: 0.998823	valid's auc: 0.967698
# [482]	train's auc: 0.998835	valid's auc: 0.967726
# [483]	train's auc: 0.99884	valid's auc: 0.967731
# [484]	train's auc: 0.998848	valid's auc: 0.967767
# [485]	train's auc: 0.998851	valid's auc: 0.967756
# [486]	train's auc: 0.998855	valid's auc: 0.967732
# [487]	train's auc: 0.998877	valid's auc: 0.967765
# [488]	train's auc: 0.998885	valid's auc: 0.967783
# [489]	train's auc: 0.998892	valid's auc: 0.96778
# [490]	train's auc: 0.998898	valid's auc: 0.967828
# [491]	train's auc: 0.998899	valid's auc: 0.96784
# [492]	train's auc: 0.998903	valid's auc: 0.967863
# [493]	train's auc: 0.998919	valid's auc: 0.967868
# [494]	train's auc: 0.998924	valid's auc: 0.967899
# [495]	train's auc: 0.99894	valid's auc: 0.967898
# [496]	train's auc: 0.998955	valid's auc: 0.967901
# [497]	train's auc: 0.998962	valid's auc: 0.96795
# [498]	train's auc: 0.998972	valid's auc: 0.967983
# [499]	train's auc: 0.998985	valid's auc: 0.96798
# [500]	train's auc: 0.998985	valid's auc: 0.967987
# Did not meet early stopping. Best iteration is:
# [500]	train's auc: 0.998985	valid's auc: 0.967987
# The 0 kfold score : 0.7471411901983663
# [1]	train's auc: 0.870584	valid's auc: 0.877856
# Training until validation scores don't improve for 100 rounds.
# [2]	train's auc: 0.897402	valid's auc: 0.900435
# [3]	train's auc: 0.902959	valid's auc: 0.904302
# [4]	train's auc: 0.907894	valid's auc: 0.909955
# [5]	train's auc: 0.919187	valid's auc: 0.921749
# [6]	train's auc: 0.927154	valid's auc: 0.926858
# [7]	train's auc: 0.930713	valid's auc: 0.933244
# [8]	train's auc: 0.933392	valid's auc: 0.935719
# [9]	train's auc: 0.935841	valid's auc: 0.937279
# [10]	train's auc: 0.93983	valid's auc: 0.941547
# [11]	train's auc: 0.941146	valid's auc: 0.943856
# [12]	train's auc: 0.943609	valid's auc: 0.945109
# [13]	train's auc: 0.944083	valid's auc: 0.945775
# [14]	train's auc: 0.94582	valid's auc: 0.946784
# [15]	train's auc: 0.948336	valid's auc: 0.949463
# [16]	train's auc: 0.949015	valid's auc: 0.949819
# [17]	train's auc: 0.949796	valid's auc: 0.949362
# [18]	train's auc: 0.950386	valid's auc: 0.950159
# [19]	train's auc: 0.951667	valid's auc: 0.951995
# [20]	train's auc: 0.952758	valid's auc: 0.952758
# [21]	train's auc: 0.953761	valid's auc: 0.953475
# [22]	train's auc: 0.954089	valid's auc: 0.953051
# [23]	train's auc: 0.954919	valid's auc: 0.954006
# [24]	train's auc: 0.955917	valid's auc: 0.954959
# [25]	train's auc: 0.956263	valid's auc: 0.955078
# [26]	train's auc: 0.956958	valid's auc: 0.955612
# [27]	train's auc: 0.957117	valid's auc: 0.955636
# [28]	train's auc: 0.957693	valid's auc: 0.955999
# [29]	train's auc: 0.958329	valid's auc: 0.956227
# [30]	train's auc: 0.958776	valid's auc: 0.956518
# [31]	train's auc: 0.959258	valid's auc: 0.956906
# [32]	train's auc: 0.959646	valid's auc: 0.957208
# [33]	train's auc: 0.960278	valid's auc: 0.957448
# [34]	train's auc: 0.960872	valid's auc: 0.958101
# [35]	train's auc: 0.961454	valid's auc: 0.958464
# [36]	train's auc: 0.9617	valid's auc: 0.958677
# [37]	train's auc: 0.962105	valid's auc: 0.958907
# [38]	train's auc: 0.962717	valid's auc: 0.959571
# [39]	train's auc: 0.96317	valid's auc: 0.959976
# [40]	train's auc: 0.963574	valid's auc: 0.960244
# [41]	train's auc: 0.963979	valid's auc: 0.96062
# [42]	train's auc: 0.964452	valid's auc: 0.960931
# [43]	train's auc: 0.964928	valid's auc: 0.961047
# [44]	train's auc: 0.965347	valid's auc: 0.961338
# [45]	train's auc: 0.965767	valid's auc: 0.962076
# [46]	train's auc: 0.966149	valid's auc: 0.96244
# [47]	train's auc: 0.966569	valid's auc: 0.963016
# [48]	train's auc: 0.96682	valid's auc: 0.963174
# [49]	train's auc: 0.967243	valid's auc: 0.963253
# [50]	train's auc: 0.967604	valid's auc: 0.963432
# [51]	train's auc: 0.968024	valid's auc: 0.963892
# [52]	train's auc: 0.968255	valid's auc: 0.96398
# [53]	train's auc: 0.968568	valid's auc: 0.964225
# [54]	train's auc: 0.968892	valid's auc: 0.964254
# [55]	train's auc: 0.969248	valid's auc: 0.964378
# [56]	train's auc: 0.969593	valid's auc: 0.964187
# [57]	train's auc: 0.970036	valid's auc: 0.964541
# [58]	train's auc: 0.97033	valid's auc: 0.964673
# [59]	train's auc: 0.970614	valid's auc: 0.964668
# [60]	train's auc: 0.970971	valid's auc: 0.96514
# [61]	train's auc: 0.97132	valid's auc: 0.965171
# [62]	train's auc: 0.971542	valid's auc: 0.965205
# [63]	train's auc: 0.971816	valid's auc: 0.965293
# [64]	train's auc: 0.972044	valid's auc: 0.965672
# [65]	train's auc: 0.972298	valid's auc: 0.965885
# [66]	train's auc: 0.972621	valid's auc: 0.965997
# [67]	train's auc: 0.972932	valid's auc: 0.965914
# [68]	train's auc: 0.973204	valid's auc: 0.966134
# [69]	train's auc: 0.973485	valid's auc: 0.966455
# [70]	train's auc: 0.973725	valid's auc: 0.966588
# [71]	train's auc: 0.974071	valid's auc: 0.966683
# [72]	train's auc: 0.974372	valid's auc: 0.966861
# [73]	train's auc: 0.974586	valid's auc: 0.966831
# [74]	train's auc: 0.974814	valid's auc: 0.966903
# [75]	train's auc: 0.975013	valid's auc: 0.967071
# [76]	train's auc: 0.975244	valid's auc: 0.967231
# [77]	train's auc: 0.975475	valid's auc: 0.967338
# [78]	train's auc: 0.97567	valid's auc: 0.967322
# [79]	train's auc: 0.975852	valid's auc: 0.967521
# [80]	train's auc: 0.976086	valid's auc: 0.967745
# [81]	train's auc: 0.976283	valid's auc: 0.967811
# [82]	train's auc: 0.976501	valid's auc: 0.967862
# [83]	train's auc: 0.976693	valid's auc: 0.968034
# [84]	train's auc: 0.976914	valid's auc: 0.968066
# [85]	train's auc: 0.977023	valid's auc: 0.968184
# [86]	train's auc: 0.977219	valid's auc: 0.968327
# [87]	train's auc: 0.977438	valid's auc: 0.968246
# [88]	train's auc: 0.977566	valid's auc: 0.968308
# [89]	train's auc: 0.977777	valid's auc: 0.968434
# [90]	train's auc: 0.978003	valid's auc: 0.968461
# [91]	train's auc: 0.978197	valid's auc: 0.968422
# [92]	train's auc: 0.978374	valid's auc: 0.968502
# [93]	train's auc: 0.978672	valid's auc: 0.968661
# [94]	train's auc: 0.978804	valid's auc: 0.968808
# [95]	train's auc: 0.978903	valid's auc: 0.968966
# [96]	train's auc: 0.979043	valid's auc: 0.969079
# [97]	train's auc: 0.979222	valid's auc: 0.969053
# [98]	train's auc: 0.979378	valid's auc: 0.969069
# [99]	train's auc: 0.979619	valid's auc: 0.969177
# [100]	train's auc: 0.979757	valid's auc: 0.969213
# [101]	train's auc: 0.979935	valid's auc: 0.969286
# [102]	train's auc: 0.98021	valid's auc: 0.969267
# [103]	train's auc: 0.980276	valid's auc: 0.969301
# [104]	train's auc: 0.980399	valid's auc: 0.969347
# [105]	train's auc: 0.980549	valid's auc: 0.969349
# [106]	train's auc: 0.980741	valid's auc: 0.969526
# [107]	train's auc: 0.980943	valid's auc: 0.969598
# [108]	train's auc: 0.981202	valid's auc: 0.969681
# [109]	train's auc: 0.981318	valid's auc: 0.969515
# [110]	train's auc: 0.981475	valid's auc: 0.969621
# [111]	train's auc: 0.981638	valid's auc: 0.969675
# [112]	train's auc: 0.98178	valid's auc: 0.969843
# [113]	train's auc: 0.981951	valid's auc: 0.969792
# [114]	train's auc: 0.982094	valid's auc: 0.969629
# [115]	train's auc: 0.98222	valid's auc: 0.969659
# [116]	train's auc: 0.982404	valid's auc: 0.969804
# [117]	train's auc: 0.982541	valid's auc: 0.969839
# [118]	train's auc: 0.982714	valid's auc: 0.969956
# [119]	train's auc: 0.982835	valid's auc: 0.970113
# [120]	train's auc: 0.982969	valid's auc: 0.970003
# [121]	train's auc: 0.983061	valid's auc: 0.969975
# [122]	train's auc: 0.983205	valid's auc: 0.970048
# [123]	train's auc: 0.983315	valid's auc: 0.970105
# [124]	train's auc: 0.98342	valid's auc: 0.970019
# [125]	train's auc: 0.983587	valid's auc: 0.969979
# [126]	train's auc: 0.983727	valid's auc: 0.970037
# [127]	train's auc: 0.983839	valid's auc: 0.970007
# [128]	train's auc: 0.983916	valid's auc: 0.970075
# [129]	train's auc: 0.984008	valid's auc: 0.970123
# [130]	train's auc: 0.984114	valid's auc: 0.970095
# [131]	train's auc: 0.984286	valid's auc: 0.969894
# [132]	train's auc: 0.984419	valid's auc: 0.969911
# [133]	train's auc: 0.984547	valid's auc: 0.969985
# [134]	train's auc: 0.984647	valid's auc: 0.970022
# [135]	train's auc: 0.984723	valid's auc: 0.97007
# [136]	train's auc: 0.984891	valid's auc: 0.970077
# [137]	train's auc: 0.98504	valid's auc: 0.970063
# [138]	train's auc: 0.98518	valid's auc: 0.97013
# [139]	train's auc: 0.985293	valid's auc: 0.970189
# [140]	train's auc: 0.985413	valid's auc: 0.970189
# [141]	train's auc: 0.985506	valid's auc: 0.970215
# [142]	train's auc: 0.985609	valid's auc: 0.970143
# [143]	train's auc: 0.985747	valid's auc: 0.970192
# [144]	train's auc: 0.985859	valid's auc: 0.970225
# [145]	train's auc: 0.985992	valid's auc: 0.970188
# [146]	train's auc: 0.986119	valid's auc: 0.970225
# [147]	train's auc: 0.986214	valid's auc: 0.970211
# [148]	train's auc: 0.986299	valid's auc: 0.970147
# [149]	train's auc: 0.986452	valid's auc: 0.970211
# [150]	train's auc: 0.986511	valid's auc: 0.97021
# [151]	train's auc: 0.986634	valid's auc: 0.9702
# [152]	train's auc: 0.986736	valid's auc: 0.970226
# [153]	train's auc: 0.986819	valid's auc: 0.9703
# [154]	train's auc: 0.986942	valid's auc: 0.970208
# [155]	train's auc: 0.987092	valid's auc: 0.970133
# [156]	train's auc: 0.98724	valid's auc: 0.970193
# [157]	train's auc: 0.987369	valid's auc: 0.970238
# [158]	train's auc: 0.98745	valid's auc: 0.970214
# [159]	train's auc: 0.987493	valid's auc: 0.970225
# [160]	train's auc: 0.987599	valid's auc: 0.970189
# [161]	train's auc: 0.987686	valid's auc: 0.970149
# [162]	train's auc: 0.987824	valid's auc: 0.970109
# [163]	train's auc: 0.987883	valid's auc: 0.970028
# [164]	train's auc: 0.987975	valid's auc: 0.969999
# [165]	train's auc: 0.988056	valid's auc: 0.970137
# [166]	train's auc: 0.988183	valid's auc: 0.970143
# [167]	train's auc: 0.988266	valid's auc: 0.970169
# [168]	train's auc: 0.988354	valid's auc: 0.97025
# [169]	train's auc: 0.988443	valid's auc: 0.970146
# [170]	train's auc: 0.98858	valid's auc: 0.970176
# [171]	train's auc: 0.98868	valid's auc: 0.970169
# [172]	train's auc: 0.988795	valid's auc: 0.970281
# [173]	train's auc: 0.988929	valid's auc: 0.970307
# [174]	train's auc: 0.989008	valid's auc: 0.970406
# [175]	train's auc: 0.989062	valid's auc: 0.970371
# [176]	train's auc: 0.989132	valid's auc: 0.970412
# [177]	train's auc: 0.989212	valid's auc: 0.970446
# [178]	train's auc: 0.989283	valid's auc: 0.97037
# [179]	train's auc: 0.989371	valid's auc: 0.970476
# [180]	train's auc: 0.989435	valid's auc: 0.970492
# [181]	train's auc: 0.98946	valid's auc: 0.970386
# [182]	train's auc: 0.989516	valid's auc: 0.970494
# [183]	train's auc: 0.989583	valid's auc: 0.97057
# [184]	train's auc: 0.989663	valid's auc: 0.970604
# [185]	train's auc: 0.989771	valid's auc: 0.970601
# [186]	train's auc: 0.989873	valid's auc: 0.970617
# [187]	train's auc: 0.989949	valid's auc: 0.970648
# [188]	train's auc: 0.990086	valid's auc: 0.970721
# [189]	train's auc: 0.99016	valid's auc: 0.970724
# [190]	train's auc: 0.990258	valid's auc: 0.970674
# [191]	train's auc: 0.990315	valid's auc: 0.970727
# [192]	train's auc: 0.990357	valid's auc: 0.97077
# [193]	train's auc: 0.990425	valid's auc: 0.970676
# [194]	train's auc: 0.990481	valid's auc: 0.970615
# [195]	train's auc: 0.990591	valid's auc: 0.970524
# [196]	train's auc: 0.990641	valid's auc: 0.97052
# [197]	train's auc: 0.990721	valid's auc: 0.970407
# [198]	train's auc: 0.990768	valid's auc: 0.970435
# [199]	train's auc: 0.990852	valid's auc: 0.970482
# [200]	train's auc: 0.990899	valid's auc: 0.970532
# [201]	train's auc: 0.990937	valid's auc: 0.970501
# [202]	train's auc: 0.990988	valid's auc: 0.9705
# [203]	train's auc: 0.991048	valid's auc: 0.970518
# [204]	train's auc: 0.991088	valid's auc: 0.970469
# [205]	train's auc: 0.991145	valid's auc: 0.970458
# [206]	train's auc: 0.991185	valid's auc: 0.970526
# [207]	train's auc: 0.991256	valid's auc: 0.970554
# [208]	train's auc: 0.991331	valid's auc: 0.970664
# [209]	train's auc: 0.991378	valid's auc: 0.970681
# [210]	train's auc: 0.991457	valid's auc: 0.970607
# [211]	train's auc: 0.991549	valid's auc: 0.970666
# [212]	train's auc: 0.991622	valid's auc: 0.970814
# [213]	train's auc: 0.991689	valid's auc: 0.970839
# [214]	train's auc: 0.991774	valid's auc: 0.970768
# [215]	train's auc: 0.99182	valid's auc: 0.970798
# [216]	train's auc: 0.99188	valid's auc: 0.970833
# [217]	train's auc: 0.991987	valid's auc: 0.970953
# [218]	train's auc: 0.992032	valid's auc: 0.970997
# [219]	train's auc: 0.992075	valid's auc: 0.971017
# [220]	train's auc: 0.992157	valid's auc: 0.971016
# [221]	train's auc: 0.992198	valid's auc: 0.971004
# [222]	train's auc: 0.992283	valid's auc: 0.970999
# [223]	train's auc: 0.99233	valid's auc: 0.971005
# [224]	train's auc: 0.992392	valid's auc: 0.971037
# [225]	train's auc: 0.992474	valid's auc: 0.971014
# [226]	train's auc: 0.992541	valid's auc: 0.970965
# [227]	train's auc: 0.992591	valid's auc: 0.971009
# [228]	train's auc: 0.992637	valid's auc: 0.971032
# [229]	train's auc: 0.992734	valid's auc: 0.971007
# [230]	train's auc: 0.992786	valid's auc: 0.971031
# [231]	train's auc: 0.992836	valid's auc: 0.970975
# [232]	train's auc: 0.992899	valid's auc: 0.971073
# [233]	train's auc: 0.992951	valid's auc: 0.97118
# [234]	train's auc: 0.99299	valid's auc: 0.97113
# [235]	train's auc: 0.993082	valid's auc: 0.971166
# [236]	train's auc: 0.993156	valid's auc: 0.971128
# [237]	train's auc: 0.993198	valid's auc: 0.971081
# [238]	train's auc: 0.993274	valid's auc: 0.9711
# [239]	train's auc: 0.99331	valid's auc: 0.97112
# [240]	train's auc: 0.993349	valid's auc: 0.971078
# [241]	train's auc: 0.993389	valid's auc: 0.97103
# [242]	train's auc: 0.993453	valid's auc: 0.971005
# [243]	train's auc: 0.993487	valid's auc: 0.971021
# [244]	train's auc: 0.993518	valid's auc: 0.971036
# [245]	train's auc: 0.99356	valid's auc: 0.971045
# [246]	train's auc: 0.993575	valid's auc: 0.971085
# [247]	train's auc: 0.99362	valid's auc: 0.971153
# [248]	train's auc: 0.993661	valid's auc: 0.97116
# [249]	train's auc: 0.993695	valid's auc: 0.971177
# [250]	train's auc: 0.993713	valid's auc: 0.971221
# [251]	train's auc: 0.993766	valid's auc: 0.971258
# [252]	train's auc: 0.993828	valid's auc: 0.971284
# [253]	train's auc: 0.993858	valid's auc: 0.971321
# [254]	train's auc: 0.993892	valid's auc: 0.971334
# [255]	train's auc: 0.993933	valid's auc: 0.97136
# [256]	train's auc: 0.993968	valid's auc: 0.97138
# [257]	train's auc: 0.993983	valid's auc: 0.971374
# [258]	train's auc: 0.994029	valid's auc: 0.971394
# [259]	train's auc: 0.994104	valid's auc: 0.9714
# [260]	train's auc: 0.994153	valid's auc: 0.971404
# [261]	train's auc: 0.994192	valid's auc: 0.971495
# [262]	train's auc: 0.994221	valid's auc: 0.971541
# [263]	train's auc: 0.994274	valid's auc: 0.971581
# [264]	train's auc: 0.994297	valid's auc: 0.971636
# [265]	train's auc: 0.994346	valid's auc: 0.971646
# [266]	train's auc: 0.994407	valid's auc: 0.971621
# [267]	train's auc: 0.994462	valid's auc: 0.971631
# [268]	train's auc: 0.994528	valid's auc: 0.971653
# [269]	train's auc: 0.994549	valid's auc: 0.971588
# [270]	train's auc: 0.994602	valid's auc: 0.971594
# [271]	train's auc: 0.994636	valid's auc: 0.971612
# [272]	train's auc: 0.994671	valid's auc: 0.971574
# [273]	train's auc: 0.994681	valid's auc: 0.971604
# [274]	train's auc: 0.994721	valid's auc: 0.971711
# [275]	train's auc: 0.994763	valid's auc: 0.971769
# [276]	train's auc: 0.994835	valid's auc: 0.971704
# [277]	train's auc: 0.994845	valid's auc: 0.971767
# [278]	train's auc: 0.994889	valid's auc: 0.971784
# [279]	train's auc: 0.994979	valid's auc: 0.971839
# [280]	train's auc: 0.995018	valid's auc: 0.971817
# [281]	train's auc: 0.995038	valid's auc: 0.97183
# [282]	train's auc: 0.995078	valid's auc: 0.971827
# [283]	train's auc: 0.995107	valid's auc: 0.971777
# [284]	train's auc: 0.995141	valid's auc: 0.971761
# [285]	train's auc: 0.995169	valid's auc: 0.971796
# [286]	train's auc: 0.995209	valid's auc: 0.971799
# [287]	train's auc: 0.995258	valid's auc: 0.971776
# [288]	train's auc: 0.995284	valid's auc: 0.971768
# [289]	train's auc: 0.995375	valid's auc: 0.971723
# [290]	train's auc: 0.995409	valid's auc: 0.971731
# [291]	train's auc: 0.99545	valid's auc: 0.971677
# [292]	train's auc: 0.995496	valid's auc: 0.971566
# [293]	train's auc: 0.995522	valid's auc: 0.971563
# [294]	train's auc: 0.995552	valid's auc: 0.971511
# [295]	train's auc: 0.995583	valid's auc: 0.971489
# [296]	train's auc: 0.995613	valid's auc: 0.971415
# [297]	train's auc: 0.995654	valid's auc: 0.971392
# [298]	train's auc: 0.99567	valid's auc: 0.971314
# [299]	train's auc: 0.995693	valid's auc: 0.971263
# [300]	train's auc: 0.995709	valid's auc: 0.971287
# [301]	train's auc: 0.995758	valid's auc: 0.971262
# [302]	train's auc: 0.995792	valid's auc: 0.971175
# [303]	train's auc: 0.995832	valid's auc: 0.971204
# [304]	train's auc: 0.995849	valid's auc: 0.971152
# [305]	train's auc: 0.995906	valid's auc: 0.971186
# [306]	train's auc: 0.995947	valid's auc: 0.971203
# [307]	train's auc: 0.995963	valid's auc: 0.97119
# [308]	train's auc: 0.996026	valid's auc: 0.971213
# [309]	train's auc: 0.99607	valid's auc: 0.971209
# [310]	train's auc: 0.996098	valid's auc: 0.971241
# [311]	train's auc: 0.996129	valid's auc: 0.97127
# [312]	train's auc: 0.996153	valid's auc: 0.971198
# [313]	train's auc: 0.996161	valid's auc: 0.971218
# [314]	train's auc: 0.996182	valid's auc: 0.97125
# [315]	train's auc: 0.996203	valid's auc: 0.971252
# [316]	train's auc: 0.996263	valid's auc: 0.971169
# [317]	train's auc: 0.996274	valid's auc: 0.971168
# [318]	train's auc: 0.996299	valid's auc: 0.971112
# [319]	train's auc: 0.99632	valid's auc: 0.971133
# [320]	train's auc: 0.99637	valid's auc: 0.971133
# [321]	train's auc: 0.9964	valid's auc: 0.971144
# [322]	train's auc: 0.996465	valid's auc: 0.971072
# [323]	train's auc: 0.996497	valid's auc: 0.971139
# [324]	train's auc: 0.996519	valid's auc: 0.971188
# [325]	train's auc: 0.996544	valid's auc: 0.971243
# [326]	train's auc: 0.996575	valid's auc: 0.971196
# [327]	train's auc: 0.996584	valid's auc: 0.971221
# [328]	train's auc: 0.996591	valid's auc: 0.971271
# [329]	train's auc: 0.996613	valid's auc: 0.971282
# [330]	train's auc: 0.996621	valid's auc: 0.971252
# [331]	train's auc: 0.99666	valid's auc: 0.971221
# [332]	train's auc: 0.996681	valid's auc: 0.971241
# [333]	train's auc: 0.996693	valid's auc: 0.971188
# [334]	train's auc: 0.996723	valid's auc: 0.971195
# [335]	train's auc: 0.996748	valid's auc: 0.971208
# [336]	train's auc: 0.996764	valid's auc: 0.971261
# [337]	train's auc: 0.996787	valid's auc: 0.971276
# [338]	train's auc: 0.996808	valid's auc: 0.971237
# [339]	train's auc: 0.996863	valid's auc: 0.971295
# [340]	train's auc: 0.996885	valid's auc: 0.971196
# [341]	train's auc: 0.99691	valid's auc: 0.971179
# [342]	train's auc: 0.996927	valid's auc: 0.971167
# [343]	train's auc: 0.996955	valid's auc: 0.971066
# [344]	train's auc: 0.996969	valid's auc: 0.97112
# [345]	train's auc: 0.996994	valid's auc: 0.971157
# [346]	train's auc: 0.997053	valid's auc: 0.971107
# [347]	train's auc: 0.99707	valid's auc: 0.971106
# [348]	train's auc: 0.997096	valid's auc: 0.971101
# [349]	train's auc: 0.997113	valid's auc: 0.971142
# [350]	train's auc: 0.997166	valid's auc: 0.971211
# [351]	train's auc: 0.997192	valid's auc: 0.971245
# [352]	train's auc: 0.997219	valid's auc: 0.971169
# [353]	train's auc: 0.997237	valid's auc: 0.971162
# [354]	train's auc: 0.997262	valid's auc: 0.971183
# [355]	train's auc: 0.997293	valid's auc: 0.971166
# [356]	train's auc: 0.997311	valid's auc: 0.971189
# ...
# [36]	train's auc: 0.961969	valid's auc: 0.954838
# [37]	train's auc: 0.962392	valid's auc: 0.955227
# [38]	train's auc: 0.963055	valid's auc: 0.955615
# [39]	train's auc: 0.963373	valid's auc: 0.955987
# [40]	train's auc: 0.963852	valid's auc: 0.956258
# [41]	train's auc: 0.964359	valid's auc: 0.956477
# [42]	train's auc: 0.964727	valid's auc: 0.956904
# [43]	train's auc: 0.965397	valid's auc: 0.957486
# [44]	train's auc: 0.965768	valid's auc: 0.957701
# [45]	train's auc: 0.966193	valid's auc: 0.957997
# [46]	train's auc: 0.966568	valid's auc: 0.958479
# [47]	train's auc: 0.96699	valid's auc: 0.958778
# [48]	train's auc: 0.967418	valid's auc: 0.959104
# [49]	train's auc: 0.967771	valid's auc: 0.959359
# [50]	train's auc: 0.968057	valid's auc: 0.959591
# [51]	train's auc: 0.968387	valid's auc: 0.959842
# [52]	train's auc: 0.968682	valid's auc: 0.96024
# [53]	train's auc: 0.969123	valid's auc: 0.960664
# [54]	train's auc: 0.969349	valid's auc: 0.960642
# [55]	train's auc: 0.96969	valid's auc: 0.961129
# [56]	train's auc: 0.969899	valid's auc: 0.961304
# [57]	train's auc: 0.970211	valid's auc: 0.961748
# [58]	train's auc: 0.97049	valid's auc: 0.96173
# [59]	train's auc: 0.970779	valid's auc: 0.962069
# [60]	train's auc: 0.970962	valid's auc: 0.962509
# [61]	train's auc: 0.97116	valid's auc: 0.962639
# [62]	train's auc: 0.971377	valid's auc: 0.962744
# [63]	train's auc: 0.971788	valid's auc: 0.962946
# [64]	train's auc: 0.972078	valid's auc: 0.962996
# [65]	train's auc: 0.972282	valid's auc: 0.963163
# [66]	train's auc: 0.972449	valid's auc: 0.963215
# [67]	train's auc: 0.972864	valid's auc: 0.963277
# [68]	train's auc: 0.973186	valid's auc: 0.963516
# [69]	train's auc: 0.973499	valid's auc: 0.963727
# [70]	train's auc: 0.97375	valid's auc: 0.963955
# [71]	train's auc: 0.974046	valid's auc: 0.963913
# [72]	train's auc: 0.974237	valid's auc: 0.96412
# [73]	train's auc: 0.974533	valid's auc: 0.964215
# [74]	train's auc: 0.974796	valid's auc: 0.96432
# [75]	train's auc: 0.974998	valid's auc: 0.964575
# [76]	train's auc: 0.975139	valid's auc: 0.964505
# [77]	train's auc: 0.975268	valid's auc: 0.964493
# [78]	train's auc: 0.97544	valid's auc: 0.964575
# [79]	train's auc: 0.97564	valid's auc: 0.964729
# [80]	train's auc: 0.975847	valid's auc: 0.964844
# [81]	train's auc: 0.976127	valid's auc: 0.964897
# [82]	train's auc: 0.976392	valid's auc: 0.965068
# [83]	train's auc: 0.976464	valid's auc: 0.965056
# [84]	train's auc: 0.976642	valid's auc: 0.9651
# [85]	train's auc: 0.97684	valid's auc: 0.965207
# [86]	train's auc: 0.976974	valid's auc: 0.965291
# [87]	train's auc: 0.977115	valid's auc: 0.965369
# [88]	train's auc: 0.977207	valid's auc: 0.965395
# [89]	train's auc: 0.977388	valid's auc: 0.965551
# [90]	train's auc: 0.977574	valid's auc: 0.965621
# [91]	train's auc: 0.977745	valid's auc: 0.965578
# [92]	train's auc: 0.977942	valid's auc: 0.965725
# [93]	train's auc: 0.978129	valid's auc: 0.965688
# [94]	train's auc: 0.978356	valid's auc: 0.96569
# [95]	train's auc: 0.978601	valid's auc: 0.965871
# [96]	train's auc: 0.978795	valid's auc: 0.965918
# [97]	train's auc: 0.978995	valid's auc: 0.966046
# [98]	train's auc: 0.979152	valid's auc: 0.966032
# [99]	train's auc: 0.979368	valid's auc: 0.96602
# [100]	train's auc: 0.979613	valid's auc: 0.965958
# [101]	train's auc: 0.979842	valid's auc: 0.966143
# [102]	train's auc: 0.979972	valid's auc: 0.966239
# [103]	train's auc: 0.980238	valid's auc: 0.966224
# [104]	train's auc: 0.980397	valid's auc: 0.966247
# [105]	train's auc: 0.980501	valid's auc: 0.96622
# [106]	train's auc: 0.980688	valid's auc: 0.96632
# [107]	train's auc: 0.981035	valid's auc: 0.966486
# [108]	train's auc: 0.981175	valid's auc: 0.966491
# [109]	train's auc: 0.981344	valid's auc: 0.966411
# [110]	train's auc: 0.981479	valid's auc: 0.966408
# [111]	train's auc: 0.981585	valid's auc: 0.966484
# [112]	train's auc: 0.981729	valid's auc: 0.966638
# [113]	train's auc: 0.981909	valid's auc: 0.966679
# [114]	train's auc: 0.982063	valid's auc: 0.966848
# [115]	train's auc: 0.982156	valid's auc: 0.966824
# [116]	train's auc: 0.982317	valid's auc: 0.966866
# [117]	train's auc: 0.982488	valid's auc: 0.96681
# [118]	train's auc: 0.982628	valid's auc: 0.966918
# [119]	train's auc: 0.982777	valid's auc: 0.966991
# [120]	train's auc: 0.982842	valid's auc: 0.967073
# [121]	train's auc: 0.983034	valid's auc: 0.967085
# [122]	train's auc: 0.983164	valid's auc: 0.967177
# [123]	train's auc: 0.983242	valid's auc: 0.967167
# [124]	train's auc: 0.983393	valid's auc: 0.967141
# [125]	train's auc: 0.983503	valid's auc: 0.967141
# [126]	train's auc: 0.9837	valid's auc: 0.967217
# [127]	train's auc: 0.983785	valid's auc: 0.967273
# [128]	train's auc: 0.983899	valid's auc: 0.967191
# [129]	train's auc: 0.984029	valid's auc: 0.967191
# [130]	train's auc: 0.984161	valid's auc: 0.967173
# [131]	train's auc: 0.984287	valid's auc: 0.967305
# [132]	train's auc: 0.984398	valid's auc: 0.967286
# [133]	train's auc: 0.984539	valid's auc: 0.967298
# [134]	train's auc: 0.984628	valid's auc: 0.96729
# [135]	train's auc: 0.984663	valid's auc: 0.96742
# [136]	train's auc: 0.984769	valid's auc: 0.967284
# [137]	train's auc: 0.984948	valid's auc: 0.967354
# [138]	train's auc: 0.985079	valid's auc: 0.96729
# [139]	train's auc: 0.985173	valid's auc: 0.967373
# [140]	train's auc: 0.985335	valid's auc: 0.967437
# [141]	train's auc: 0.985451	valid's auc: 0.967517
# [142]	train's auc: 0.985557	valid's auc: 0.967525
# [143]	train's auc: 0.985675	valid's auc: 0.967476
# [144]	train's auc: 0.985793	valid's auc: 0.967442
# [145]	train's auc: 0.985836	valid's auc: 0.967443
# [146]	train's auc: 0.985926	valid's auc: 0.967498
# [147]	train's auc: 0.986066	valid's auc: 0.967501
# [148]	train's auc: 0.986231	valid's auc: 0.967544
# [149]	train's auc: 0.986271	valid's auc: 0.967457
# [150]	train's auc: 0.986383	valid's auc: 0.967421
# [151]	train's auc: 0.986508	valid's auc: 0.967483
# [152]	train's auc: 0.986614	valid's auc: 0.967485
# [153]	train's auc: 0.98673	valid's auc: 0.96762
# [154]	train's auc: 0.986879	valid's auc: 0.967608
# [155]	train's auc: 0.986972	valid's auc: 0.967657
# [156]	train's auc: 0.987057	valid's auc: 0.967557
# [157]	train's auc: 0.987152	valid's auc: 0.967565
# [158]	train's auc: 0.987191	valid's auc: 0.96762
# [159]	train's auc: 0.987261	valid's auc: 0.967687
# [160]	train's auc: 0.987397	valid's auc: 0.967706
# [161]	train's auc: 0.987524	valid's auc: 0.967654
# [162]	train's auc: 0.987692	valid's auc: 0.967667
# [163]	train's auc: 0.987818	valid's auc: 0.967678
# [164]	train's auc: 0.987909	valid's auc: 0.967585
# [165]	train's auc: 0.98803	valid's auc: 0.967612
# [166]	train's auc: 0.988163	valid's auc: 0.96766
# [167]	train's auc: 0.988213	valid's auc: 0.96766
# [168]	train's auc: 0.988286	valid's auc: 0.967666
# [169]	train's auc: 0.988421	valid's auc: 0.967759
# [170]	train's auc: 0.988491	valid's auc: 0.967774
# [171]	train's auc: 0.988614	valid's auc: 0.967674
# [172]	train's auc: 0.988686	valid's auc: 0.967756
# [173]	train's auc: 0.988722	valid's auc: 0.967801
# [174]	train's auc: 0.988805	valid's auc: 0.967937
# [175]	train's auc: 0.988918	valid's auc: 0.967938
# [176]	train's auc: 0.989043	valid's auc: 0.967796
# [177]	train's auc: 0.989104	valid's auc: 0.967797
# [178]	train's auc: 0.989177	valid's auc: 0.967732
# [179]	train's auc: 0.98928	valid's auc: 0.967742
# [180]	train's auc: 0.989383	valid's auc: 0.967836
# [181]	train's auc: 0.989464	valid's auc: 0.967844
# [182]	train's auc: 0.989513	valid's auc: 0.967895
# [183]	train's auc: 0.989588	valid's auc: 0.967963
# [184]	train's auc: 0.989669	valid's auc: 0.967949
# [185]	train's auc: 0.989743	valid's auc: 0.967914
# [186]	train's auc: 0.989811	valid's auc: 0.967911
# [187]	train's auc: 0.989889	valid's auc: 0.967981
# [188]	train's auc: 0.989968	valid's auc: 0.967945
# [189]	train's auc: 0.990037	valid's auc: 0.967912
# [190]	train's auc: 0.99007	valid's auc: 0.967845
# [191]	train's auc: 0.990114	valid's auc: 0.967847
# [192]	train's auc: 0.990178	valid's auc: 0.967844
# [193]	train's auc: 0.990215	valid's auc: 0.967847
# [194]	train's auc: 0.990307	valid's auc: 0.967938
# [195]	train's auc: 0.990378	valid's auc: 0.967942
# [196]	train's auc: 0.990433	valid's auc: 0.968013
# [197]	train's auc: 0.990516	valid's auc: 0.96804
# [198]	train's auc: 0.990572	valid's auc: 0.967993
# [199]	train's auc: 0.99067	valid's auc: 0.968002
# [200]	train's auc: 0.99075	valid's auc: 0.968086
# [201]	train's auc: 0.990764	valid's auc: 0.968126
# [202]	train's auc: 0.990856	valid's auc: 0.968132
# [203]	train's auc: 0.990941	valid's auc: 0.968151
# [204]	train's auc: 0.990958	valid's auc: 0.96817
# [205]	train's auc: 0.991054	valid's auc: 0.968159
# [206]	train's auc: 0.991097	valid's auc: 0.968179
# [207]	train's auc: 0.991161	valid's auc: 0.968226
# [208]	train's auc: 0.99124	valid's auc: 0.968236
# [209]	train's auc: 0.991325	valid's auc: 0.968296
# [210]	train's auc: 0.99141	valid's auc: 0.968302
# [211]	train's auc: 0.991449	valid's auc: 0.968341
# [212]	train's auc: 0.991504	valid's auc: 0.968321
# [213]	train's auc: 0.991597	valid's auc: 0.968335
# [214]	train's auc: 0.991676	valid's auc: 0.968363
# [215]	train's auc: 0.991725	valid's auc: 0.968344
# [216]	train's auc: 0.991794	valid's auc: 0.968335
# [217]	train's auc: 0.991866	valid's auc: 0.968335
# [218]	train's auc: 0.991922	valid's auc: 0.968358
# [219]	train's auc: 0.991991	valid's auc: 0.968354
# [220]	train's auc: 0.992037	valid's auc: 0.968375
# [221]	train's auc: 0.992103	valid's auc: 0.968408
# [222]	train's auc: 0.992164	valid's auc: 0.968411
# [223]	train's auc: 0.992214	valid's auc: 0.968482
# [224]	train's auc: 0.992264	valid's auc: 0.968608
# [225]	train's auc: 0.992304	valid's auc: 0.968633
# [226]	train's auc: 0.992342	valid's auc: 0.968707
# [227]	train's auc: 0.992426	valid's auc: 0.968597
# [228]	train's auc: 0.992471	valid's auc: 0.968617
# [229]	train's auc: 0.992484	valid's auc: 0.968638
# [230]	train's auc: 0.992523	valid's auc: 0.968698
# [231]	train's auc: 0.992563	valid's auc: 0.968676
# [232]	train's auc: 0.99264	valid's auc: 0.968638
# [233]	train's auc: 0.992679	valid's auc: 0.968703
# [234]	train's auc: 0.992705	valid's auc: 0.968739
# [235]	train's auc: 0.992771	valid's auc: 0.968681
# [236]	train's auc: 0.992821	valid's auc: 0.968743
# [237]	train's auc: 0.992868	valid's auc: 0.968623
# [238]	train's auc: 0.992947	valid's auc: 0.968637
# [239]	train's auc: 0.992971	valid's auc: 0.968706
# [240]	train's auc: 0.993045	valid's auc: 0.968702
# [241]	train's auc: 0.993079	valid's auc: 0.968687
# [242]	train's auc: 0.993132	valid's auc: 0.96866
# [243]	train's auc: 0.993195	valid's auc: 0.968667
# [244]	train's auc: 0.993264	valid's auc: 0.968675
# [245]	train's auc: 0.993351	valid's auc: 0.968695
# [246]	train's auc: 0.9934	valid's auc: 0.968726
# [247]	train's auc: 0.993444	valid's auc: 0.968688
# [248]	train's auc: 0.993502	valid's auc: 0.968735
# [249]	train's auc: 0.993549	valid's auc: 0.968821
# [250]	train's auc: 0.993617	valid's auc: 0.968851
# [251]	train's auc: 0.993686	valid's auc: 0.968863
# [252]	train's auc: 0.993738	valid's auc: 0.968806
# [253]	train's auc: 0.993802	valid's auc: 0.968744
# [254]	train's auc: 0.993802	valid's auc: 0.968767
# [255]	train's auc: 0.993832	valid's auc: 0.968783
# [256]	train's auc: 0.993867	valid's auc: 0.968782
# [257]	train's auc: 0.993922	valid's auc: 0.968853
# [258]	train's auc: 0.993986	valid's auc: 0.968743
# [259]	train's auc: 0.994055	valid's auc: 0.968672
# [260]	train's auc: 0.994132	valid's auc: 0.96878
# [261]	train's auc: 0.994179	valid's auc: 0.968791
# [262]	train's auc: 0.994241	valid's auc: 0.968728
# [263]	train's auc: 0.994296	valid's auc: 0.968753
# [264]	train's auc: 0.994352	valid's auc: 0.968688
# [265]	train's auc: 0.994406	valid's auc: 0.968678
# [266]	train's auc: 0.994432	valid's auc: 0.96869
# [267]	train's auc: 0.99448	valid's auc: 0.968549
# [268]	train's auc: 0.994503	valid's auc: 0.968457
# [269]	train's auc: 0.994547	valid's auc: 0.968425
# [270]	train's auc: 0.994578	valid's auc: 0.968402
# [271]	train's auc: 0.994623	valid's auc: 0.968433
# [272]	train's auc: 0.99468	valid's auc: 0.968509
# [273]	train's auc: 0.994716	valid's auc: 0.968632
# [274]	train's auc: 0.994746	valid's auc: 0.968669
# [275]	train's auc: 0.994777	valid's auc: 0.968638
# [276]	train's auc: 0.994816	valid's auc: 0.968668
# [277]	train's auc: 0.994851	valid's auc: 0.968698
# [278]	train's auc: 0.994901	valid's auc: 0.968672
# [279]	train's auc: 0.994954	valid's auc: 0.968628
# [280]	train's auc: 0.994985	valid's auc: 0.968562
# [281]	train's auc: 0.99502	valid's auc: 0.968581
# [282]	train's auc: 0.995061	valid's auc: 0.968524
# [283]	train's auc: 0.995119	valid's auc: 0.968533
# [284]	train's auc: 0.995145	valid's auc: 0.968505
# [285]	train's auc: 0.995196	valid's auc: 0.968519
# [286]	train's auc: 0.995223	valid's auc: 0.968528
# [287]	train's auc: 0.995257	valid's auc: 0.968503
# [288]	train's auc: 0.995312	valid's auc: 0.968572
# [289]	train's auc: 0.995357	valid's auc: 0.968588
# [290]	train's auc: 0.995394	valid's auc: 0.968575
# [291]	train's auc: 0.99543	valid's auc: 0.96852
# [292]	train's auc: 0.995445	valid's auc: 0.968606
# [293]	train's auc: 0.995483	valid's auc: 0.968629
# [294]	train's auc: 0.995518	valid's auc: 0.968647
# [295]	train's auc: 0.99555	valid's auc: 0.968625
# [296]	train's auc: 0.995586	valid's auc: 0.96868
# [297]	train's auc: 0.99561	valid's auc: 0.968663
# [298]	train's auc: 0.995636	valid's auc: 0.968625
# [299]	train's auc: 0.995681	valid's auc: 0.968657
# [300]	train's auc: 0.995736	valid's auc: 0.968676
# [301]	train's auc: 0.995814	valid's auc: 0.968608
# [302]	train's auc: 0.99587	valid's auc: 0.968756
# [303]	train's auc: 0.995902	valid's auc: 0.968694
# [304]	train's auc: 0.995917	valid's auc: 0.968635
# [305]	train's auc: 0.995942	valid's auc: 0.968721
# [306]	train's auc: 0.996003	valid's auc: 0.968661
# [307]	train's auc: 0.996018	valid's auc: 0.968599
# [308]	train's auc: 0.996076	valid's auc: 0.968595
# [309]	train's auc: 0.996101	valid's auc: 0.968605
# [310]	train's auc: 0.996141	valid's auc: 0.968536
# [311]	train's auc: 0.99616	valid's auc: 0.968536
# [312]	train's auc: 0.996161	valid's auc: 0.968516
# [313]	train's auc: 0.996205	valid's auc: 0.968532
# [314]	train's auc: 0.996234	valid's auc: 0.968547
# [315]	train's auc: 0.996251	valid's auc: 0.968633
# [316]	train's auc: 0.996285	valid's auc: 0.968577
# [317]	train's auc: 0.996327	valid's auc: 0.968676
# [318]	train's auc: 0.996344	valid's auc: 0.968659
# [319]	train's auc: 0.996366	valid's auc: 0.96866
# [320]	train's auc: 0.996397	valid's auc: 0.968682
# [321]	train's auc: 0.996459	valid's auc: 0.968697
# [322]	train's auc: 0.99649	valid's auc: 0.968638
# [323]	train's auc: 0.996511	valid's auc: 0.968654
# [324]	train's auc: 0.99653	valid's auc: 0.968708
# [325]	train's auc: 0.996567	valid's auc: 0.968685
# [326]	train's auc: 0.996598	valid's auc: 0.968676
# [327]	train's auc: 0.996608	valid's auc: 0.968697
# [328]	train's auc: 0.996657	valid's auc: 0.968728
# [329]	train's auc: 0.996693	valid's auc: 0.968721
# [330]	train's auc: 0.996718	valid's auc: 0.968718
# [331]	train's auc: 0.996738	valid's auc: 0.968751
# [332]	train's auc: 0.99678	valid's auc: 0.96875
# [333]	train's auc: 0.996805	valid's auc: 0.968807
# [334]	train's auc: 0.996816	valid's auc: 0.968762
# [335]	train's auc: 0.996855	valid's auc: 0.96877
# [336]	train's auc: 0.996888	valid's auc: 0.968776
# [337]	train's auc: 0.996911	valid's auc: 0.96868
# [338]	train's auc: 0.996933	valid's auc: 0.968594
# [339]	train's auc: 0.99695	valid's auc: 0.968702
# [340]	train's auc: 0.996976	valid's auc: 0.968769
# [341]	train's auc: 0.996991	valid's auc: 0.968749
# [342]	train's auc: 0.997021	valid's auc: 0.96868
# [343]	train's auc: 0.99705	valid's auc: 0.968661
# [344]	train's auc: 0.997074	valid's auc: 0.968665
# [345]	train's auc: 0.997116	valid's auc: 0.968735
# [346]	train's auc: 0.997145	valid's auc: 0.968799
# [347]	train's auc: 0.997183	valid's auc: 0.96874
# [348]	train's auc: 0.99723	valid's auc: 0.968728
# [349]	train's auc: 0.997245	valid's auc: 0.968703
# [350]	train's auc: 0.997264	valid's auc: 0.968718
# [351]	train's auc: 0.997296	valid's auc: 0.96869
# Early stopping, best iteration is:
# [251]	train's auc: 0.993686	valid's auc: 0.968863
# The 4 kfold score : 0.7220536756126021
# score_0: 0.7471411901983663
# score_1: 0.7245040840140022
# score_2: 0.7163360560093349
# score_3: 0.7231038506417735
# score_4: 0.7220536756126021
# score_mean:  0.7266277712952158
